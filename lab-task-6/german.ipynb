# %% [markdown]
# ## Morphological Generation on Hindi, Bengali, German, Middle high German

# %%
# !git clone -b my --single-branch https://github.com/Kenny-08/morph-generation.git
# Out:
# Cloning into 'morph-generation'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 38 (delta 12), reused 37 (delta 11), pack-reused 0
# Unpacking objects: 100% (38/38), done.

# %%
cd morph-generation/
# Out:
# /content/morph-generation

# %%
# !python morph_inflection_generation.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Prediction:	 पाते है
# 0.2727272727272727
#
# 2
# Actual    :	 झांकिए
# Prediction:	 ये झाेे
# 0.125
#
# 3
# Actual    :	 चुराते होंगे
# Prediction:	 चुरता थे
# 0.2857142857142857
#
# 4
# Actual    :	 लड़ी होती
# Prediction:	 लड़ी होती
# 1.0
#
# 5
# Actual    :	 पिघल रही होगी
# Prediction:	 पिघलती होगी
# 0.3333333333333333
#
# 6
# Actual    :	 चढ़ती हैं
# Prediction:	 चढ़ती हैं
# 1.0
#
# 7
# Actual    :	 आरम्भ कर रही हैं
# Prediction:	 आरम्भ करती हैं
# 0.5
#
# 8
# Actual    :	 बन रही होती
# Prediction:	 बन रही होती
# 1.0
#
# 9
# Actual    :	 भेजती होती
# Prediction:	 जपनती हूती
# 0.6666666666666666
#
# 10
# Actual    :	 जगी हो
# Prediction:	 जगी हो
# 1.0
#
# 11
# Actual    :	 सहमा होगा
# Prediction:	 सहमा होगा
# 1.0
#
# 12
# Actual    :	 उड़ाई होती
# Prediction:	 उड़ाई हो
# 0.75
#
# 13
# Actual    :	 संभोग कर रही है
# Prediction:	 संगी करती है
# 0.23529411764705882
#
# 14
# Actual    :	 ये फँसें
# Prediction:	 ये सुसें
# 0.8
#
# 15
# Actual    :	 चबा रही होती
# Prediction:	 चबा रही होती
# 1.0
#
# 16
# Actual    :	 माफ़ करता था
# Prediction:	 माफ़ करता था
# 1.0
#
# 17
# Actual    :	 ठीक होई हूँ
# Prediction:	 मैठ की हूठी
# 0.15384615384615385
#
# 18
# Actual    :	 पिघले होते
# Prediction:	 पिघला हो
# 0.6666666666666666
#
# 19
# Actual    :	 हम सड़ें
# Prediction:	 सड़नें
# 0.1
#
# 20
# Actual    :	 तू अध्ययन करेगी
# Prediction:	 यह अध्ययन करे
# 0.7058823529411765
#
# 21
# Actual    :	 स्वप्न देखते
# Prediction:	 ये पने
# 0.14285714285714285
#
# 22
# Actual    :	 तुम बनोगे
# Prediction:	 बन ी
# 0.09090909090909091
#
# 23
# Actual    :	 ये खोलें
# Prediction:	 तुम लोड़ा
# 0.1
#
# 24
# Actual    :	 उड़ा रही हों
# Prediction:	 उड़ा रही हों
# 1.0
#
# 25
# Actual    :	 प्रयत्न करती होती
# Prediction:	 प्रयत्त करती हूँ
# 0.7368421052631579
#
# 26
# Actual    :	 बेच रही होंगी
# Prediction:	 बेचती थीं
# 0.26666666666666666
#
# 27
# Actual    :	 झूम रही हैं
# Prediction:	 झूमी हैं
# 0.38461538461538464
#
# 28
# Actual    :	 तू छिपाएगी
# Prediction:	 छिपियाए
# 0.08333333333333333
#
# 29
# Actual    :	 हम टेंटुआ दबाएं
# Prediction:	 टेंटु दबट बटें
# 0.23529411764705882
#
# 30
# Actual    :	 बचता होता
# Prediction:	 बचता होता
# 1.0
#
# 31
# Actual    :	 बेच रही होगी
# Prediction:	 बेचती थीं
# 0.2857142857142857
#
# 32
# Actual    :	 बनती हूँगी
# Prediction:	 बन रही हूँग
# 0.25
#
# 33
# Actual    :	 नहा रहा होगा
# Prediction:	 नहाता होगा
# 0.2857142857142857
#
# 34
# Actual    :	 छुट रही होती
# Prediction:	 छुटती होती
# 0.2857142857142857
#
# 35
# Actual    :	 मस्ती करते होते
# Prediction:	 मस्ती करते होते
# 1.0
#
# 36
# Actual    :	 प्रवेश किया होगा
# Prediction:	 प्रवेश किया था
# 0.7222222222222222
#
# 37
# Actual    :	 यह स्वप्न देखेगी
# Prediction:	 स्वप्देख देखती
# 0.1111111111111111
#
# 38
# Actual    :	 छींक रही हैं
# Prediction:	 छींक रही हैं
# 1.0
#
# 39
# Actual    :	 ना करती हों
# Prediction:	 ना करती हों
# 1.0
#
# 40
# Actual    :	 यह अपना पालक पनीर देखे
# Prediction:	 अपना पा पन करनेखी
# 0.20833333333333334
#
# 41
# Actual    :	 तुम जपोगे
# Prediction:	 जपिए
# 0.09090909090909091
#
# 42
# Actual    :	 हगे थे
# Prediction:	 हगे थे
# 1.0
#
# 43
# Actual    :	 बनाए थे
# Prediction:	 बना थे
# 0.4444444444444444
#
# 44
# Actual    :	 बोल रहे हैं
# Prediction:	 बोल रहे हैते
# 0.8461538461538461
#
# 45
# Actual    :	 ये बेचेंगे
# Prediction:	 तुम चबेंगे
# 0.5
#
# 46
# Actual    :	 बैठता होगा
# Prediction:	 बैठता होगा
# 1.0
#
# 47
# Actual    :	 छीलता हो
# Prediction:	 छीलता हो
# 1.0
#
# 48
# Actual    :	 सेक्स किया होता
# Prediction:	 सेक्सि किया हूँ
# 0.4117647058823529
#
# 49
# Actual    :	 बोलती हों
# Prediction:	 बोलती हों
# 1.0
#
# 50
# Actual    :	 मतलब होई हों
# Prediction:	 तूम बन हों
# 0.07142857142857142
#
# 51
# Actual    :	 उलटी कर रही होती
# Prediction:	 उौलत करती होती
# 0.2777777777777778
#
# 52
# Actual    :	 ऐश किया होता
# Prediction:	 ऐश किया होता
# 1.0
#
# 53
# Actual    :	 सहमा रही हैं
# Prediction:	 सहमाती हैं
# 0.35714285714285715
#
# 54
# Actual    :	 खोला हो
# Prediction:	 खोल ा हो
# 0.4444444444444444
#
# 55
# Actual    :	 उतरने
# Prediction:	 उती
# 0.42857142857142855
#
# 56
# Actual    :	 कुरेदने
# Prediction:	 ये ी
# 0.1111111111111111
#
# 57
# Actual    :	 घुसा हूँ
# Prediction:	 घुसा हो
# 0.7
#
# 58
# Actual    :	 झाड़ते हों
# Prediction:	 झाड़ते हों
# 1.0
#
# 59
# Actual    :	 लिखते होगे
# Prediction:	 लिख रहे थे
# 0.5
#
# 60
# Actual    :	 कूटे हो
# Prediction:	 कूट किये
# 0.4444444444444444
#
# 61
# Actual    :	 मोड़ रहे हो
# Prediction:	 मोड़ते हो
# 0.38461538461538464
#
# 62
# Actual    :	 अंछर मारई होती
# Prediction:	 अंछर मार रही हो
# 0.625
#
# 63
# Actual    :	 पहन रही हों
# Prediction:	 पहनती हों
# 0.3076923076923077
#
# 64
# Actual    :	 रची होती
# Prediction:	 चरी होती
# 0.8
#
# 65
# Actual    :	 झाड़ी हूँगी
# Prediction:	 झाड़ी हूँगी
# 1.0
#
# 66
# Actual    :	 छुट रही हों
# Prediction:	 छुटती हों
# 0.3076923076923077
#
# 67
# Actual    :	 चुसी होती
# Prediction:	 चुसी है
# 0.6363636363636364
#
# 68
# Actual    :	 ठगी होती
# Prediction:	 झगी होती
# 0.9
#
# 69
# Actual    :	 मनाती थीं
# Prediction:	 मनाती थीं
# 1.0
#
# 70
# Actual    :	 यह भेजे
# Prediction:	 भूने
# 0.1111111111111111
#
# 71
# Actual    :	 नहाते हो
# Prediction:	 नहाते है
# 0.9
#
# 72
# Actual    :	 अंछर मारए होंगे
# Prediction:	 अंछर मार रहे थे
# 0.7058823529411765
#
# 73
# Actual    :	 त्यागा होता
# Prediction:	 त्यागा है
# 0.6923076923076923
#
# 74
# Actual    :	 गुणा करता हूँगा
# Prediction:	 गुणा कर रहा हूँग
# 0.47058823529411764
#
# 75
# Actual    :	 मैं साफ़ करूंगी
# Prediction:	 येमाफ करतूंगी
# 0.058823529411764705
#
# 76
# Actual    :	 उड़ता होता
# Prediction:	 उड़ रहा होत
# 0.3333333333333333
#
# 77
# Actual    :	 गुणा कर रही थीं
# Prediction:	 गुणा कर रही होंग
# 0.8235294117647058
#
# 78
# Actual    :	 बर्दाश्त किया था
# Prediction:	 बर्दाश्त किया था
# 1.0
#
# 79
# Actual    :	 ये पहनें
# Prediction:	 पहनी
# 0.1
#
# 80
# Actual    :	 पड़ी हूँ
# Prediction:	 पड़ रही ह
# 0.5
#
# 81
# Actual    :	 इलाज कर रहा था
# Prediction:	 इलाज करता था
# 0.5
#
# 82
# Actual    :	 मिला रहे थे
# Prediction:	 मिलाते थे
# 0.38461538461538464
#
# 83
# Actual    :	 समझ रहा था
# Prediction:	 समझ रहा था
# 1.0
#
# 84
# Actual    :	 बर्दाश्त कियी थी
# Prediction:	 बर्दाश्त कियी थी
# 1.0
#
# 85
# Actual    :	 चाट रहा होता
# Prediction:	 चाटता है
# 0.2857142857142857
#
# 86
# Actual    :	 दोहरा रही होगी
# Prediction:	 दोहरा ी थी
# 0.4375
#
# 87
# Actual    :	 स्वप्न देख रहे होंगे
# Prediction:	 स्वप्न देखते होंगे
# 0.5
#
# 88
# Actual    :	 सुधार रही होगी
# Prediction:	 सुधार कर रही थी
# 0.5
#
# 89
# Actual    :	 लौटी होगी
# Prediction:	 लौटी होगी
# 1.0
#
# 90
# Actual    :	 ये पूजा करेंगी
# Prediction:	 पूजा करेंगी
# 0.0625
#
# 91
# Actual    :	 चुक रहा होता
# Prediction:	 चुकता होता
# 0.2857142857142857
#
# 92
# Actual    :	 सूंघती हों
# Prediction:	 सूंघ ी हों
# 0.9166666666666666
#
# 93
# Actual    :	 नहाती थी
# Prediction:	 नानती थी
# 0.8
#
# 94
# Actual    :	 सोचती हैं
# Prediction:	 सोचती है
# 0.8181818181818182
#
# 95
# Actual    :	 पिट रहे थे
# Prediction:	 पिटते थे
# 0.3333333333333333
#
# 96
# Actual    :	 पीया हूँ
# Prediction:	 पी हैँ
# 0.3
#
# 97
# Actual    :	 हस्तमैथुन किया होगा
# Prediction:	 हस्तमार किया होगा
# 0.2857142857142857
#
# 98
# Actual    :	 गिरफ़्तार करता होगा
# Prediction:	 गिरफ़्तार करता होगा
# 1.0
#
# 99
# Actual    :	 बन रही हों
# Prediction:	 बनती हों
# 0.25
#
# 100
# Actual    :	 झूमते हों
# Prediction:	 झूमते हों
# 1.0
#
# 101
# Actual    :	 झगड़े थे
# Prediction:	 झगड़े थे
# 1.0
#
# 102
# Actual    :	 भूले हैं
# Prediction:	 भूल होते
# 0.5
#
# 103
# Actual    :	 सुना रहे होंगे
# Prediction:	 सुना रहे थे
# 0.625
#
# 104
# Actual    :	 प्रेम करते होंगे
# Prediction:	 प्रेम करते थे
# 0.6666666666666666
#
# 105
# Actual    :	 जोड़ए होगे
# Prediction:	 जोड़े थे
# 0.5
#
# 106
# Actual    :	 तुम नहाओ
# Prediction:	 हम नहनाए
# 0.3
#
# 107
# Actual    :	 तुम छोड़ो
# Prediction:	 छोड़ छो
# 0.09090909090909091
#
# 108
# Actual    :	 साफ़ किया है
# Prediction:	 साफ़ किया है
# 1.0
#
# 109
# Actual    :	 उबल रही होती
# Prediction:	 उबलती होती
# 0.2857142857142857
#
# 110
# Actual    :	 याद कर रहा होता
# Prediction:	 याद करता हो
# 0.4117647058823529
#
# 111
# Actual    :	 बात कर रहा हूँ
# Prediction:	 बात कर रहा हूँ
# 1.0
#
# 112
# Actual    :	 चढ़ा रहे थे
# Prediction:	 चढ़ा रहे थे
# 1.0
#
# 113
# Actual    :	 बैठा हूँ
# Prediction:	 बैठा हूँ
# 1.0
#
# 114
# Actual    :	 जगा था
# Prediction:	 जगा था
# 1.0
#
# 115
# Actual    :	 बजाई हो
# Prediction:	 बजाई है
# 0.8888888888888888
#
# 116
# Actual    :	 मतलब होती हूँ
# Prediction:	 मतलब होती हूँ
# 1.0
#
# 117
# Actual    :	 लटकती थी
# Prediction:	 लौटती थी
# 0.8
#
# 118
# Actual    :	 यह हटेगा
# Prediction:	 तुम हटोगी
# 0.1
#
# 119
# Actual    :	 नफ़रत कर रही हैं
# Prediction:	 नफ़रत करती हैं
# 0.5
#
# 120
# Actual    :	 निकलते हो
# Prediction:	 निकलते है
# 0.9090909090909091
#
# 121
# Actual    :	 रखती
# Prediction:	 यी
# 0.16666666666666666
#
# 122
# Actual    :	 सेक्स कर रही होंगी
# Prediction:	 सेक्स करती होंगी
# 0.45
#
# 123
# Actual    :	 सहमते हों
# Prediction:	 सहमते हों
# 1.0
#
# 124
# Actual    :	 कुरेद रही थी
# Prediction:	 कुरेदती थी
# 0.42857142857142855
#
# 125
# Actual    :	 बर्दाश्त कर रही होगी
# Prediction:	 बर्दाश्त करती ही
# 0.5454545454545454
#
# 126
# Actual    :	 बोलती होती
# Prediction:	 बोलती होती
# 1.0
#
# 127
# Actual    :	 तू जागेगी
# Prediction:	 या जागी
# 0.45454545454545453
#
# 128
# Actual    :	 छेड़ रहे हो
# Prediction:	 छेड़ रहे हो
# 1.0
#
# 129
# Actual    :	 छाप रही होंगी
# Prediction:	 छाप रही होंगी
# 1.0
#
# 130
# Actual    :	 अंगारे बरस रही हूँ
# Prediction:	 अंगारे बरसी हूँ
# 0.6
#
# 131
# Actual    :	 आदर करता हूँगा
# Prediction:	 आदर करता था
# 0.625
#
# 132
# Actual    :	 भागए थे
# Prediction:	 भाग रहे
# 0.5555555555555556
#
# 133
# Actual    :	 सहमाता
# Prediction:	 यहमानती
# 0.5
#
# 134
# Actual    :	 बाटए हों
# Prediction:	 बाटा हों
# 0.9
#
# 135
# Actual    :	 चोद रहा था
# Prediction:	 चोदता था
# 0.3333333333333333
#
# 136
# Actual    :	 सोची होंगी
# Prediction:	 सोची होंगी
# 1.0
#
# 137
# Actual    :	 दोहराइये
# Prediction:	 यह होदा
# 0.1
#
# 138
# Actual    :	 बिखर रही होगी
# Prediction:	 बिखरती होगी
# 0.3333333333333333
#
# 139
# Actual    :	 भुना होता
# Prediction:	 भुना होता
# 1.0
#
# 140
# Actual    :	 डर रहे थे
# Prediction:	 ड़ते थे
# 0.18181818181818182
#
# 141
# Actual    :	 आग्रह करती है
# Prediction:	 आग्रह करती है
# 1.0
#
# 142
# Actual    :	 हिली थी
# Prediction:	 हिली थी
# 1.0
#
# 143
# Actual    :	 हल चलाता
# Prediction:	 हम चलायी
# 0.7
#
# 144
# Actual    :	 कुरेदा हूँगा
# Prediction:	 कुरेदा हूँगा
# 1.0
#
# 145
# Actual    :	 डलवाती होती
# Prediction:	 डलवा रही है
# 0.46153846153846156
#
# 146
# Actual    :	 नशा कियी हो
# Prediction:	 नशा कियी हो
# 1.0
#
# 147
# Actual    :	 बटोरती होती
# Prediction:	 बटोर रही हो
# 0.46153846153846156
#
# 148
# Actual    :	 चोट किये होंगे
# Prediction:	 चोट किये होंगे
# 1.0
#
# 149
# Actual    :	 छींकती हो
# Prediction:	 छींकती हो
# 1.0
#
# 150
# Actual    :	 अंगारा होती होगी
# Prediction:	 अंगारा हो रही थीं
# 0.6111111111111112
#
# 151
# Actual    :	 पहुँची हो
# Prediction:	 पहुँची हो
# 1.0
#
# 152
# Actual    :	 यह सड़े
# Prediction:	 ये सड़से
# 0.6666666666666666
#
# 153
# Actual    :	 अंगारे बरसई होती
# Prediction:	 अंगारे बरसई हैं
# 0.7777777777777778
#
# 154
# Actual    :	 सहमाए होंगे
# Prediction:	 समान रहे थे
# 0.38461538461538464
#
# 155
# Actual    :	 लौटती थीं
# Prediction:	 लौटती थीं
# 1.0
#
# 156
# Actual    :	 झगड़ते थे
# Prediction:	 झगड़ रहे थ
# 0.45454545454545453
#
# 157
# Actual    :	 ठगती हैं
# Prediction:	 गगती हैं
# 0.9
#
# 158
# Actual    :	 शुक्रिया करती थी
# Prediction:	 शुक्रिया करती थी
# 1.0
#
# 159
# Actual    :	 तैराता होता
# Prediction:	 तूबाता होता
# 0.8461538461538461
#
# 160
# Actual    :	 ठग रही होती
# Prediction:	 उठती होती
# 0.07692307692307693
#
# 161
# Actual    :	 टपकिए
# Prediction:	 पीटी
# 0.14285714285714285
#
# 162
# Actual    :	 ग़लत कर रहा था
# Prediction:	 ग़लत करता था
# 0.5
#
# 163
# Actual    :	 गिरफ़्तार करती थीं
# Prediction:	 गिरफ़्तार करती थीं
# 1.0
#
# 164
# Actual    :	 भौंह चढ़ाई होगी
# Prediction:	 भौंह चढ़ाई थी
# 0.7058823529411765
#
# 165
# Actual    :	 निर्माण किये हों
# Prediction:	 निरिक्या किये हों
# 0.2222222222222222
#
# 166
# Actual    :	 जला रही हैं
# Prediction:	 जला रही है
# 0.8461538461538461
#
# 167
# Actual    :	 यह तौबा करेगी
# Prediction:	 तै बात कर
# 0.13333333333333333
#
# 168
# Actual    :	 चूमी थी
# Prediction:	 चूम ी
# 0.4444444444444444
#
# 169
# Actual    :	 कुरेदे हो
# Prediction:	 कुरेद किये
# 0.5454545454545454
#
# 170
# Actual    :	 पीए थे
# Prediction:	 पीक थे
# 0.875
#
# 171
# Actual    :	 घृणा कियी होती
# Prediction:	 घृणा कियी हैं
# 0.75
#
# 172
# Actual    :	 हम पसीजेंगी
# Prediction:	 तुम पसीजें
# 0.07692307692307693
#
# 173
# Actual    :	 चलती है
# Prediction:	 चलती है
# 1.0
#
# 174
# Actual    :	 थाम रहा हो
# Prediction:	 थामता हो
# 0.3333333333333333
#
# 175
# Actual    :	 झूठ बोल रहे होंगे
# Prediction:	 झूठत बर रहे होंगे
# 0.7894736842105263
#
# 176
# Actual    :	 पा रही होती
# Prediction:	 पाती होती
# 0.23076923076923078
#
# 177
# Actual    :	 तू दबाएगा
# Prediction:	 दबा
# 0.09090909090909091
#
# 178
# Actual    :	 सहमा रहे हों
# Prediction:	 सहमाते हों
# 0.35714285714285715
#
# 179
# Actual    :	 सहायता किया
# Prediction:	 ययययाययायी
# 0.15384615384615385
#
# 180
# Actual    :	 हम टपकेंगी
# Prediction:	 मैट पिटेंगी
# 0.16666666666666666
#
# 181
# Actual    :	 अंगारे बरसती हैं
# Prediction:	 अंगारे बरती हैं
# 0.5555555555555556
#
# 182
# Actual    :	 सूखी होंगी
# Prediction:	 सूखी थीं
# 0.5833333333333334
#
# 183
# Actual    :	 नहा रही हूँ
# Prediction:	 नहाती है
# 0.3076923076923077
#
# 184
# Actual    :	 पाई हूँगी
# Prediction:	 पाई हूँगी
# 1.0
#
# 185
# Actual    :	 ग़लत कर रही हूँ
# Prediction:	 ग़लत करती हूँ
# 0.47058823529411764
#
# 186
# Actual    :	 बनाया हूँगा
# Prediction:	 बनाया था
# 0.5384615384615384
#
# 187
# Actual    :	 इस्तेमाल किये होगे
# Prediction:	 इस्तेमाल किये होगे
# 1.0
#
# 188
# Actual    :	 हम चोट करें
# Prediction:	 चोट की
# 0.07692307692307693
#
# 189
# Actual    :	 लौटती थी
# Prediction:	 लौटती थी
# 1.0
#
# 190
# Actual    :	 मना रही हों
# Prediction:	 मनाती हों
# 0.3076923076923077
#
# 191
# Actual    :	 झूमी हों
# Prediction:	 झूमी हों
# 1.0
#
# 192
# Actual    :	 माफ़ कियी होती
# Prediction:	 माफ़ कियी होती
# 1.0
#
# 193
# Actual    :	 रौशन करते हो
# Prediction:	 रौशन करते है
# 0.9285714285714286
#
# 194
# Actual    :	 मिला रही हूँ
# Prediction:	 मिलाती हूँ
# 0.35714285714285715
#
# 195
# Actual    :	 खेला था
# Prediction:	 खडल रहा
# 0.4444444444444444
#
# 196
# Actual    :	 दोहराते हैं
# Prediction:	 दोंरताते हैं
# 0.3076923076923077
#
# 197
# Actual    :	 लू कर रहा होता
# Prediction:	 लू कर रहा हूँ
# 0.75
#
# 198
# Actual    :	 सहमाने
# Prediction:	 यहम थाए
# 0.375
#
# 199
# Actual    :	 बर्दाश्त कियी थी
# Prediction:	 बर्दाश्त कियी थी
# 1.0
#
# 200
# Actual    :	 पड़ रही हों
# Prediction:	 पड़ रही हों
# 1.0
#
# 201
# Actual    :	 जमा कियी होंगी
# Prediction:	 जमा कियी हीं
# 0.75
#
# 202
# Actual    :	 ये डलवाएंगी
# Prediction:	 डलवालोए
# 0.15384615384615385
#
# 203
# Actual    :	 भौंह चढ़ाई थी
# Prediction:	 भौंह चढ़ाई थी
# 1.0
#
# 204
# Actual    :	 कस रहे होते
# Prediction:	 कस रहे होते
# 1.0
#
# 205
# Actual    :	 ये बिकेंगी
# Prediction:	 बिकते
# 0.08333333333333333
#
# 206
# Actual    :	 दौड़ रहे होते
# Prediction:	 दौड़ रहे होते
# 1.0
#
# 207
# Actual    :	 झाँकती हूँगी
# Prediction:	 झाँकी ी थी
# 0.35714285714285715
#
# 208
# Actual    :	 मैं निखारूँगा
# Prediction:	 निखारूँ
# 0.06666666666666667
#
# 209
# Actual    :	 भेज रहा हो
# Prediction:	 भौजता हो
# 0.25
#
# 210
# Actual    :	 बिलबिलाना
# Prediction:	 ये येमाए
# 0.18181818181818182
#
# 211
# Actual    :	 यह कोशिश करेगी
# Prediction:	 कोशिश कर
# 0.0625
#
# 212
# Actual    :	 बिलबिलाए होगे
# Prediction:	 बिलबियाए थे
# 0.6
#
# 213
# Actual    :	 पिट रहा हूँ
# Prediction:	 पिट रहा हूँ
# 1.0
#
# 214
# Actual    :	 कोशिश करो
# Prediction:	 ये ोशायी
# 0.16666666666666666
#
# 215
# Actual    :	 सामने आता हो
# Prediction:	 सामाने आता रह
# 0.2857142857142857
#
# 216
# Actual    :	 रोकते हैं
# Prediction:	 रोकते हैं
# 1.0
#
# 217
# Actual    :	 आरम्भ कर रहा होगा
# Prediction:	 आर्भ करता था
# 0.21052631578947367
#
# 218
# Actual    :	 कोशिश कर रही हैं
# Prediction:	 कोशिश करती हैं
# 0.5
#
# 219
# Actual    :	 बाँध
# Prediction:	 यहमा
# 0.25
#
# 220
# Actual    :	 टेंटुआ दबाई होती
# Prediction:	 टेंटुआ दबाई होती
# 1.0
#
# 221
# Actual    :	 स्थापित करती होती
# Prediction:	 स्थापित करती होती
# 1.0
#
# 222
# Actual    :	 स्थापित करता था
# Prediction:	 स्थापित करता था
# 1.0
#
# 223
# Actual    :	 तू बांधएगी
# Prediction:	 बांध बरे
# 0.08333333333333333
#
# 224
# Actual    :	 तुम खड़ा करो
# Prediction:	 खड़ा करना
# 0.07142857142857142
#
# 225
# Actual    :	 नापए हो
# Prediction:	 नापए है
# 0.8888888888888888
#
# 226
# Actual    :	 अंछर मार रहे थे
# Prediction:	 अंछर मार रहे थे
# 1.0
#
# 227
# Actual    :	 कसती हूँ
# Prediction:	 कसती है
# 0.7
#
# 228
# Actual    :	 यह डाउनलोड करे
# Prediction:	 डाउनलोड करे
# 0.0625
#
# 229
# Actual    :	 चूसती होगी
# Prediction:	 चूसती थीं
# 0.5833333333333334
#
# 230
# Actual    :	 फूँका है
# Prediction:	 फूँकिया ह
# 0.5
#
# 231
# Actual    :	 चमकी होती
# Prediction:	 चमक रही हो
# 0.45454545454545453
#
# 232
# Actual    :	 चोरी करती हैं
# Prediction:	 चोरी करती हैं
# 1.0
#
# 233
# Actual    :	 पका रही हूँ
# Prediction:	 पका रही है
# 0.7692307692307693
#
# 234
# Actual    :	 दोहरा रही होंगी
# Prediction:	 दोहरा रही थीं
# 0.7058823529411765
#
# 235
# Actual    :	 तैरी होती
# Prediction:	 तैरी हैं
# 0.6363636363636364
#
# 236
# Actual    :	 उठाी थीं
# Prediction:	 उठाई थीं
# 0.9
#
# 237
# Actual    :	 सहमाती होगी
# Prediction:	 सहमाती थी
# 0.6153846153846154
#
# 238
# Actual    :	 सुधार किया हो
# Prediction:	 सुधार किया हो
# 1.0
#
# 239
# Actual    :	 निभाई होती
# Prediction:	 निकाई है
# 0.5833333333333334
#
# 240
# Actual    :	 उबलती होंगी
# Prediction:	 उबलती थीं
# 0.6153846153846154
#
# 241
# Actual    :	 ये बनेंगी
# Prediction:	 बन रेंगी
# 0.18181818181818182
#
# 242
# Actual    :	 चुसे होते
# Prediction:	 चुसे होते
# 1.0
#
# 243
# Actual    :	 हटती होंगी
# Prediction:	 तुम रही हों
# 0.16666666666666666
#
# 244
# Actual    :	 डलवाए हो
# Prediction:	 डलवाए हो
# 1.0
#
# 245
# Actual    :	 हग रही हूँ
# Prediction:	 हगती हूँ
# 0.25
#
# 246
# Actual    :	 मरोड़ रही हैं
# Prediction:	 मरोड़ रही हैं
# 1.0
#
# 247
# Actual    :	 अंगारा बन रही हो
# Prediction:	 अंगारा बनती हो
# 0.5555555555555556
#
# 248
# Actual    :	 भुन रहे हैं
# Prediction:	 भुन रहे हैं
# 1.0
#
# 249
# Actual    :	 बैठता हूँ
# Prediction:	 बैठता हैता
# 0.7272727272727273
#
# 250
# Actual    :	 भुने होते
# Prediction:	 भुने होते
# 1.0
#
# 251
# Actual    :	 मरती हों
# Prediction:	 मरती हों
# 1.0
#
# 252
# Actual    :	 घृणा कर रहे थे
# Prediction:	 घृणा करते थे
# 0.5
#
# 253
# Actual    :	 चलाई हों
# Prediction:	 चलाई हों
# 1.0
#
# 254
# Actual    :	 सुनाओ
# Prediction:	 यननानी
# 0.375
#
# 255
# Actual    :	 आराम करती होती
# Prediction:	 आराम करती हो
# 0.8125
#
# 256
# Actual    :	 झाँका था
# Prediction:	 झाँका था
# 1.0
#
# 257
# Actual    :	 चुराे
# Prediction:	 ये चाने
# 0.125
#
# 258
# Actual    :	 उलटी किया हो
# Prediction:	 उलट किया हो
# 0.2857142857142857
#
# 259
# Actual    :	 घूमती हूँ
# Prediction:	 घूम रही हू
# 0.36363636363636365
#
# 260
# Actual    :	 विश्लेषण कियी होगी
# Prediction:	 विश्लेषण करे होगी
# 0.55
#
# 261
# Actual    :	 याद करते होते
# Prediction:	 याद कर रहे होत
# 0.4666666666666667
#
# 262
# Actual    :	 सहमा रही होती
# Prediction:	 सहमाती होती
# 0.3333333333333333
#
# 263
# Actual    :	 साफ़ किये हों
# Prediction:	 साफ़ किये हों
# 1.0
#
# 264
# Actual    :	 रोई हो
# Prediction:	 रो रही
# 0.5
#
# 265
# Actual    :	 लाती होगी
# Prediction:	 लाती थीं
# 0.5454545454545454
#
# 266
# Actual    :	 अपलोड कर रही होगी
# Prediction:	 अपलोड करती थीं
# 0.47368421052631576
#
# 267
# Actual    :	 तौबा करती होती
# Prediction:	 तौबा करती होती
# 1.0
#
# 268
# Actual    :	 दोहराई होती
# Prediction:	 दोहराई हो
# 0.7692307692307693
#
# 269
# Actual    :	 पहन रही हूँगी
# Prediction:	 पहन रही हूँगी
# 1.0
#
# 270
# Actual    :	 घुस रही होगी
# Prediction:	 घुसती थीं
# 0.2857142857142857
#
# 271
# Actual    :	 आराम कियी हूँ
# Prediction:	 आराम कियी हूँ
# 1.0
#
# 272
# Actual    :	 फिसलते होंगे
# Prediction:	 फिसलते थे
# 0.5714285714285714
#
# 273
# Actual    :	 लौटी थी
# Prediction:	 लौटी थी
# 1.0
#
# 274
# Actual    :	 गान की
# Prediction:	 यागायी
# 0.4
#
# 275
# Actual    :	 खाँसती होगी
# Prediction:	 खाँसती थी
# 0.6153846153846154
#
# 276
# Actual    :	 मर रहे हैं
# Prediction:	 हम रहे हो
# 0.5833333333333334
#
# 277
# Actual    :	 पूछना
# Prediction:	 पूछी
# 0.5714285714285714
#
# 278
# Actual    :	 नशा कर रहा होगा
# Prediction:	 नशा कर रहा होगा
# 1.0
#
# 279
# Actual    :	 सामने आ रही होगी
# Prediction:	 सामनेम आ रही थी
# 0.3333333333333333
#
# 280
# Actual    :	 झूठ बोली होती
# Prediction:	 झूठी को
# 0.26666666666666666
#
# 281
# Actual    :	 सहमा रही थी
# Prediction:	 सहमाती थी
# 0.38461538461538464
#
# 282
# Actual    :	 फूटे हैं
# Prediction:	 फूट रहे ह
# 0.5
#
# 283
# Actual    :	 खो रही होगी
# Prediction:	 खो रही होगी
# 1.0
#
# 284
# Actual    :	 ये ना करेंगी
# Prediction:	 ना करते
# 0.14285714285714285
#
# 285
# Actual    :	 पा रहा होगा
# Prediction:	 पा रहा होगा
# 1.0
#
# 286
# Actual    :	 डूबते होते
# Prediction:	 डूबते होते
# 1.0
#
# 287
# Actual    :	 टेंटुआ दबा रही होती
# Prediction:	 टेंटुआ दबा रही होती
# 1.0
#
# 288
# Actual    :	 उलटी कर रहे थे
# Prediction:	 उललत करते थे
# 0.375
#
# 289
# Actual    :	 फूटा हूँ
# Prediction:	 फूट ा हूँ
# 0.4
#
# 290
# Actual    :	 झाँकी होती
# Prediction:	 झाँक रही हो
# 0.5
#
# 291
# Actual    :	 मैं उछलूँगा
# Prediction:	 उठली
# 0.07692307692307693
#
# 292
# Actual    :	 अंछर मार रही हों
# Prediction:	 अंछर मार रही हों
# 1.0
#
# 293
# Actual    :	 सुधार रहा था
# Prediction:	 सुधार करता था
# 0.5
#
# 294
# Actual    :	 जाना है
# Prediction:	 जाना है
# 1.0
#
# 295
# Actual    :	 ख़रीद रही थीं
# Prediction:	 ख़रीदती थीं
# 0.4
#
# 296
# Actual    :	 मरोड़ता हूँ
# Prediction:	 मरोड़ रहा हू
# 0.46153846153846156
#
# 297
# Actual    :	 उठ रहा हूँ
# Prediction:	 उठता हूँ
# 0.25
#
# 298
# Actual    :	 बचा रहे होते
# Prediction:	 बचा रहे होते
# 1.0
#
# 299
# Actual    :	 फैल रहे होगे
# Prediction:	 फैल रहे थे
# 0.6428571428571429
#
# 300
# Actual    :	 खड़ा करते हो
# Prediction:	 खड़ा करते हो
# 1.0
#
# 301
# Actual    :	 डाउनलोड करते हों
# Prediction:	 डाउनलोड करते हों
# 1.0
#
# 302
# Actual    :	 चूसा
# Prediction:	 चूसी
# 0.7142857142857143
#
# 303
# Actual    :	 कह रही हूँ
# Prediction:	 कहती हूँ
# 0.25
#
# 304
# Actual    :	 सिखाई होगी
# Prediction:	 सिखाई होगी
# 1.0
#
# 305
# Actual    :	 आग्रह करने
# Prediction:	 यहम गा
# 0.08333333333333333
#
# 306
# Actual    :	 डाउनलोड कर रहा हूँ
# Prediction:	 डाउनलोड कर रहा हूँ
# 1.0
#
# 307
# Actual    :	 सुधार कर रहा हो
# Prediction:	 सुधार करता हो
# 0.5294117647058824
#
# 308
# Actual    :	 चलाती है
# Prediction:	 चलाती है
# 1.0
#
# 309
# Actual    :	 ये छोड़ें
# Prediction:	 छुड़ोड़ो
# 0.36363636363636365
#
# 310
# Actual    :	 बना रही होती
# Prediction:	 बनाती होती
# 0.2857142857142857
#
# 311
# Actual    :	 तू पिटेगी
# Prediction:	 पिटी
# 0.09090909090909091
#
# 312
# Actual    :	 बर्दाश्त कर
# Prediction:	 ययायी
# 0.06666666666666667
#
# 313
# Actual    :	 तुम भौंको
# Prediction:	 भौंभुकं
# 0.18181818181818182
#
# 314
# Actual    :	 अपना पालक पनीर देख रही होंगी
# Prediction:	 अपना पालक पनीर देखती होंगी
# 0.6333333333333333
#
# 315
# Actual    :	 घुस करती हो
# Prediction:	 घुस करती हो
# 1.0
#
# 316
# Actual    :	 ख़तना करती थीं
# Prediction:	 ख़तना करती थीं
# 1.0
#
# 317
# Actual    :	 इलाज कर रही होगी
# Prediction:	 इलाज करती होगी
# 0.4444444444444444
#
# 318
# Actual    :	 डाउनलोड कियी थीं
# Prediction:	 डाउनलोड कियी थीं
# 1.0
#
# 319
# Actual    :	 गान कियी होती
# Prediction:	 गान कियी होती
# 1.0
#
# 320
# Actual    :	 रही होती
# Prediction:	 रही होती
# 1.0
#
# 321
# Actual    :	 सुना रहे हो
# Prediction:	 सुनाते है
# 0.38461538461538464
#
# 322
# Actual    :	 छुड़ा रही थीं
# Prediction:	 छुड़ा रही थीं
# 1.0
#
# 323
# Actual    :	 अपलोड करती थी
# Prediction:	 अपलोड करती थी
# 1.0
#
# 324
# Actual    :	 यह चूमे
# Prediction:	 चूमी
# 0.1111111111111111
#
# 325
# Actual    :	 छोड़ते होंगे
# Prediction:	 छोड़ रहे थे
# 0.35714285714285715
#
# 326
# Actual    :	 उड़ने
# Prediction:	 उने
# 0.2857142857142857
#
# 327
# Actual    :	 उड़ती हो
# Prediction:	 उड़ती हो
# 1.0
#
# 328
# Actual    :	 थाम रही हो
# Prediction:	 थामती हो
# 0.3333333333333333
#
# 329
# Actual    :	 बीती हो
# Prediction:	 बीत करे
# 0.4444444444444444
#
# 330
# Actual    :	 बिखरता हूँ
# Prediction:	 बिखरता हूँ
# 1.0
#
# 331
# Actual    :	 कसा हूँगा
# Prediction:	 कस रहा हूँ
# 0.36363636363636365
#
# 332
# Actual    :	 तरसती हों
# Prediction:	 तैरती हों
# 0.8181818181818182
#
# 333
# Actual    :	 छोड़ रहे होते
# Prediction:	 छोड़ रहे होते
# 1.0
#
# 334
# Actual    :	 कह रहे हो
# Prediction:	 कहते है
# 0.2727272727272727
#
# 335
# Actual    :	 सूखो
# Prediction:	 यना
# 0.14285714285714285
#
# 336
# Actual    :	 चोट करता हूँ
# Prediction:	 चोट कर रहा हू
# 0.5
#
# 337
# Actual    :	 पढ़ाते हैं
# Prediction:	 पढ़ाते हैं
# 1.0
#
# 338
# Actual    :	 आश्चर्य किये हो
# Prediction:	 आश्चर्य किये है
# 0.9411764705882353
#
# 339
# Actual    :	 छोड़ रही थी
# Prediction:	 छोड़ रही थी
# 1.0
#
# 340
# Actual    :	 खाँसता होगा
# Prediction:	 खाँसता था
# 0.6153846153846154
#
# 341
# Actual    :	 हम छापएंगी
# Prediction:	 छापने
# 0.08333333333333333
#
# 342
# Actual    :	 उछलते होंगे
# Prediction:	 उछलते थे
# 0.5384615384615384
#
# 343
# Actual    :	 फूँक रहा हो
# Prediction:	 फूँक रहा हो
# 1.0
#
# 344
# Actual    :	 अंछर मारई थीं
# Prediction:	 अंछर मारई थीं
# 1.0
#
# 345
# Actual    :	 मरोड़ा हूँगा
# Prediction:	 मरोड़ा हूँगा
# 1.0
#
# 346
# Actual    :	 इलाज किये हो
# Prediction:	 इलाज किये हो
# 1.0
#
# 347
# Actual    :	 कूटे होते
# Prediction:	 कूटे होते
# 1.0
#
# 348
# Actual    :	 बची हूँ
# Prediction:	 चबी हूँ
# 0.7777777777777778
#
# 349
# Actual    :	 आग्रह कर रही है
# Prediction:	 आग्रह करती है
# 0.5294117647058824
#
# 350
# Actual    :	 प्रेम करते थे
# Prediction:	 प्रेम करते थे
# 1.0
#
# 351
# Actual    :	 उड़ा रहा था
# Prediction:	 उड़ा रहा था
# 1.0
#
# 352
# Actual    :	 पकया होगा
# Prediction:	 पक रहा होग
# 0.2727272727272727
#
# 353
# Actual    :	 नहाई होती
# Prediction:	 नाही हैं
# 0.36363636363636365
#
# 354
# Actual    :	 उड़ रहा होता
# Prediction:	 उड़ रहा होता
# 1.0
#
# 355
# Actual    :	 पिट रहा था
# Prediction:	 पिट रहा था
# 1.0
#
# 356
# Actual    :	 रो रहे हो
# Prediction:	 रो रहे हो
# 1.0
#
# 357
# Actual    :	 पकई होगी
# Prediction:	 पकी थीं
# 0.4
#
# 358
# Actual    :	 मैं छीनूँ
# Prediction:	 छीनी
# 0.09090909090909091
#
# 359
# Actual    :	 उतारे हो
# Prediction:	 उतार  हो
# 0.9
#
# 360
# Actual    :	 चुम्बन किये थे
# Prediction:	 चुम्बन किये थे
# 1.0
#
# 361
# Actual    :	 तुम लू करोगी
# Prediction:	 लू करूं
# 0.14285714285714285
#
# 362
# Actual    :	 पलट रही हूँ
# Prediction:	 पलट रही हूँ
# 1.0
#
# 363
# Actual    :	 घुस करती होंगी
# Prediction:	 घुस करती होंगी
# 1.0
#
# 364
# Actual    :	 भौंह चढ़ाए होते
# Prediction:	 भौंह चढ़ाए होते
# 1.0
#
# 365
# Actual    :	 ये बांधएं
# Prediction:	 ये बांधओ
# 0.7272727272727273
#
# 366
# Actual    :	 पड़े हों
# Prediction:	 पड़े हों
# 1.0
#
# 367
# Actual    :	 नफ़रत कर रहे थे
# Prediction:	 नफ़रत करते थे
# 0.5294117647058824
#
# 368
# Actual    :	 ये मिटेंगी
# Prediction:	 ये मिटेंगे
# 0.9166666666666666
#
# 369
# Actual    :	 गिरफ़्तार कर रहा होता
# Prediction:	 गिरफ़्तार करता हूँ
# 0.5652173913043478
#
# 370
# Actual    :	 ख़रीदी थी
# Prediction:	 ख़री कियी
# 0.6363636363636364
#
# 371
# Actual    :	 बिलबिलाई हूँ
# Prediction:	 बिलबिलाई हूँ
# 1.0
#
# 372
# Actual    :	 अंगारे उगलए हैं
# Prediction:	 अंगारे बरसे हैं
# 0.7647058823529411
#
# 373
# Actual    :	 सुस्ताता होगा
# Prediction:	 सुस्ताता होगा
# 1.0
#
# 374
# Actual    :	 अंगारा होई हों
# Prediction:	 अंगारा होए हों
# 0.9375
#
# 375
# Actual    :	 छोड़ रहे होगे
# Prediction:	 छोड़ रहे थे
# 0.6666666666666666
#
# 376
# Actual    :	 कह रहा होता
# Prediction:	 कहता हूँ
# 0.23076923076923078
#
# 377
# Actual    :	 पक रही है
# Prediction:	 पकती है
# 0.2727272727272727
#
# 378
# Actual    :	 ये सहमाएं
# Prediction:	 सम समथाने
# 0.45454545454545453
#
# 379
# Actual    :	 बिक रही हों
# Prediction:	 बिकती हों
# 0.3076923076923077
#
# 380
# Actual    :	 झूमी थीं
# Prediction:	 झूमी थीं
# 1.0
#
# 381
# Actual    :	 बिखरती होगी
# Prediction:	 बिखती थी
# 0.3076923076923077
#
# 382
# Actual    :	 जाई होती
# Prediction:	 जाई है
# 0.6
#
# 383
# Actual    :	 तरस रही थी
# Prediction:	 तरती थी
# 0.3333333333333333
#
# 384
# Actual    :	 पढ़ाता
# Prediction:	 यढ़ायी
# 0.625
#
# 385
# Actual    :	 तैरते होंगे
# Prediction:	 तैरते थे
# 0.5384615384615384
#
# 386
# Actual    :	 आरम्भ किया है
# Prediction:	 आरम्भ किया है
# 1.0
#
# 387
# Actual    :	 हिलती होंगी
# Prediction:	 लिलती थीं
# 0.5384615384615384
#
# 388
# Actual    :	 इनकार करते होते
# Prediction:	 इनकार कर रहे हो
# 0.5882352941176471
#
# 389
# Actual    :	 चाटती होती
# Prediction:	 चाटती होती
# 1.0
#
# 390
# Actual    :	 पिट रही हो
# Prediction:	 पिट रही हो
# 1.0
#
# 391
# Actual    :	 अंगारा बनने
# Prediction:	 यययांगा
# 0.15384615384615385
#
# 392
# Actual    :	 हिलते होंगे
# Prediction:	 हिलते थे
# 0.5384615384615384
#
# 393
# Actual    :	 झाँकते हो
# Prediction:	 झात करते ह
# 0.2727272727272727
#
# 394
# Actual    :	 चूसता होता
# Prediction:	 चूसता होता
# 1.0
#
# 395
# Actual    :	 झांकती
# Prediction:	 येमायी
# 0.375
#
# 396
# Actual    :	 रह रहा है
# Prediction:	 रह रहा है
# 1.0
#
# 397
# Actual    :	 इंतज़ार कियी हैं
# Prediction:	 इंतज़ार करे हैं
# 0.5555555555555556
#
# 398
# Actual    :	 इंतज़ार करता है
# Prediction:	 इस्तजार करता है
# 0.7647058823529411
#
# 399
# Actual    :	 ठीक कर रही होंगी
# Prediction:	 ठीक कर रही होंगी
# 1.0
#
# 400
# Actual    :	 हस्तमैथुन कियी होगी
# Prediction:	 हम्तमैथुन कियी होगी
# 0.9523809523809523
#
# 401
# Actual    :	 हम चुसें
# Prediction:	 तुम चुसें
# 0.1
#
# 402
# Actual    :	 फैल रहे हो
# Prediction:	 फैल रहे है
# 0.9166666666666666
#
# 403
# Actual    :	 टपक रहे थे
# Prediction:	 टपक रहे थे
# 1.0
#
# 404
# Actual    :	 पढ़ा था
# Prediction:	 पढ़ रहा
# 0.5555555555555556
#
# 405
# Actual    :	 बर्दाश्त कर रही होगी
# Prediction:	 बर्दाश्त करती होगी
# 0.5454545454545454
#
# 406
# Actual    :	 तू चुनेगी
# Prediction:	 चुना
# 0.09090909090909091
#
# 407
# Actual    :	 ऐश कियी होती
# Prediction:	 ऐश कियी होती
# 1.0
#
# 408
# Actual    :	 लौटता हूँगा
# Prediction:	 लौटता हूँगा
# 1.0
#
# 409
# Actual    :	 बिकता होता
# Prediction:	 बिकता होता
# 1.0
#
# 410
# Actual    :	 काटती हूँगी
# Prediction:	 काटती हूँगी
# 1.0
#
# 411
# Actual    :	 उठा रहे थे
# Prediction:	 उठा रहे थे
# 1.0
#
# 412
# Actual    :	 त्याग रहे होंगे
# Prediction:	 त्यागते होंगे
# 0.35294117647058826
#
# 413
# Actual    :	 बाँधती थी
# Prediction:	 बाँध रही थ
# 0.45454545454545453
#
# 414
# Actual    :	 हम अपलोड करेंगे
# Prediction:	 अपलोड करोड
# 0.058823529411764705
#
# 415
# Actual    :	 मैं खोलूँगी
# Prediction:	 खोलो
# 0.07692307692307693
#
# 416
# Actual    :	 यह तरसे
# Prediction:	 तैर थी
# 0.1111111111111111
#
# 417
# Actual    :	 प्राप्त कियी होती
# Prediction:	 प्राप्त कियी होती
# 1.0
#
# 418
# Actual    :	 छीपता हूँ
# Prediction:	 छीपता हूँ
# 1.0
#
# 419
# Actual    :	 अंगारा हो जाता है
# Prediction:	 अंगारा होता है
# 0.5263157894736842
#
# 420
# Actual    :	 पूछ रहा हूँ
# Prediction:	 पूछ रहा हूँ
# 1.0
#
# 421
# Actual    :	 छिपा रही है
# Prediction:	 छिपाती है
# 0.38461538461538464
#
# 422
# Actual    :	 पी रही हूँ
# Prediction:	 पीटती हूँ
# 0.25
#
# 423
# Actual    :	 रुकया था
# Prediction:	 रुक रहा थ
# 0.4
#
# 424
# Actual    :	 सड़ती होंगी
# Prediction:	 सड़ रही होंग
# 0.3076923076923077
#
# 425
# Actual    :	 सहमा रही होती
# Prediction:	 सहमाती है
# 0.3333333333333333
#
# 426
# Actual    :	 जमी होती
# Prediction:	 जमी होती
# 1.0
#
# 427
# Actual    :	 इलाज करता है
# Prediction:	 इलाज करता है
# 1.0
#
# 428
# Actual    :	 छील रही हो
# Prediction:	 छीलती हो
# 0.3333333333333333
#
# 429
# Actual    :	 रौशन कर रही हो
# Prediction:	 रौशन करती हो
# 0.5
#
# 430
# Actual    :	 चलता होगा
# Prediction:	 चलता होगा
# 1.0
#
# 431
# Actual    :	 पहुँच
# Prediction:	 पही
# 0.3333333333333333
#
# 432
# Actual    :	 डूबता होगा
# Prediction:	 डूबता होगा
# 1.0
#
# 433
# Actual    :	 छींकते थे
# Prediction:	 छींकते थे
# 1.0
#
# 434
# Actual    :	 जोड़ई होती
# Prediction:	 जोड़ी होती
# 0.9166666666666666
#
# 435
# Actual    :	 दिलाई होती
# Prediction:	 दिलाई है
# 0.6666666666666666
#
# 436
# Actual    :	 खोलती थीं
# Prediction:	 खोलती थीं
# 1.0
#
# 437
# Actual    :	 छीपी थीं
# Prediction:	 छीी थीं
# 0.3
#
# 438
# Actual    :	 चोरी किया हूँ
# Prediction:	 चोरी किया हूँ
# 1.0
#
# 439
# Actual    :	 बन्द कर रही हूँगी
# Prediction:	 बन्द करती हूँगी
# 0.42105263157894735
#
# 440
# Actual    :	 खोजते
# Prediction:	 ययी
# 0.14285714285714285
#
# 441
# Actual    :	 उड़ती हो
# Prediction:	 उड़ रही ह
# 0.4
#
# 442
# Actual    :	 रोकता था
# Prediction:	 रोकता था
# 1.0
#
# 443
# Actual    :	 ये सेक्स करेंगे
# Prediction:	 ये सेक्स करेंगे
# 1.0
#
# 444
# Actual    :	 हंस रहे होंगे
# Prediction:	 हंसते होंगे
# 0.26666666666666666
#
# 445
# Actual    :	 पहुँच रहे हैं
# Prediction:	 पहमचते हैं
# 0.26666666666666666
#
# 446
# Actual    :	 भेज रहा होगा
# Prediction:	 भुन रहा होगा
# 0.8571428571428571
#
# 447
# Actual    :	 चुने हैं
# Prediction:	 चुन रहे ह
# 0.5
#
# 448
# Actual    :	 पलटती होती
# Prediction:	 पलटती होती
# 1.0
#
# 449
# Actual    :	 नशा करता था
# Prediction:	 नशा करता था
# 1.0
#
# 450
# Actual    :	 पिघला हो
# Prediction:	 पिसल किया
# 0.4
#
# 451
# Actual    :	 भूलता हो
# Prediction:	 भूलता हो
# 1.0
#
# 452
# Actual    :	 अंगारा हो रहा होता
# Prediction:	 अंगारा होता होता
# 0.5
#
# 453
# Actual    :	 जलाती होंगी
# Prediction:	 जला रही थीं
# 0.38461538461538464
#
# 454
# Actual    :	 लड़ती होती
# Prediction:	 लड़ती होती
# 1.0
#
# 455
# Actual    :	 याद कर रहे हैं
# Prediction:	 याद करते हैं
# 0.4375
#
# 456
# Actual    :	 कमाती हूँ
# Prediction:	 कमाती हूँ
# 1.0
#
# 457
# Actual    :	 साफ़ किये थे
# Prediction:	 साफ़ किये थे
# 1.0
#
# 458
# Actual    :	 मिला रहा था
# Prediction:	 मिलाता था
# 0.38461538461538464
#
# 459
# Actual    :	 पढ़ती हो
# Prediction:	 पढ़ रही ह
# 0.4
#
# 460
# Actual    :	 प्रारम्भ करती होती
# Prediction:	 प्रारम्भ करती होती
# 1.0
#
# 461
# Actual    :	 बटोरी है
# Prediction:	 बटोर है
# 0.5
#
# 462
# Actual    :	 भागई थीं
# Prediction:	 भाग रही थ
# 0.5
#
# 463
# Actual    :	 अंगारा हो रही होगी
# Prediction:	 अंगारा हो रही थी
# 0.75
#
# 464
# Actual    :	 तू झांकेगी
# Prediction:	 झांकी
# 0.08333333333333333
#
# 465
# Actual    :	 दिलाता हूँ
# Prediction:	 दिला ा हैँ
# 0.8333333333333334
#
# 466
# Actual    :	 सड़ता होगा
# Prediction:	 सड़ रहा होग
# 0.3333333333333333
#
# 467
# Actual    :	 नफ़रत करती थी
# Prediction:	 तौशनत करती थी
# 0.7333333333333333
#
# 468
# Actual    :	 रोने
# Prediction:	 यीर
# 0.16666666666666666
#
# 469
# Actual    :	 जमा करती होगी
# Prediction:	 जमा करती होगी
# 1.0
#
# 470
# Actual    :	 बकई होंगी
# Prediction:	 बन रही हों
# 0.2727272727272727
#
# 471
# Actual    :	 चूसते होते
# Prediction:	 चूसते होते
# 1.0
#
# 472
# Actual    :	 अपना पालक पनीर देखती हो
# Prediction:	 अपना पालक पनीर देखती हो
# 1.0
#
# 473
# Actual    :	 सूज रहे होगे
# Prediction:	 सूखते थे
# 0.21428571428571427
#
# 474
# Actual    :	 हटी होंगी
# Prediction:	 हटी होंगी
# 1.0
#
# 475
# Actual    :	 शुक्रिया कर रहा हूँ
# Prediction:	 शुक्रिया करता हूँ
# 0.5714285714285714
#
# 476
# Actual    :	 चमकता हो
# Prediction:	 चमकता हो
# 1.0
#
# 477
# Actual    :	 चोद रही हो
# Prediction:	 चोदती है
# 0.3333333333333333
#
# 478
# Actual    :	 निखारता था
# Prediction:	 निकाता था
# 0.3333333333333333
#
# 479
# Actual    :	 हग रहे थे
# Prediction:	 हग रहे थे
# 1.0
#
# 480
# Actual    :	 भौंकती हो
# Prediction:	 भौंकती हो
# 1.0
#
# 481
# Actual    :	 तुम छींकओगी
# Prediction:	 छेंी
# 0.07692307692307693
#
# 482
# Actual    :	 संभोग कियी थी
# Prediction:	 संभोग कियी थी
# 1.0
#
# 483
# Actual    :	 इस्तेमाल कर रहा है
# Prediction:	 इस्तेमाल करता है
# 0.6
#
# 484
# Actual    :	 लटक रही है
# Prediction:	 लूटती है
# 0.16666666666666666
#
# 485
# Actual    :	 भौंह चढ़ाती हो
# Prediction:	 भौंभौंचढ़ा रही
# 0.3125
#
# 486
# Actual    :	 गुणा कियी होगी
# Prediction:	 गुणा कियी होगी
# 1.0
#
# 487
# Actual    :	 ख़रीदते हैं
# Prediction:	 ख़रीदते हैं
# 1.0
#
# 488
# Actual    :	 उबल रहा हूँगा
# Prediction:	 उबलता हूँगा
# 0.26666666666666666
#
# 489
# Actual    :	 उलटी किया हूँ
# Prediction:	 उठली किया हूँ
# 0.8666666666666667
#
# 490
# Actual    :	 आराम करता होगा
# Prediction:	 आराम करता था
# 0.6875
#
# 491
# Actual    :	 पिघला था
# Prediction:	 पिघलत था
# 0.9
#
# 492
# Actual    :	 पीट रही है
# Prediction:	 पीट रही है
# 1.0
#
# 493
# Actual    :	 लूटता था
# Prediction:	 लूटता था
# 1.0
#
# 494
# Actual    :	 तू प्यार करेगी
# Prediction:	 यै प्या कर
# 0.375
#
# 495
# Actual    :	 बजाते होंगे
# Prediction:	 बजाते होंगे
# 1.0
#
# 496
# Actual    :	 प्रारम्भ करती होती
# Prediction:	 प्रारम्भ करती है
# 0.8
#
# 497
# Actual    :	 बांध रही हो
# Prediction:	 बांध रही हो
# 1.0
#
# 498
# Actual    :	 हंसी होती
# Prediction:	 हंसी होती
# 1.0
#
# 499
# Actual    :	 तौबा किया है
# Prediction:	 बैठा किया है
# 0.7857142857142857
#
# 500
# Actual    :	 बोलता है
# Prediction:	 बोल रहा ह
# 0.4
#
# 501
# Actual    :	 उबलता है
# Prediction:	 उबलता है
# 1.0
#
# 502
# Actual    :	 पिघल रहा था
# Prediction:	 पिघलता था
# 0.38461538461538464
#
# 503
# Actual    :	 छापया था
# Prediction:	 छापना था
# 0.9
#
# 504
# Actual    :	 हल चला रही होंगी
# Prediction:	 हल चला रही थीं
# 0.7222222222222222
#
# 505
# Actual    :	 बनाया होता
# Prediction:	 बनाया है
# 0.6666666666666666
#
# 506
# Actual    :	 भौंह चढ़ाई हैं
# Prediction:	 भौंह चढ़ा की
# 0.625
#
# 507
# Actual    :	 छीप रहे थे
# Prediction:	 छीप रहे थे
# 1.0
#
# 508
# Actual    :	 लूटी थीं
# Prediction:	 लूटी थीं
# 1.0
#
# 509
# Actual    :	 तरसता
# Prediction:	 ती
# 0.2857142857142857
#
# 510
# Actual    :	 ये टूटें
# Prediction:	 यूट टें
# 0.2
#
# 511
# Actual    :	 डलवा रहे थे
# Prediction:	 डलवा रहे थे
# 1.0
#
# 512
# Actual    :	 प्यार कर रहा था
# Prediction:	 प्यार करता था
# 0.5294117647058824
#
# 513
# Actual    :	 यह छीले
# Prediction:	 छीं ली
# 0.1111111111111111
#
# 514
# Actual    :	 हम रुकएं
# Prediction:	 तुम करे
# 0.1
#
# 515
# Actual    :	 ये डाउनलोड करें
# Prediction:	 डाउनलोड करो
# 0.058823529411764705
#
# 516
# Actual    :	 खड़ा करते हैं
# Prediction:	 खड़ा करते हैं
# 1.0
#
# 517
# Actual    :	 पक रहा हूँ
# Prediction:	 पक रहा हूँ
# 1.0
#
# 518
# Actual    :	 ये छुड़ाएंगी
# Prediction:	 यु छुड़ाएंगी
# 0.9285714285714286
#
# 519
# Actual    :	 पिघली थी
# Prediction:	 पिपसी पी
# 0.6
#
# 520
# Actual    :	 सुनाई हैं
# Prediction:	 सुनाई हैं
# 1.0
#
# 521
# Actual    :	 बाटया हो
# Prediction:	 बाटा हो
# 0.4
#
# 522
# Actual    :	 सूंघती थी
# Prediction:	 सूंघ रही थ
# 0.45454545454545453
#
# 523
# Actual    :	 पकाता हो
# Prediction:	 पका रहा ह
# 0.4
#
# 524
# Actual    :	 लगती थीं
# Prediction:	 लग रही थी
# 0.3
#
# 525
# Actual    :	 जमा हूँगा
# Prediction:	 जम ा हूँगा
# 0.2727272727272727
#
# 526
# Actual    :	 बक रही होती
# Prediction:	 बन रही होती
# 0.9230769230769231
#
# 527
# Actual    :	 खोजती हैं
# Prediction:	 खोती हैं
# 0.2727272727272727
#
# 528
# Actual    :	 शिकार कियी होगी
# Prediction:	 शिकार कियी होगी
# 1.0
#
# 529
# Actual    :	 चुसते होते
# Prediction:	 चुसते होते
# 1.0
#
# 530
# Actual    :	 आदर किया हो
# Prediction:	 आदर किया हो
# 1.0
#
# 531
# Actual    :	 रखना
# Prediction:	 यीने
# 0.5
#
# 532
# Actual    :	 प्रारम्भ करो
# Prediction:	 यामामतमैमाये
# 0.2
#
# 533
# Actual    :	 हगते हैं
# Prediction:	 हगते है
# 0.8
#
# 534
# Actual    :	 बेच रहे हों
# Prediction:	 बेचते हों
# 0.3076923076923077
#
# 535
# Actual    :	 जाती थी
# Prediction:	 जाती थी
# 1.0
#
# 536
# Actual    :	 ख़रीद रहा हूँगा
# Prediction:	 ख़रीद रहा हूँगा
# 1.0
#
# 537
# Actual    :	 घुमाती हूँ
# Prediction:	 घुमा रही है
# 0.4166666666666667
#
# 538
# Actual    :	 पढ़ाई होंगी
# Prediction:	 पढ़ाई थीं
# 0.6153846153846154
#
# 539
# Actual    :	 घुस कियी थीं
# Prediction:	 घुस कियी थीं
# 1.0
#
# 540
# Actual    :	 छेड़ रहे होगे
# Prediction:	 छेड़ रहे थे
# 0.6666666666666666
#
# 541
# Actual    :	 झगड़ रही हो
# Prediction:	 झगड़ रही हो
# 1.0
#
# 542
# Actual    :	 ठगा होगा
# Prediction:	 उठा होगा
# 0.8
#
# 543
# Actual    :	 बाट रहे होते
# Prediction:	 बाटते हो
# 0.2857142857142857
#
# 544
# Actual    :	 अंगारा हो जाता
# Prediction:	 यहमायायायया
# 0.1875
#
# 545
# Actual    :	 विश्लेषण कियी होगी
# Prediction:	 विश्लेषण कर रही होग
# 0.55
#
# 546
# Actual    :	 खोती होती
# Prediction:	 खोती होती
# 1.0
#
# 547
# Actual    :	 बनती हूँ
# Prediction:	 बनती हूँ
# 1.0
#
# 548
# Actual    :	 चमकती हूँगी
# Prediction:	 चमकती थी
# 0.5384615384615384
#
# 549
# Actual    :	 बचाते थे
# Prediction:	 बचा रहे थ
# 0.4
#
# 550
# Actual    :	 कुरेदते होगे
# Prediction:	 कुरेदते थे
# 0.6428571428571429
#
# 551
# Actual    :	 झूठ बोलती थीं
# Prediction:	 झूठ बोलती थीं
# 1.0
#
# 552
# Actual    :	 नागरिक बनाई होती
# Prediction:	 अनगरिक बनाई है
# 0.6666666666666666
#
# 553
# Actual    :	 मुड़ी होंगी
# Prediction:	 मुड़ी थीं
# 0.6153846153846154
#
# 554
# Actual    :	 पसीजते होगे
# Prediction:	 पसीजते थे
# 0.6153846153846154
#
# 555
# Actual    :	 मक्खन लगाती होती
# Prediction:	 मक्खन करती हैं
# 0.3888888888888889
#
# 556
# Actual    :	 प्यार करते हो
# Prediction:	 प्यार करते हो
# 1.0
#
# 557
# Actual    :	 बाट रही थी
# Prediction:	 बाटती थी
# 0.3333333333333333
#
# 558
# Actual    :	 जान रही थी
# Prediction:	 जानती थी
# 0.3333333333333333
#
# 559
# Actual    :	 अंगारा होए होते
# Prediction:	 अंगारा होए होते
# 1.0
#
# 560
# Actual    :	 दोहरा रही थी
# Prediction:	 दोहरा ी थी
# 0.5
#
# 561
# Actual    :	 भूलती होंगी
# Prediction:	 भूलती थीं
# 0.6153846153846154
#
# 562
# Actual    :	 लूटी होती
# Prediction:	 लूटी होती
# 1.0
#
# 563
# Actual    :	 तुम बनाओगी
# Prediction:	 बन बनाएंगी
# 0.3333333333333333
#
# 564
# Actual    :	 ठीक किये हैं
# Prediction:	 ठीक किये हैं
# 1.0
#
# 565
# Actual    :	 खोती हो
# Prediction:	 खोती है
# 0.8888888888888888
#
# 566
# Actual    :	 लगी थी
# Prediction:	 लग रही
# 0.5
#
# 567
# Actual    :	 चिल्लाई थीं
# Prediction:	 चिल्ला थीं
# 0.5384615384615384
#
# 568
# Actual    :	 मिटती थी
# Prediction:	 मिटता थी
# 0.9
#
# 569
# Actual    :	 सुस्ताता था
# Prediction:	 सुस्ताता था
# 1.0
#
# 570
# Actual    :	 नशा करती थी
# Prediction:	 नशा करती थी
# 1.0
#
# 571
# Actual    :	 चुके होंगे
# Prediction:	 चुके होंगे
# 1.0
#
# 572
# Actual    :	 बजाई होगी
# Prediction:	 बजाई थी
# 0.5454545454545454
#
# 573
# Actual    :	 पूछी थी
# Prediction:	 पूछी थी
# 1.0
#
# 574
# Actual    :	 नागरिक बनाती होती
# Prediction:	 नागरिक बनती होती
# 0.5263157894736842
#
# 575
# Actual    :	 स्वप्न देखती हों
# Prediction:	 स्वप्न देखती हों
# 1.0
#
# 576
# Actual    :	 प्रारम्भ कर रहा होता
# Prediction:	 प्रारम्भ करता है
# 0.5454545454545454
#
# 577
# Actual    :	 पलटी होती
# Prediction:	 पलटी होती
# 1.0
#
# 578
# Actual    :	 बाँधते हों
# Prediction:	 बाँधते हों
# 1.0
#
# 579
# Actual    :	 सीख रहे होते
# Prediction:	 सीखते होते
# 0.2857142857142857
#
# 580
# Actual    :	 चूस रहे होंगे
# Prediction:	 चूसते थे
# 0.26666666666666666
#
# 581
# Actual    :	 झाँकी है
# Prediction:	 झाँकी है
# 1.0
#
# 582
# Actual    :	 पीती हैं
# Prediction:	 पी रही है
# 0.3
#
# 583
# Actual    :	 गिरफ़्तार करती थी
# Prediction:	 गिरफ़्रा करती थी
# 0.42105263157894735
#
# 584
# Actual    :	 मतलब हो रही है
# Prediction:	 मतलब हो रही है
# 1.0
#
# 585
# Actual    :	 इंतज़ार कर रही हो
# Prediction:	 इसतज़ार करती हो
# 0.5263157894736842
#
# 586
# Actual    :	 तैयार कर रही थीं
# Prediction:	 तैयार कर रही थीं
# 1.0
#
# 587
# Actual    :	 यह फिसले
# Prediction:	 फिसली
# 0.1
#
# 588
# Actual    :	 पढ़ाते थे
# Prediction:	 पढ़ा रते थ
# 0.45454545454545453
#
# 589
# Actual    :	 झुक रही हूँ
# Prediction:	 झुक रही हो
# 0.7692307692307693
#
# 590
# Actual    :	 पहचाने हैं
# Prediction:	 पहचाने हैं
# 1.0
#
# 591
# Actual    :	 प्राप्त कर रही हों
# Prediction:	 प्रयात करती हों
# 0.25
#
# 592
# Actual    :	 पढ़ता था
# Prediction:	 पढ़ रहा थ
# 0.4
#
# 593
# Actual    :	 लटकी थीं
# Prediction:	 लटक रही थ
# 0.5
#
# 594
# Actual    :	 खड़ा करता था
# Prediction:	 खड़ा करता था
# 1.0
#
# 595
# Actual    :	 ख़तना कर रहे थे
# Prediction:	 ख़तना कर रहे थे
# 1.0
#
# 596
# Actual    :	 निकल रहा होता
# Prediction:	 निकल रहा हूँ
# 0.7333333333333333
#
# 597
# Actual    :	 तैराते होते
# Prediction:	 तैरा रहे होत
# 0.38461538461538464
#
# 598
# Actual    :	 छोड़ती है
# Prediction:	 छोड़ती है
# 1.0
#
# 599
# Actual    :	 दोहरा रही हूँ
# Prediction:	 दोंहाती है
# 0.26666666666666666
#
# 600
# Actual    :	 इंतज़ार कर रही होंगी
# Prediction:	 इमरफ़ जरत कर रही होंग
# 0.18181818181818182
#
# 601
# Actual    :	 रौशन करता होगा
# Prediction:	 रौशन करता होगा
# 1.0
#
# 602
# Actual    :	 खेली
# Prediction:	 ये दे
# 0.2857142857142857
#
# 603
# Actual    :	 बचा रही हो
# Prediction:	 बचाती हो
# 0.3333333333333333
#
# 604
# Actual    :	 त्याग रहे होगे
# Prediction:	 त्यागते होगे
# 0.375
#
# 605
# Actual    :	 टेंटुआ दबाता होगा
# Prediction:	 टेंटुआ दबा रहा होग
# 0.5789473684210527
#
# 606
# Actual    :	 ये सीखेंगी
# Prediction:	 सीखती
# 0.16666666666666666
#
# 607
# Actual    :	 कहती थी
# Prediction:	 कहती थी
# 1.0
#
# 608
# Actual    :	 अंगारे उगलती हूँ
# Prediction:	 अंगारा बरती हूँ
# 0.3888888888888889
#
# 609
# Actual    :	 दबाता हूँगा
# Prediction:	 दबा रहा हूँग
# 0.3076923076923077
#
# 610
# Actual    :	 तैराई हों
# Prediction:	 तैराई हों
# 1.0
#
# 611
# Actual    :	 बेच रही थी
# Prediction:	 बेचती थी
# 0.3333333333333333
#
# 612
# Actual    :	 तैरी हो
# Prediction:	 तैरी हो
# 1.0
#
# 613
# Actual    :	 मरोड़ने
# Prediction:	 मम मरमो
# 0.3333333333333333
#
# 614
# Actual    :	 यह ठगे
# Prediction:	 यह थुने
# 0.5
#
# 615
# Actual    :	 रखा हूँ
# Prediction:	 तू रहा ह
# 0.2222222222222222
#
# 616
# Actual    :	 लौट रहा था
# Prediction:	 लौटता होगा
# 0.5
#
# 617
# Actual    :	 रुकती होती
# Prediction:	 रुकरती होती
# 0.3333333333333333
#
# 618
# Actual    :	 रहते होगे
# Prediction:	 रह रहे थे
# 0.45454545454545453
#
# 619
# Actual    :	 तुम बिखरोगी
# Prediction:	 बिखतु
# 0.07692307692307693
#
# 620
# Actual    :	 हारी होंगी
# Prediction:	 हारी थीं
# 0.5833333333333334
#
# 621
# Actual    :	 आग्रह किये होंगे
# Prediction:	 आग्रह किये थे
# 0.6666666666666666
#
# 622
# Actual    :	 टेंटुआ दबाती होती
# Prediction:	 टेंटुआ दबा रही होत
# 0.5789473684210527
#
# 623
# Actual    :	 अपना पालक पनीर देखते होंगे
# Prediction:	 अपापा पला करनीर देखते होंगे
# 0.17857142857142858
#
# 624
# Actual    :	 धड़की
# Prediction:	 यें
# 0.125
#
# 625
# Actual    :	 उलटी करते होते
# Prediction:	 उलोल करते होते
# 0.875
#
# 626
# Actual    :	 टेंटुआ दबाई होती
# Prediction:	 टेंटुआ दबाई हैं
# 0.7777777777777778
#
# 627
# Actual    :	 छोड़ रहे हो
# Prediction:	 छोड़ रहे हो
# 1.0
#
# 628
# Actual    :	 अंछर मारए होंगे
# Prediction:	 अंछर मारए थे
# 0.6470588235294118
#
# 629
# Actual    :	 बचाते हों
# Prediction:	 बचबाते हों
# 0.2727272727272727
#
# 630
# Actual    :	 उतर रहा होता
# Prediction:	 उतरता होता
# 0.2857142857142857
#
# 631
# Actual    :	 जमा था
# Prediction:	 जमा था
# 1.0
#
# 632
# Actual    :	 ग़लत करते हैं
# Prediction:	 ग़लत करते हैं
# 1.0
#
# 633
# Actual    :	 सामने आती हों
# Prediction:	 सामनेम करती हो
# 0.4
#
# 634
# Actual    :	 ग़लत कर रही थीं
# Prediction:	 ग़लत करती होंगी
# 0.5294117647058824
#
# 635
# Actual    :	 अंगारा होती होंगी
# Prediction:	 अंगारा बनती थीं
# 0.631578947368421
#
# 636
# Actual    :	 जलाया हो
# Prediction:	 जलाया हो
# 1.0
#
# 637
# Actual    :	 कूटी होंगी
# Prediction:	 कूटी होंगी
# 1.0
#
# 638
# Actual    :	 ना कर रही हूँगी
# Prediction:	 ना कर रही थी
# 0.6470588235294118
#
# 639
# Actual    :	 निकल रही हैं
# Prediction:	 निकल रही हैं
# 1.0
#
# 640
# Actual    :	 खेली है
# Prediction:	 खेखी है
# 0.8888888888888888
#
# 641
# Actual    :	 यह सुधार करेगा
# Prediction:	 सुधार करती
# 0.125
#
# 642
# Actual    :	 बर्दाश्त करता होगा
# Prediction:	 बर्दाश्त करता था
# 0.75
#
# 643
# Actual    :	 समझी हैं
# Prediction:	 समझी हैं
# 1.0
#
# 644
# Actual    :	 माफ़ कर रहे हो
# Prediction:	 माफ़ करते हो
# 0.5
#
# 645
# Actual    :	 सड़ता हो
# Prediction:	 सड़ रहा ह
# 0.4
#
# 646
# Actual    :	 बात कियी हैं
# Prediction:	 बात कियी हैं
# 1.0
#
# 647
# Actual    :	 तुम विश्लेषण करोगे
# Prediction:	 हम विश्लेषण करेगे
# 0.05
#
# 648
# Actual    :	 मनाती हो
# Prediction:	 मनाती हो
# 1.0
#
# 649
# Actual    :	 बह रही हो
# Prediction:	 बह रही है
# 0.9090909090909091
#
# 650
# Actual    :	 चोरी कर रहा होता
# Prediction:	 चोरी करता हो
# 0.4444444444444444
#
# 651
# Actual    :	 कंघी करते हो
# Prediction:	 कंघी करते हो
# 1.0
#
# 652
# Actual    :	 यह मक्खन लगाए
# Prediction:	 कम  क्खतलगने
# 0.3333333333333333
#
# 653
# Actual    :	 अंगारों पर पैर रखती होती
# Prediction:	 अंगारा होती हूँ
# 0.23076923076923078
#
# 654
# Actual    :	 डाउनलोड करती होगी
# Prediction:	 डाउनलोड करती होगी
# 1.0
#
# 655
# Actual    :	 गान करता होता
# Prediction:	 गान करता हो
# 0.8
#
# 656
# Actual    :	 झूलती होती
# Prediction:	 झूलती होती
# 1.0
#
# 657
# Actual    :	 हंसे हैं
# Prediction:	 हंसे हैं
# 1.0
#
# 658
# Actual    :	 रखते थे
# Prediction:	 तरते थे
# 0.7777777777777778
#
# 659
# Actual    :	 पा रहे होते
# Prediction:	 पाते होते
# 0.23076923076923078
#
# 660
# Actual    :	 तुम मिलाओगी
# Prediction:	 मि लियाएंगी
# 0.3076923076923077
#
# 661
# Actual    :	 चढ़ाई है
# Prediction:	 चढ़ाई है
# 1.0
#
# 662
# Actual    :	 तैयार किया हो
# Prediction:	 तैरा किया हो
# 0.26666666666666666
#
# 663
# Actual    :	 तुम मक्खन लगाओ
# Prediction:	 मैं मैं कलखएगी
# 0.25
#
# 664
# Actual    :	 उड़ाया
# Prediction:	 याउड़ाय
# 0.25
#
# 665
# Actual    :	 सहायता कर रही हो
# Prediction:	 सहायता करती हो
# 0.5555555555555556
#
# 666
# Actual    :	 खेल रही हूँ
# Prediction:	 खेलती हूँ
# 0.3076923076923077
#
# 667
# Actual    :	 झूमती थीं
# Prediction:	 झूम रही थी
# 0.36363636363636365
#
# 668
# Actual    :	 नफ़रत कर रही होती
# Prediction:	 नफ़रत करती होती
# 0.47368421052631576
#
# 669
# Actual    :	 दबाई हैं
# Prediction:	 बाद हैं
# 0.1
#
# 670
# Actual    :	 प्रेम करते होते
# Prediction:	 प्रेम करते होते
# 1.0
#
# 671
# Actual    :	 याद कर रही थी
# Prediction:	 याद करती थी
# 0.4666666666666667
#
# 672
# Actual    :	 जाई हो
# Prediction:	 जाई हो
# 1.0
#
# 673
# Actual    :	 ये रचें
# Prediction:	 रचुम थीं
# 0.1111111111111111
#
# 674
# Actual    :	 रोका है
# Prediction:	 रो किया
# 0.3333333333333333
#
# 675
# Actual    :	 बहता था
# Prediction:	 बह रहा ह
# 0.3333333333333333
#
# 676
# Actual    :	 सुधार कर रही होगी
# Prediction:	 सुधार कर रही थी
# 0.7368421052631579
#
# 677
# Actual    :	 चुसी थीं
# Prediction:	 चुसी थीं
# 1.0
#
# 678
# Actual    :	 लू करता हूँ
# Prediction:	 लू करता हूँ
# 1.0
#
# 679
# Actual    :	 खड़ा कर रहे होंगे
# Prediction:	 खड़ा करते होंगे
# 0.42105263157894735
#
# 680
# Actual    :	 छोड़ती
# Prediction:	 ये छे
# 0.125
#
# 681
# Actual    :	 दिलाई हूँगी
# Prediction:	 दिलाई हूँगी
# 1.0
#
# 682
# Actual    :	 ठीक करती थीं
# Prediction:	 ठीक करती थीं
# 1.0
#
# 683
# Actual    :	 पलट रही हों
# Prediction:	 पलटती हों
# 0.3076923076923077
#
# 684
# Actual    :	 आरम्भ कर रहे थे
# Prediction:	 आेचर करते थे
# 0.17647058823529413
#
# 685
# Actual    :	 ऐसी तैसी करते हों
# Prediction:	 ऐसी तैसी करते हों
# 1.0
#
# 686
# Actual    :	 गिरफ़्तार कर रही होंगी
# Prediction:	 गिरफ़्तार करती होंगी
# 0.5416666666666666
#
# 687
# Actual    :	 सुधार कर रही थीं
# Prediction:	 सुधार कर रही थीं
# 1.0
#
# 688
# Actual    :	 चोट कियी हूँ
# Prediction:	 चोट कियी हूँ
# 1.0
#
# 689
# Actual    :	 पिघलती होती
# Prediction:	 पिघलती होती
# 1.0
#
# 690
# Actual    :	 फैल रही होती
# Prediction:	 फैलती होती
# 0.2857142857142857
#
# 691
# Actual    :	 झूठ बोला था
# Prediction:	 झूठलब किया थ
# 0.38461538461538464
#
# 692
# Actual    :	 नशा कर रहे होंगे
# Prediction:	 नशा कर रहे होंगे
# 1.0
#
# 693
# Actual    :	 निर्माण कर रही है
# Prediction:	 निक्राम करती है
# 0.42105263157894735
#
# 694
# Actual    :	 चाह रहे हों
# Prediction:	 चाह रहे हों
# 1.0
#
# 695
# Actual    :	 मिटी थीं
# Prediction:	 मिट रही थ
# 0.5
#
# 696
# Actual    :	 मिला रहा है
# Prediction:	 मिला रहा है
# 1.0
#
# 697
# Actual    :	 मनाती हूँगी
# Prediction:	 मनाती थी
# 0.5384615384615384
#
# 698
# Actual    :	 अंगारों पर पैर रखए होते
# Prediction:	 अंगारे हो रे होते
# 0.24
#
# 699
# Actual    :	 हिला हूँगा
# Prediction:	 हिला हूँगा
# 1.0
#
# 700
# Actual    :	 प्रयत्न करता है
# Prediction:	 प्रयत्न करता है
# 1.0
#
# 701
# Actual    :	 उबलती हो
# Prediction:	 उबलती हो
# 1.0
#
# 702
# Actual    :	 रोकी होगी
# Prediction:	 रोकी थी
# 0.5454545454545454
#
# 703
# Actual    :	 निभाते हैं
# Prediction:	 निभाते हैं
# 1.0
#
# 704
# Actual    :	 बात कर रहा होता
# Prediction:	 बात कर रहा हूँ
# 0.7647058823529411
#
# 705
# Actual    :	 स्थापित कियी होंगी
# Prediction:	 स्थापित कियी होंगी
# 1.0
#
# 706
# Actual    :	 गुणा करती हैं
# Prediction:	 गुणा कर रही है
# 0.5333333333333333
#
# 707
# Actual    :	 भाग रही होगी
# Prediction:	 भाग रही थी
# 0.6428571428571429
#
# 708
# Actual    :	 यह आग्रह करेगी
# Prediction:	 यह आग्रह करे
# 0.8125
#
# 709
# Actual    :	 नाप रहे थे
# Prediction:	 नापते थे
# 0.3333333333333333
#
# 710
# Actual    :	 चढ़ना
# Prediction:	 चढ़यी
# 0.7142857142857143
#
# 711
# Actual    :	 हस्तमैथुन कर रहा होता
# Prediction:	 हस्तमैथुन करता हूँ
# 0.5652173913043478
#
# 712
# Actual    :	 झूठ बोलती होगी
# Prediction:	 झूठ बोलती होगी
# 1.0
#
# 713
# Actual    :	 बही होगी
# Prediction:	 बही होगी
# 1.0
#
# 714
# Actual    :	 चुनी हूँगी
# Prediction:	 चुनी हूँगी
# 1.0
#
# 715
# Actual    :	 सुधार करती है
# Prediction:	 सुधार करती है
# 1.0
#
# 716
# Actual    :	 टूटी होती
# Prediction:	 टूटी हैं
# 0.6363636363636364
#
# 717
# Actual    :	 डाउनलोड करता है
# Prediction:	 डाउनलोड करता है
# 1.0
#
# 718
# Actual    :	 जा रहे हो
# Prediction:	 जा रहे हो
# 1.0
#
# 719
# Actual    :	 ग़लत किया था
# Prediction:	 ग़लत किया था
# 1.0
#
# 720
# Actual    :	 जानते थे
# Prediction:	 जानते थे
# 1.0
#
# 721
# Actual    :	 नफ़रत किया होता
# Prediction:	 नफ़रत किया हूँ
# 0.7647058823529411
#
# 722
# Actual    :	 अपना रहा होगा
# Prediction:	 अपनाता था
# 0.3333333333333333
#
# 723
# Actual    :	 भुनते हैं
# Prediction:	 भुनते हैं
# 1.0
#
# 724
# Actual    :	 टेंटुआ दबाती होती
# Prediction:	 टेंटुआ दबा रही होत
# 0.5789473684210527
#
# 725
# Actual    :	 बन्द कर रहे होते
# Prediction:	 बन्द करते हैं
# 0.4444444444444444
#
# 726
# Actual    :	 चूसती है
# Prediction:	 चूसती है
# 1.0
#
# 727
# Actual    :	 कमाई थी
# Prediction:	 कमा कियी
# 0.4444444444444444
#
# 728
# Actual    :	 अंगारा हो जा रहा होगा
# Prediction:	 अूंगारा हो रहा होगा
# 0.08695652173913043
#
# 729
# Actual    :	 कसी होती
# ...
# Prediction:	 शिकार कियी हों
# 1.0
#
# 763
# Actual    :	 पढ़
# Prediction:	 पढ़ी
# 0.5714285714285714
#
# 764
# Actual    :	 बाटती थी
# Prediction:	 बाटती थी
# 1.0
#
# 765
# Actual    :	 उतरी होती
# Prediction:	 उतरी होती
# 1.0
#
# 766
# Actual    :	 यह दबाएगा
# Prediction:	 दबा
# 0.09090909090909091
#
# 767
# Actual    :	 निभा रही होती
# Prediction:	 निभा रही हूती
# 0.9333333333333333
#
# 768
# Actual    :	 छीपी हों
# Prediction:	 छीपी हों
# 1.0
#
# 769
# Actual    :	 उलटी कर रहे होंगे
# Prediction:	 उलटी कर रहे होंगे
# 1.0
#
# 770
# Actual    :	 हम तौबा करेंगे
# Prediction:	 तैंता करेंगे
# 0.125
#
# 771
# Actual    :	 शुक्रिया किया होता
# Prediction:	 शुक्रिया किया हूँ
# 0.8
#
# 772
# Actual    :	 जगी होती
# Prediction:	 जगी होती
# 1.0
#
# 773
# Actual    :	 खोल रही होगी
# Prediction:	 खोल रही होगी
# 1.0
#
# 774
# Actual    :	 अपलोड करती थीं
# Prediction:	 अपलोड करती थीं
# 1.0
#
# 775
# Actual    :	 लगते हैं
# Prediction:	 लग रहे है
# 0.3
#
# 776
# Actual    :	 मुड़ी है
# Prediction:	 मुड़ ी है
# 0.5
#
# 777
# Actual    :	 बन्द कियी हो
# Prediction:	 बन्द कियी हो
# 1.0
#
# 778
# Actual    :	 नापती होती
# Prediction:	 नाती है
# 0.25
#
# 779
# Actual    :	 पढ़ाते हों
# Prediction:	 पढ़ा रहे हो
# 0.4166666666666667
#
# 780
# Actual    :	 ये दबाएं
# Prediction:	 दबा
# 0.1
#
# 781
# Actual    :	 रख रहा हूँ
# Prediction:	 रखतरहा हूँ
# 0.9166666666666666
#
# 782
# Actual    :	 निर्माण कर रही होती
# Prediction:	 निरम्णा करती हो
# 0.3333333333333333
#
# 783
# Actual    :	 भुने थे
# Prediction:	 भुन रहे
# 0.5555555555555556
#
# 784
# Actual    :	 डाउनलोड कीजिए
# Prediction:	 उनडाउडल कर
# 0.2
#
# 785
# Actual    :	 त्याग रहा हो
# Prediction:	 त्यागता हो
# 0.42857142857142855
#
# 786
# Actual    :	 जग रहे हैं
# Prediction:	 जगते हैं
# 0.25
#
# 787
# Actual    :	 कह रही होंगी
# Prediction:	 कहती होंगी
# 0.21428571428571427
#
# 788
# Actual    :	 इनकार कियी हूँगी
# Prediction:	 इनकार कियी हूँगी
# 1.0
#
# 789
# Actual    :	 स्वप्न देखती थीं
# Prediction:	 स्वप्न देखती थीं
# 1.0
#
# 790
# Actual    :	 छीपती हो
# Prediction:	 छीपनती हो
# 0.4
#
# 791
# Actual    :	 ले जाए थे
# Prediction:	 ले जाए थे
# 1.0
#
# 792
# Actual    :	 रखी होती
# Prediction:	 तू रही हो
# 0.2
#
# 793
# Actual    :	 हस्तमैथुन कियी होती
# Prediction:	 मस्तम्तनिक कियी है
# 0.23809523809523808
#
# 794
# Actual    :	 ख़तना कियी थी
# Prediction:	 ख़रन कियी थी
# 0.26666666666666666
#
# 795
# Actual    :	 ख़ून कियी है
# Prediction:	 ख़ून कियी है
# 1.0
#
# 796
# Actual    :	 हस्तमैथुन करती होती
# Prediction:	 हमै्तमैथुन करती होती
# 0.09523809523809523
#
# 797
# Actual    :	 भागए होते
# Prediction:	 भाग होते
# 0.36363636363636365
#
# 798
# Actual    :	 बिकी थी
# Prediction:	 बिक कियी
# 0.4444444444444444
#
# 799
# Actual    :	 शुरू कर रहा होगा
# Prediction:	 शुरू करतरहा होगा
# 0.9444444444444444
#
# 800
# Actual    :	 मिटी होती
# Prediction:	 मिटा होती
# 0.9090909090909091
#
# 801
# Actual    :	 पड़ते हो
# Prediction:	 पड़ते हो
# 1.0
#
# 802
# Actual    :	 मस्ती कर रही हैं
# Prediction:	 मस्ती कर रही हैं
# 1.0
#
# 803
# Actual    :	 स्वप्न देखे होते
# Prediction:	 स्वप्न देखे हैं
# 0.7777777777777778
#
# 804
# Actual    :	 यह सूखेगी
# Prediction:	 सूखती
# 0.09090909090909091
#
# 805
# Actual    :	 शिकार किये होंगे
# Prediction:	 शिकार किये होंगे
# 1.0
#
# 806
# Actual    :	 स्वप्न देखो
# Prediction:	 ये पनेमैयी
# 0.14285714285714285
#
# 807
# Actual    :	 रचती थी
# Prediction:	 चरती थी
# 0.7777777777777778
#
# 808
# Actual    :	 सकता हो
# Prediction:	 सकता हो
# 1.0
#
# 809
# Actual    :	 सुस्ताया हूँगा
# Prediction:	 सुस्नाया हूँगा
# 0.9375
#
# 810
# Actual    :	 बरसते थे
# Prediction:	 बरसते थे
# 1.0
#
# 811
# Actual    :	 तैरते थे
# Prediction:	 तैरते थे
# 1.0
#
# 812
# Actual    :	 घुस कर रही थीं
# Prediction:	 घुस करती थीं
# 0.4375
#
# 813
# Actual    :	 उतरे हो
# Prediction:	 उतर रहे
# 0.5555555555555556
#
# 814
# Actual    :	 बचाती होगी
# Prediction:	 बचा रही थी
# 0.5
#
# 815
# Actual    :	 यह इस्तेमाल करेगी
# Prediction:	 इस्तेमाल करेगा
# 0.05263157894736842
#
# 816
# Actual    :	 आश्चर्य कर रही थीं
# Prediction:	 आश्चर्य करती थीं
# 0.55
#
# 817
# Actual    :	 कोशिश करते होते
# Prediction:	 कोशिश करते होते
# 1.0
#
# 818
# Actual    :	 रोकती हो
# Prediction:	 रोकती हो
# 1.0
#
# 819
# Actual    :	 डलवाई होगी
# Prediction:	 डलवाई थी
# 0.5833333333333334
#
# 820
# Actual    :	 खाँसा हूँगा
# Prediction:	 खाँसा था
# 0.5384615384615384
#
# 821
# Actual    :	 बिखरता होगा
# Prediction:	 बिखता होगा
# 0.3076923076923077
#
# 822
# Actual    :	 समझाते होते
# Prediction:	 समझाते हो
# 0.7692307692307693
#
# 823
# Actual    :	 पका रहा है
# Prediction:	 पका ा है
# 0.4166666666666667
#
# 824
# Actual    :	 हिला है
# Prediction:	 हिला है
# 1.0
#
# 825
# Actual    :	 ठीक होती हूँगी
# Prediction:	 ठी ठ करती हूँगी
# 0.1875
#
# 826
# Actual    :	 अंगारा बनया होता
# Prediction:	 अंगारा बना है
# 0.5555555555555556
#
# 827
# Actual    :	 चला रही होगी
# Prediction:	 चलाती थी
# 0.2857142857142857
#
# 828
# Actual    :	 पिट रही हों
# Prediction:	 पिट रही हो
# 0.8461538461538461
#
# 829
# Actual    :	 तैराते होगे
# Prediction:	 तैरा र थे
# 0.46153846153846156
#
# 830
# Actual    :	 छेड़ा है
# Prediction:	 छिड़ रहा
# 0.5
#
# 831
# Actual    :	 चढ़ते हो
# Prediction:	 चढ़ते है
# 0.9
#
# 832
# Actual    :	 ख़ून कर रहे थे
# Prediction:	 ख़ून करते थे
# 0.5
#
# 833
# Actual    :	 बिलबिला रहा होता
# Prediction:	 बिलबिला रहा हूँ
# 0.7777777777777778
#
# 834
# Actual    :	 यह लूटेगी
# Prediction:	 लू लूटेगी
# 0.8181818181818182
#
# 835
# Actual    :	 रहती हैं
# Prediction:	 रह रही है
# 0.3
#
# 836
# Actual    :	 मोड़ी होती
# Prediction:	 मोड़ी होती
# 1.0
#
# 837
# Actual    :	 चुनता होता
# Prediction:	 चुनता हो
# 0.75
#
# 838
# Actual    :	 ये जागें
# Prediction:	 ये जागें
# 1.0
#
# 839
# Actual    :	 छीपा हो
# Prediction:	 छीन किया
# 0.3333333333333333
#
# 840
# Actual    :	 प्रवेश कियी हो
# Prediction:	 प्रवेश करे हो
# 0.5625
#
# 841
# Actual    :	 ऐसी तैसी कर रही हों
# Prediction:	 ऐसी तैसी करती हों
# 0.5714285714285714
#
# 842
# Actual    :	 गिरफ़्तार करता हूँगा
# Prediction:	 गिरफ़्तार करता हूँगा
# 1.0
#
# 843
# Actual    :	 छिपाओ
# Prediction:	 यीनायी
# 0.25
#
# 844
# Actual    :	 उठा रही है
# Prediction:	 उठाती है
# 0.3333333333333333
#
# 845
# Actual    :	 डर रही होगी
# Prediction:	 डरती थी
# 0.23076923076923078
#
# 846
# Actual    :	 सूजे हों
# Prediction:	 सूजे हों
# 1.0
#
# 847
# Actual    :	 छीन रही हों
# Prediction:	 छीनती हों
# 0.3076923076923077
#
# 848
# Actual    :	 भूले थे
# Prediction:	 भूल रहे
# 0.5555555555555556
#
# 849
# Actual    :	 निकलते होते
# Prediction:	 निकल रहे होत
# 0.38461538461538464
#
# 850
# Actual    :	 कमाते होंगे
# Prediction:	 कमाते थे
# 0.5384615384615384
#
# 851
# Actual    :	 सामने आते
# Prediction:	 यहम माने
# 0.18181818181818182
#
# 852
# Actual    :	 चाह रहा हो
# Prediction:	 चाह रहा हो
# 1.0
#
# 853
# Actual    :	 रोक रही हैं
# Prediction:	 रोकती है
# 0.3076923076923077
#
# 854
# Actual    :	 त्यागा होगा
# Prediction:	 त्यागा होगा
# 1.0
#
# 855
# Actual    :	 भेज रही होती
# Prediction:	 भौं रही होती
# 0.8571428571428571
#
# 856
# Actual    :	 चूमा होता
# Prediction:	 चूमा हूँ
# 0.6363636363636364
#
# 857
# Actual    :	 बैठ रहा है
# Prediction:	 बैठता है
# 0.3333333333333333
#
# 858
# Actual    :	 तौबा कर रही हूँगी
# Prediction:	 तौबा कर रही हूँगी
# 1.0
#
# 859
# Actual    :	 छींक रहा हूँ
# Prediction:	 छींकता हो
# 0.35714285714285715
#
# 860
# Actual    :	 अपलोड कियी है
# Prediction:	 अपलोड कियी है
# 1.0
#
# 861
# Actual    :	 तुम तैराओगी
# Prediction:	 तै तुराएंगी
# 0.38461538461538464
#
# 862
# Actual    :	 अपलोड करती होती
# Prediction:	 अपलोड करती होती
# 1.0
#
# 863
# Actual    :	 मरोड़ रहा है
# Prediction:	 मरोड़ रहा है
# 1.0
#
# 864
# Actual    :	 चूमी होती
# Prediction:	 चूमी होती
# 1.0
#
# 865
# Actual    :	 हम बिलबिलाएंगे
# Prediction:	 बिलबिलाएंगे
# 0.25
#
# 866
# Actual    :	 घूमी थीं
# Prediction:	 घूमी थीं
# 1.0
#
# 867
# Actual    :	 ये तैराएं
# Prediction:	 तू तैर बाए
# 0.45454545454545453
#
# 868
# Actual    :	 आराम करती थीं
# Prediction:	 आराम करती थीं
# 1.0
#
# 869
# Actual    :	 आश्चर्य कियी थीं
# Prediction:	 आश्चर्य कियी थीं
# 1.0
#
# 870
# Actual    :	 उबलने
# Prediction:	 उठली
# 0.42857142857142855
#
# 871
# Actual    :	 आरम्भ किये हो
# Prediction:	 आरम्भ किये है
# 0.9333333333333333
#
# 872
# Actual    :	 गुणा कियी थी
# Prediction:	 गुणा कियी थी
# 1.0
#
# 873
# Actual    :	 हार रही थी
# Prediction:	 तारती थी
# 0.25
#
# 874
# Actual    :	 कहे हैं
# Prediction:	 कह रहे ह
# 0.4444444444444444
#
# 875
# Actual    :	 माफ़ करती हो
# Prediction:	 माफ़ करती हो
# 1.0
#
# 876
# Actual    :	 घुमाई होती
# Prediction:	 घुमाई हैं
# 0.6666666666666666
#
# 877
# Actual    :	 मैं माफ़ करूंगा
# Prediction:	 माफ़ करती
# 0.11764705882352941
#
# 878
# Actual    :	 भूल रही थी
# Prediction:	 भूलती थी
# 0.3333333333333333
#
# 879
# Actual    :	 ये बचेंगी
# Prediction:	 बचबचीं
# 0.09090909090909091
#
# 880
# Actual    :	 तैयार कर रहा हो
# Prediction:	 तैयार करता हो
# 0.5294117647058824
#
# 881
# Actual    :	 अपलोड की
# Prediction:	 अपनलोयी
# 0.25
#
# 882
# Actual    :	 स्थापित कियी है
# Prediction:	 स्थापित कियी है
# 1.0
#
# 883
# Actual    :	 अंगारे बरसया हूँ
# Prediction:	 अंगारे बरसा हूँ
# 0.6111111111111112
#
# 884
# Actual    :	 अंगारों पर पैर रखया होता
# Prediction:	 अंगारा होर करहा होता
# 0.3076923076923077
#
# 885
# Actual    :	 मक्खन लगा रहे हो
# Prediction:	 मक्खन करते है
# 0.4444444444444444
#
# 886
# Actual    :	 जप रहे हैं
# Prediction:	 जप रहे हो
# 0.75
#
# 887
# Actual    :	 चाट रही हों
# Prediction:	 चाटती हों
# 0.3076923076923077
#
# 888
# Actual    :	 चूमी हो
# Prediction:	 चूम करही
# 0.4444444444444444
#
# 889
# Actual    :	 पा रहा है
# Prediction:	 पाता है
# 0.2727272727272727
#
# 890
# Actual    :	 जागी होती
# Prediction:	 जागी होती
# 1.0
#
# 891
# Actual    :	 हम रचेंगी
# Prediction:	 तुम रहीं
# 0.09090909090909091
#
# 892
# Actual    :	 तैयार कियी होती
# Prediction:	 तैयार कियी है
# 0.7647058823529411
#
# 893
# Actual    :	 झांक रहा था
# Prediction:	 झांक रहा था
# 1.0
#
# 894
# Actual    :	 शुक्रिया कर रही हो
# Prediction:	 शुक्रिया करती है
# 0.6
#
# 895
# Actual    :	 फँस रहा होता
# Prediction:	 फँसता होता
# 0.2857142857142857
#
# 896
# Actual    :	 झुकी हों
# Prediction:	 झुकी हों
# 1.0
#
# 897
# Actual    :	 ला रही हूँगी
# Prediction:	 ला रही थी
# 0.5714285714285714
#
# 898
# Actual    :	 पूजा करती हो
# Prediction:	 पूजा करती है
# 0.9285714285714286
#
# 899
# Actual    :	 बन्द कर रहा हूँगा
# Prediction:	 बन्द करता हूँगा
# 0.42105263157894735
#
# 900
# Actual    :	 झाड़ती हूँगी
# Prediction:	 झाड़ती हूँगी
# 1.0
#
# 901
# Actual    :	 बिकी हैं
# Prediction:	 बिक रही ह
# 0.5
#
# 902
# Actual    :	 चमक रहे थे
# Prediction:	 चमक रहे थे
# 1.0
#
# 903
# Actual    :	 बैठ रहा है
# Prediction:	 बैठता है
# 0.3333333333333333
#
# 904
# Actual    :	 खड़ा कियी हों
# Prediction:	 खड़ा कियी हों
# 1.0
#
# 905
# Actual    :	 रहती हों
# Prediction:	 रही हों
# 0.3
#
# 906
# Actual    :	 सूज रही हो
# Prediction:	 सूजती हो
# 0.3333333333333333
#
# 907
# Actual    :	 हट रहे होंगे
# Prediction:	 हटते होंगे
# 0.21428571428571427
#
# 908
# Actual    :	 भौंका हो
# Prediction:	 भौंक रहा
# 0.6
#
# 909
# Actual    :	 त्यागा होता
# Prediction:	 त्यागा है
# 0.6923076923076923
#
# 910
# Actual    :	 डाउनलोड कर रहे हैं
# Prediction:	 डाउनलोड करते हैं
# 0.55
#
# 911
# Actual    :	 प्रेम किया होता
# Prediction:	 प्रेम किया है
# 0.7647058823529411
#
# 912
# Actual    :	 घूमता हूँ
# Prediction:	 घूम ा हूँ
# 0.9090909090909091
#
# 913
# Actual    :	 मिटा हो
# Prediction:	 मिटा हो
# 1.0
#
# 914
# Actual    :	 नाप रही होगी
# Prediction:	 नापी होगी
# 0.35714285714285715
#
# 915
# Actual    :	 खोजी होती
# Prediction:	 खो ी होती
# 0.9090909090909091
#
# 916
# Actual    :	 भेजी होती
# Prediction:	 भुमी होती
# 0.8181818181818182
#
# 917
# Actual    :	 चोरी करता था
# Prediction:	 चोरी करता था
# 1.0
#
# 918
# Actual    :	 पिघली हैं
# Prediction:	 पिघली हैं
# 1.0
#
# 919
# Actual    :	 बैठता
# Prediction:	 यी
# 0.14285714285714285
#
# 920
# Actual    :	 चुस रही होती
# Prediction:	 चुसती होती
# 0.2857142857142857
#
# 921
# Actual    :	 अंगारा बनते हों
# Prediction:	 अंगारा बनते हों
# 1.0
#
# 922
# Actual    :	 बाँधा होगा
# Prediction:	 बाँधया था
# 0.4166666666666667
#
# 923
# Actual    :	 बिखरती हो
# Prediction:	 बिकती हो
# 0.2727272727272727
#
# 924
# Actual    :	 बोली थी
# Prediction:	 बोल रही
# 0.5555555555555556
#
# 925
# Actual    :	 तौबा करती थी
# Prediction:	 तौबा करती थी
# 1.0
#
# 926
# Actual    :	 पलट रहा हूँ
# Prediction:	 पलटता हूँ
# 0.3076923076923077
#
# 927
# Actual    :	 सूख रहे होंगे
# Prediction:	 सूखते थे
# 0.26666666666666666
#
# 928
# Actual    :	 जुड़ रहा हो
# Prediction:	 जुड़ रहा हो
# 1.0
#
# 929
# Actual    :	 लू करती हों
# Prediction:	 लू करती हों
# 1.0
#
# 930
# Actual    :	 इनकार कियी है
# Prediction:	 इनकार कियी है
# 1.0
#
# 931
# Actual    :	 बीत रहे होते
# Prediction:	 बीतते होते
# 0.2857142857142857
#
# 932
# Actual    :	 पसीजी होती
# Prediction:	 पसीजी होती
# 1.0
#
# 933
# Actual    :	 बकता होगा
# Prediction:	 बनता होगा
# 0.9090909090909091
#
# 934
# Actual    :	 ख़ून करता हूँ
# Prediction:	 ख़ून करता है
# 0.8
#
# 935
# Actual    :	 ग़लत कियी थीं
# Prediction:	 ग़लत कियी थीं
# 1.0
#
# 936
# Actual    :	 झूठ बोल रहा हूँ
# Prediction:	 झूठल बो रहा हूँ
# 0.7647058823529411
#
# 937
# Actual    :	 यह पिटेगा
# Prediction:	 पिटपिए
# 0.2727272727272727
#
# 938
# Actual    :	 सोच रहा हूँ
# Prediction:	 सोच रहा हूँ
# 1.0
#
# 939
# Actual    :	 बोल रहे होते
# Prediction:	 बोल रहे हो
# 0.7857142857142857
#
# 940
# Actual    :	 बेचते होगे
# Prediction:	 बेचते होगे
# 1.0
#
# 941
# Actual    :	 उठ रही हो
# Prediction:	 उठती हो
# 0.2727272727272727
#
# 942
# Actual    :	 घुस कर रहे होते
# Prediction:	 घुस करते हैं
# 0.4117647058823529
#
# 943
# Actual    :	 मिट रहा था
# Prediction:	 मिटाता था
# 0.3333333333333333
#
# 944
# Actual    :	 हस्तमैथुन करना
# Prediction:	 हममैंमैंगममैं
# 0.125
#
# 945
# Actual    :	 अपलोड कर रहा है
# Prediction:	 अपलोड करता है
# 0.5294117647058824
#
# 946
# Actual    :	 छीली होती
# Prediction:	 छीली हैं
# 0.6363636363636364
#
# 947
# Actual    :	 मस्ती किया होगा
# Prediction:	 मस्ती किया था
# 0.7058823529411765
#
# 948
# Actual    :	 डरता हूँ
# Prediction:	 डरता हूँ
# 1.0
#
# 949
# Actual    :	 पसीजता
# Prediction:	 पीजीजी
# 0.375
#
# 950
# Actual    :	 भौंक रहे हों
# Prediction:	 भौंकते हों
# 0.35714285714285715
#
# 951
# Actual    :	 इलाज कर रहे होगे
# Prediction:	 इलाज करते होगे
# 0.4444444444444444
#
# 952
# Actual    :	 चोदी होती
# Prediction:	 चोदी होती
# 1.0
#
# 953
# Actual    :	 चूमता था
# Prediction:	 चूमता था
# 1.0
#
# 954
# Actual    :	 झूम रही हो
# Prediction:	 झूमी हो
# 0.4166666666666667
#
# 955
# Actual    :	 तुम इस्तेमाल करोगी
# Prediction:	 हम इस्तेमाल करेंगी
# 0.2
#
# 956
# Actual    :	 घूम रही है
# Prediction:	 घूम रही
# 0.6666666666666666
#
# 957
# Actual    :	 प्यार कर रही होती
# Prediction:	 प्यार करती होती
# 0.47368421052631576
#
# 958
# Actual    :	 प्रवेश कर रहे थे
# Prediction:	 प्रवेश करते थे
# 0.5555555555555556
#
# 959
# Actual    :	 पिघल रहे होते
# Prediction:	 पिघलते होते
# 0.3333333333333333
#
# 960
# Actual    :	 पका रही थीं
# Prediction:	 पका रही थीं
# 1.0
#
# 961
# Actual    :	 पीटी होगी
# Prediction:	 पीटी थीं
# 0.5454545454545454
#
# 962
# Actual    :	 बचा है
# Prediction:	 बचा है
# 1.0
#
# 963
# Actual    :	 ठगा होता
# Prediction:	 भगा है
# 0.5
#
# 964
# Actual    :	 तुला रहे होते
# Prediction:	 तुलाते होते
# 0.3333333333333333
#
# 965
# Actual    :	 सीखती हो
# Prediction:	 सीखती हो
# 1.0
#
# 966
# Actual    :	 भेजता था
# Prediction:	 भौन रहा थ
# 0.2
#
# 967
# Actual    :	 दिला रहा था
# Prediction:	 दिलाता था
# 0.38461538461538464
#
# 968
# Actual    :	 मुड़ रहा हो
# Prediction:	 मुड़ रहा हो
# 1.0
#
# 969
# Actual    :	 सका होता
# Prediction:	 सका है
# 0.6
#
# 970
# Actual    :	 नहाई है
# Prediction:	 नहा ी है
# 0.4444444444444444
#
# 971
# Actual    :	 खोजती होगी
# Prediction:	 खोत रही थी
# 0.4166666666666667
#
# 972
# Actual    :	 अपलोड किये होते
# Prediction:	 अपलोड किये होते
# 1.0
#
# 973
# Actual    :	 रोई हों
# Prediction:	 रो रही ह
# 0.4444444444444444
#
# 974
# Actual    :	 संभोग कर रहा होता
# Prediction:	 संभोग करता हूँ
# 0.47368421052631576
#
# 975
# Actual    :	 सहमती है
# Prediction:	 समझती है
# 0.8
#
# 976
# Actual    :	 उड़ाता हूँगा
# Prediction:	 उड़ा रहा हूँग
# 0.35714285714285715
#
# 977
# Actual    :	 पूछे होते
# Prediction:	 पूछे हैं
# 0.6363636363636364
#
# 978
# Actual    :	 छुड़ाती हूँ
# Prediction:	 छुड़ाती है
# 0.7692307692307693
#
# 979
# Actual    :	 डलवाती थी
# Prediction:	 डलवा करती
# 0.5454545454545454
#
# 980
# Actual    :	 प्राप्त करो
# Prediction:	 यहमैयाये
# 0.07142857142857142
#
# 981
# Actual    :	 निर्माण करते थे
# Prediction:	 निर्थार करते थे
# 0.8823529411764706
#
# 982
# Actual    :	 डलवाता होता
# Prediction:	 डलाल रहा हो
# 0.3076923076923077
#
# 983
# Actual    :	 सोच रहे थे
# Prediction:	 सोच रहे थे
# 1.0
#
# 984
# Actual    :	 शुरू किया होगा
# Prediction:	 शुरू किया होगा
# 1.0
#
# 985
# Actual    :	 मैं नशा करूंगा
# Prediction:	 नशा करूंगा
# 0.125
#
# 986
# Actual    :	 नशा करते हो
# Prediction:	 नशा करते हो
# 1.0
#
# 987
# Actual    :	 अंगारे बरस रहा है
# Prediction:	 अंगारे बरस रहा है
# 1.0
#
# 988
# Actual    :	 पीई होती
# Prediction:	 पी ी हूँ
# 0.4
#
# 989
# Actual    :	 अध्ययन कर रहे हैं
# Prediction:	 अध्ययन कर रहे है
# 0.8947368421052632
#
# 990
# Actual    :	 ठीक होई थीं
# Prediction:	 ठीक होए थीं
# 0.9230769230769231
#
# 991
# Actual    :	 जमे हो
# Prediction:	 जम किये
# 0.375
#
# 992
# Actual    :	 अपलोड किये हैं
# Prediction:	 अपलोड किये हैं
# 1.0
#
# 993
# Actual    :	 मैं भागऊंगा
# Prediction:	 भागी
# 0.07692307692307693
#
# 994
# Actual    :	 दौड़ता होगा
# Prediction:	 दौड़ रहा होग
# 0.38461538461538464
#
# 995
# Actual    :	 मुड़ रहा होता
# Prediction:	 मुड़ रहा हूँ
# 0.7333333333333333
#
# 996
# Actual    :	 तैरे होंगे
# Prediction:	 तरखे होंगे
# 0.8333333333333334
#
# 997
# Actual    :	 सेक्स कियी होती
# Prediction:	 सेक्स कियी है
# 0.7647058823529411
#
# 998
# Actual    :	 जमा कियी हो
# Prediction:	 जमा कियी हो
# 1.0
#
# 999
# Actual    :	 अंगारे उगलई थी
# Prediction:	 अंगारा बरसई थी
# 0.75
#
# 1000
# Actual    :	 हटे
# Prediction:	 यहमनी
# 0.16666666666666666
#
# 0.6372158354573738
# 338

# %%
# -*- coding: utf-8 -*-
"""
**Importing Modules**
"""

import pandas as pd
import matplotlib.pyplot as plt
import random
import torch 
from torch import nn
from torch.autograd import Variable
from torch.nn import functional as F

SEED = 1
random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

file_name = 'hindi-train-medium'
evaluate_file = 'hindi-dev'

"""**Processing Files And Other Useful Function**"""

def file_preprocess(file_name):
    
    # from google.colab import files
    # uploaded = files.upload()
    
    pandas_holder = pd.read_csv(file_name, sep='\t', names=['word', 'inflection', 'feature'])
    
    words_list = [list(word) for word in list(pandas_holder['word'])]
    inflection_list = [list(inflection) for inflection in list(pandas_holder['inflection'])]
    feature_list = [feat.split(';') for feat in list(pandas_holder['feature'])]
    #print(words_list);

    vocab_chars_word = [char for word in words_list for char in word]
    vocab_chars_inflection = [char for word in inflection_list for char in word]
    # print(vocab_chars_word)

    char_vocab = ['<pad>', '<sos>', '<eos>'] + list(set(vocab_chars_word+vocab_chars_inflection))
    feat_vocab = ['<pad>'] + list(set([f for feat in feature_list for f in feat]))

    # print(char_vocab)
    char_to_index = dict(zip(char_vocab, list(range(len(char_vocab)))))
    index_to_char = dict(zip(list(range(len(char_vocab))), char_vocab))
    feature_to_index = dict(zip(feat_vocab, list(range(len(feat_vocab)))))

    # 2 added here b/c sos and eos appended to each word and inflection word
    word_list_length = [len(word)+2 for word in words_list]
    inflection_list_length = [len(word)+2 for word in inflection_list]
    feature_list_length = [len(feat) for feat in feature_list]

    max_word_length = max(word_list_length)
    max_inflection_length = max(inflection_list_length)
    max_feature_length = max(feature_list_length)

    return words_list, inflection_list, feature_list, char_to_index, index_to_char, feature_to_index, max_word_length, max_inflection_length, max_feature_length

def boundary_appender(sentence_list):
    sent_list = []
    for sentence in sentence_list:
        sentence.append('<eos>')
        sentence.insert(0,'<sos>')
        sent_list.append(sentence)
    return sent_list

def sentence_pad(sentence_list, length):
    sent_list = []
    for sentence in sentence_list:
        while len(sentence) != length:
            sentence.append(char_to_index['<pad>'])
        sent_list.append(sentence)
    return sent_list

def word_pad(word, length):
    while len(word) != length:
        word.append(char_to_index['<pad>'])
    return word

def source_taget_equal_length_maker(source, target):
    source_lengths = [len(s) for s in source]
    target_lengths = [len(t) for t in target]
    max_lengths = max(max(source_lengths), max(target_lengths))

    source_sent = sentence_pad(source, max_lengths)
    target_sent = sentence_pad(target, max_lengths)
    return source_sent, target_sent, max_lengths

def sentence_encoder(sentence_list, dictionary):
    sent_list = [[dictionary[word] for word in sentence]for sentence in sentence_list]
    return sent_list

def mini_batch_creator(sentence_list, batch_size):
    final = [sentence_list[i * batch_size:(i + 1) * batch_size] for i in range((len(sentence_list) + batch_size - 1) // batch_size)]
    return final

"""**Encoder Class**"""

class EncoderLSTM(nn.Module):
    def __init__(self,vocab_size,embedding_size, encoder_hid_dem,decoder_hid_dem,bidirectional,device):
        super().__init__()
        # super(EncoderLSTM, self).__init__()
        self.encoder_hid_dem  = encoder_hid_dem
        self.encoder_n_direction=1;
        self.device = device
        self.bias = False
        if(bidirectional==True):
            self.encoder_n_direction=2;

        self.embedding_layer  = nn.Embedding(num_embeddings=vocab_size, embedding_dim=embedding_size, padding_idx=0)
        self.GRU_layer        = nn.GRU(input_size=embedding_size, hidden_size=encoder_hid_dem, batch_first=True, bidirectional=bidirectional)
        self.fc               = nn.Linear(encoder_hid_dem*self.encoder_n_direction,decoder_hid_dem)
        #self.GRU_layer.bias   = torch.nn.Parameter(torch.zeros(encoder_hid_dem))


    def forward(self, input_word):
        # print(input_word.size())
        #[batch_size    src_sent_lent]

        embed_out = self.embedding_layer(input_word)
        #[BATCH_SIZE    src_sent_lent   embedding_dim]
        
        embed_out = F.relu(embed_out)
        embed_out = F.dropout(embed_out, p=0.5)

        self.batch = embed_out.size()[0]

        # hidden = self.init_hidden()
        GRU_out,hidden = self.GRU_layer(embed_out)

        
        # print(GRU_out.size())
        # print(hidd.size())

        #[BATCH_SIZE    sec_sent_len    n_direction*hid_dem]
        #[n_layer*n_direction   batch_size    hid_dem]

        #where the first hid_dim elements in the third axis are the hidden states from the top layer forward RNN, and the last hid_dim elements are hidden states from the top layer backward RNN

        #hidden is stacked [forward_1, backward_1, forward_2, backward_2, ...]
        #hidden [-2, :, : ] is the last of the forwards RNN 
        #hidden [-1, :, : ] is the last of the backwards RNN

        GRU_out = F.relu(GRU_out)
        hidden = torch.tanh(self.fc(torch.cat((hidden[-2,:,:],hidden[-1,:,:]),dim=1)))
        
        # print(GRU_out.size())
        # print(hidden.size())

        #outputs = [batch_size    src sent len, encoder_hid_dim * n_direction]
        #hidden = [batch size, dec hid dim]
        return GRU_out,hidden

    def init_hidden(self):
        return (Variable(torch.eye(1, self.encoder_hid_dem)).unsqueeze(1).repeat(2, self.batch, 1).to(self.device))

"""**Attention Class**"""

class Attention(nn.Module):
    def __init__(self,encoder_hid_dem,decoder_hid_dem,bidirectional):
        super().__init__()
        self.enc_hid_dim = encoder_hid_dem
        self.dec_hid_dim = decoder_hid_dem
        self.encoder_n_direction=1;
        if(bidirectional==True):
            self.encoder_n_direction=2;
        self.attn = nn.Linear((encoder_hid_dem * self.encoder_n_direction) + decoder_hid_dem, decoder_hid_dem)
        self.v = nn.Parameter(torch.rand(decoder_hid_dem))
        
    def forward(self, hidden, encoder_outputs):
        
        #hidden = [batch size, dec hid dim]
        #encoder_outputs = [batch_size    ,src sent len, enc hid dim * encoder_n_direction]
        
        batch_size = encoder_outputs.shape[0]
        src_len    = encoder_outputs.shape[1]
        
        hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)
        
        #hidden          = [batch size, src sent len, dec hid dim]
        #encoder_outputs = [batch size, src sent len, enc hid dim * encoder_n_direction]
        
        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim=2))) 
        #energy = [batch size, src sent len, dec hid dim]
        
        energy = energy.permute(0, 2, 1)
        #energy = [batch size, dec hid dim, src sent len]
        
        #v = [dec hid dim]
        v = self.v.repeat(batch_size, 1).unsqueeze(1)
        #v = [batch size, 1, dec hid dim]
                
        attention = torch.bmm(v, energy).squeeze(1)
        #attention= [batch size, src len]
        
        return F.softmax(attention, dim=1)

"""**Decoder Class**"""

class DecoderLSTM(nn.Module):
    def __init__(self, decoder_hid_dem, encoder_hid_dem, vocab_size,embedding_dim,attention,decoder_input_size,linear_input_size,bidirectional,device):
        super().__init__()      
        self.encoder_hid_dem=encoder_hid_dem
        self.decoder_hid_dem=decoder_hid_dem
        self.attention=attention
        self.device = device

        self.decoder_n_direction=1;
        if(bidirectional==True):
            self.decoder_n_direction=2;
        self.GRU_layer_out = nn.GRU(decoder_input_size,decoder_hid_dem)
        self.out_layer = nn.Linear(in_features=linear_input_size, out_features=vocab_size)
        #self.GRU_layer_out.bias = torch.nn.Parameter(torch.zeros(decoder_input_size))

    def forward(self, feature, hidden,actual_word,encoder_outputs):

        feature = feature.unsqueeze(1)
        # print('decoder')
        # print(feature.size())
        #[batch_size    src_sent_lent=1   feat_size=6]
       
        # print(hidden.size())
        # [batch_size     dec_hid_dim]


        # print(actual_word.size())
        # [batch_size    src_sent_lent=1   embedding_dim]

        # print(encoder_outputs.size())
        # outputs = [batch_size    src sent len, encoder_hid_dim * encoder_n_directional]


        a = self.attention(hidden,encoder_outputs)
        #  print(a.size())
        # [batch_size    src_sent_len]

        a = a.unsqueeze(1)
        #a = [batch size, 1, src len] 

        weighted = torch.bmm(a,encoder_outputs)
        # print(weighted.size())
        # weighted = [batch size, 1, enc_hid_dim * encoder_n_direction]
        # if len(actual_word.size()) != 0:
        input_char = torch.cat((actual_word,feature,weighted),2) 
        # else:
        #     input_char = torch.cat((feature,weighted),2)

        input_char=input_char.permute(1,0,2)
        #  print(input_char.size())
        # [1    BATCH_SIZE      decoder_input_size]

        hidden = hidden.unsqueeze(0)
        # print(hidden.size())
        #[1 batch_size decoder_hid_dem]
       
        output, hidden = self.GRU_layer_out(input_char, hidden)

        # print(output.size())
        # [sent_len=1   batch_size  decoder_n_direction*decoder_hid_dem]
        # print(hidden.size())
        # [n_layer*n_direction    BATCH_SIZE      hid_dem]



        output = F.leaky_relu(output)
        output = F.dropout(output, p=0.5)

        output = torch.cat((output.squeeze(0),weighted.squeeze(1),actual_word.squeeze(1)),dim=1)
        pre_out = self.out_layer(output)
        predicted_output = F.log_softmax(pre_out, dim=1)

        # print(predicted_output.size())
        # [ batch_size vacab_size ]
        return predicted_output, hidden.squeeze(0)  

    def init_hidden(self, batch):
        return (Variable(torch.eye(1, self.decoder_hid_dem)).unsqueeze(1).repeat(1, batch, 1).to(self.device),Variable(torch.eye(1, self.decoder_hid_dem)).unsqueeze(1).repeat(1, batch, 1).to(self.device))

"""**Ploatter Class**"""

def ploatter(loss, acc, val_loss, val_acc):
    fig = plt.figure()

    # x axis values
    x = list(range(1,len(loss)+1))
    fig1=plt.figure(figsize=(18, 12), dpi= 80, facecolor='w', edgecolor='k')
    fig1=plt.subplot(1,2,1)

    lines_1 = plt.plot(x, loss, x, val_loss)
    l1, l2 = lines_1
    plt.setp(lines_1, linestyle='--')
    plt.setp(l1, linewidth=2, color='b', label='Train Loss')
    plt.setp(l2, linewidth=2, color='g', label='Validation Loss')

    plt.legend(loc='upper right')
    fig1.set_title('Loss/Epoch')
    fig1.set_xlabel('Epoch')
    fig1.set_ylabel('loss')

    fig2=plt.subplot(1, 2, 2)

    lines_2 = plt.plot(x, acc, x, val_acc)
    l1, l2 = lines_2
    plt.setp(lines_2, linestyle='--')
    plt.setp(l1, linewidth=2, color='b', label='Train Accuracy')
    plt.setp(l2, linewidth=2, color='g', label='Validation Accuracy')

    plt.legend(loc='upper right')
    fig2.set_title('Accuracy/Epoch')
    fig2.set_xlabel('Epoch')
    fig2.set_ylabel('Accuracy')
    
    
    fig.savefig(file_name+'.png')
    plt.show()

"""**Training Model Class**"""

def train_model(encoder, decoder, encoder_optimizer, decoder_optimizer, criteria, train_input_word, train_output_word, train_feature_words, max_word_length,device):


    # print(train_input_word.size())
    # print(train_feature_words.size())

    batch_size = train_input_word.size()[0]

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    actual_word = encoder.embedding_layer(torch.tensor(char_to_index['<sos>']).view(1, -1).to(device)).repeat(batch_size, 1, 1)
    # print(encoder.embedding_layer(torch.tensor(char_to_index['<sos>']).to(device)).size())
    
    encoder_outputs,hidden = encoder(train_input_word)

    feature = train_feature_words[:, :]
    
    char_loss   = 0.0
    running_acc = 0.0

    for idx in range(max_word_length):

        predicted_output, hidden = decoder(feature, hidden,actual_word,encoder_outputs)

        topv, topi = predicted_output.topk(1)
        bs = topi.size()[0]
        temp2 = torch.zeros(0,1,300).to(device)

        for row in range(bs):
            index = topi[row][0].item()
            temp = encoder.embedding_layer(torch.tensor(index).view(1, -1).to(device))
            temp2 = torch.cat((temp2,temp))

        teacher_force = random.random() < .5
        
        if teacher_force == 1:
            actual_word = encoder.embedding_layer(train_output_word[:,idx]).unsqueeze(1)
        else:
            actual_word = temp2
        
        # print(temp2.size())
        # initial_word = encoder.embedding_layer(torch.tensor(char_to_index[index_to_char[topi.item()]]).view(1, -1).cuda())



        predicted_label = torch.argmax(predicted_output, dim=1)
        num_correct = (predicted_label == train_output_word[:, idx]).sum()
        
        running_acc += num_correct.item()
        char_loss += criteria(predicted_output, train_output_word[:, idx])

    char_loss.backward()
    
    encoder_optimizer.step()
    decoder_optimizer.step()

    return char_loss.item()/max_word_length, running_acc/(max_word_length*batch_size)

"""**Validation Class**"""

def validate_model(encoder, decoder, criteria, valid_input_word, valid_output_word, valid_feature_words, max_word_length,device):
    batch_size = valid_input_word.size()[0]

    initial_word = encoder.embedding_layer(torch.tensor(char_to_index['<sos>']).view(1, -1).to(device)).repeat(batch_size, 1, 1)

    encoder_outputs,hidden = encoder(valid_input_word)
    decoder_output = []

    vali_char_loss = 0.0
    vali_running_acc = 0.0
  
    feature = valid_feature_words[:, :]
    act = torch.zeros(batch_size,max_word_length).to(device)
  
    for idx in range(max_word_length):

        predicted_output, hidden = decoder(feature, hidden,initial_word,encoder_outputs)
        # initial_word = encoder.embedding_layer(valid_output_word[:,idx]).unsqueeze(1)               
        # topv, topi = predicted_output.data.topk(batch_size)
        # initial_word = encoder.embedding_layer(torch.tensor(char_to_index[index_to_char[topi.item()]]).view(1, -1).to(device)).repeat(batch_size, 1, 1)

        
        topv, topi = predicted_output.topk(1)
        bs = topi.size()[0]
        temp2 = torch.zeros(0,1,300).to(device)

        decoder_output.append(topi)

        for row in range(bs):
            index = topi[row][0].item()
            act[row][idx] = index
            temp = encoder.embedding_layer(torch.tensor(index).view(1, -1).to(device))
            temp2 = torch.cat((temp2,temp))

        initial_word = temp2

        predicted_label = torch.argmax(predicted_output, dim=1)

        num_correct = (predicted_label == valid_output_word[:, idx]).sum()
        vali_running_acc += num_correct.item()
        vali_char_loss += criteria(predicted_output, valid_output_word[:, idx])
    
    # for i in range(batch_size):
    #   for j in range(max_word_length):
    #     print(index_to_char[int(act[i][j].item())],end="")
    #   print('')
    

        
    return vali_char_loss.item() / max_word_length, vali_running_acc / (max_word_length * batch_size)

"""**Actual Training function**"""

def train_iter(encoder, decoder, input_word, output_word, feat_encode_list, valid_word, valid_label, valid_feat,device,encoder_optimizer,decoder_optimizer, batch_size, epoch_size):
    criteria = nn.NLLLoss()

    input_word_minibatches  = mini_batch_creator(input_word, batch_size=batch_size)
    output_word_minibatches = mini_batch_creator(output_word, batch_size=batch_size)
    feature_minibatches     = mini_batch_creator(feat_encode_list, batch_size=batch_size)

    # valid_word_minibatches  = mini_batch_creator(valid_word,batch_size=10)
    # valid_label_minibatches = mini_batch_creator(valid_label,batch_size=10)
    # valid_feat_minibatches  = mini_batch_creator(valid_feat,batch_size=10)

    return_batch_loss, return_batch_acc = [], []
    val_return_batch_loss, val_return_batch_acc = [], []

    valid_word, valid_label, max_length_1 = source_taget_equal_length_maker(valid_word, valid_label)
    valid_word = torch.tensor(valid_word).to(device)
    valid_label = torch.tensor(valid_label).to(device)
    valid_feat = torch.FloatTensor(valid_feat).to(device)

    for epoch in range(epoch_size):

        batch_loss, batch_acc = [], []
        val_batch_loss, val_batch_acc = [], []

        for batch_idx, _ in enumerate(input_word_minibatches):
            train_word = input_word_minibatches[batch_idx]
            train_label = output_word_minibatches[batch_idx]
            train_feat = feature_minibatches[batch_idx]

            train_word, train_label, max_length = source_taget_equal_length_maker(train_word, train_label)

            train_word = torch.tensor(train_word).to(device)
            train_label = torch.tensor(train_label).to(device)
            train_feat = torch.FloatTensor(train_feat).to(device)

            loss, accuracy = train_model(encoder, decoder, encoder_optimizer, decoder_optimizer, criteria, train_word, train_label, train_feat, max_length,device)

            batch_loss.append(loss)
            batch_acc.append(accuracy)


            # print("Epoch: %d/%d" %(epoch+1, epoch_size),
            #       "Batch: %d/%d" %(batch_idx+1, len(input_word_minibatches)),
            #       "TrainLoss: %3f" %(loss),
            #       "TrainAccuracy: %3f" %(accuracy),
            #       "Avg_TrainLoss: %3f" % (sum(batch_loss)/len(batch_loss)),
            #       "Avg_TrainAccuracy: %3f" %(sum(batch_acc)/len(batch_acc)),)

        return_batch_loss.append(sum(batch_loss)/len(batch_loss))
        return_batch_acc.append(sum(batch_acc)/len(batch_acc))



        # for batch_idx,_ in enumerate(valid_word_minibatches):
        #     valid_word=valid_word_minibatches[batch_idx]
        #     valid_label=valid_label_minibatches[batch_idx] 
        #     valid_feat=valid_feat_minibatches[batch_idx]

        #     valid_word,valid_label,max_length2 = source_taget_equal_length_maker(valid_word,valid_label)

        #     valid_word=torch.tensor(valid_word).to(device)
        #     valid_label=torch.tensor(valid_label).to(device)
        #     valid_feat=torch.FloatTensor(valid_feat).to(device)

        val_loss, val_accuracy = validate_model(encoder, decoder, criteria, valid_word, valid_label, valid_feat, max_length_1,device)
        # val_loss, val_accuracy = validate_model(encoder, decoder, None, valid_word, valid_label, valid_feat, max_length_1,device)
        val_batch_loss.append(val_loss)
        val_batch_acc.append(val_accuracy)
       
      
      
        print('>>>>' * 30)
        print("Epoch: %d/%d" % (epoch + 1, epoch_size),
              "Avg_TrainLoss: %3f" % (sum(batch_loss) / len(batch_loss)),
              "Avg_TrainAccuracy: %3f" % (sum(batch_acc) / len(batch_acc)),
              "Avg_ValLoss: %3f" % (sum(val_batch_loss) / len(val_batch_loss)),
              "Avg_ValAccuracy: %3f" % (sum(val_batch_acc) / len(val_batch_acc)),)
        print('<<<<' * 30)

        val_return_batch_acc.append(sum(val_batch_acc)/len(val_batch_acc))
        val_return_batch_loss.append(sum(val_batch_loss)/len(val_batch_loss))

    return return_batch_acc, return_batch_loss, val_return_batch_acc, val_return_batch_loss

"""**Actual Code Starts**"""
  






words_list, inflection_list, feature_list, char_to_index, index_to_char, feature_to_index, max_word_length, max_inflection_length, max_feature_length = file_preprocess(file_name)

words_list      = boundary_appender(words_list)
inflection_list = boundary_appender(inflection_list)

word_encode_list  = sentence_encoder(words_list, char_to_index)
inf_encode_list   = sentence_encoder(inflection_list, char_to_index)
feat_encode_list  = sentence_pad(sentence_encoder(feature_list, feature_to_index), max_feature_length)


test_words_list, test_inflection_list, test_feature_list, _, _, _, _, _, _ = file_preprocess(evaluate_file)
t_word_list       = boundary_appender(test_words_list)
t_inflection_list = boundary_appender(test_inflection_list)

test_word_encode_list = sentence_encoder(t_word_list, char_to_index)
test_inf_encode_list  = sentence_encoder(t_inflection_list, char_to_index)
test_feat_encode_list = sentence_pad(sentence_encoder(test_feature_list, feature_to_index), max_feature_length)


"""**Hyperparameters**"""
embedding_size   = 300
encoder_hid_dem  = 300
decoder_hid_dem  = 3*encoder_hid_dem
vocab_size       = len(char_to_index.keys())
dropout          = .75
BATCH_SIZE       = 10         
EPOCH_SIZE       = 30
learning_rate    = 0.00069
encoder_bidirectional =True
decoder_birectional   =True
teacher_forcing_ratio = .5


if(encoder_bidirectional):
    decoder_input_size  =len(feat_encode_list[0]) + embedding_size+(encoder_hid_dem)*2
    linear_input_size=embedding_size+decoder_hid_dem+(encoder_hid_dem)*2
else:
    decoder_input_size  =len(feat_encode_list[0]) + embedding_size+(encoder_hid_dem)*1
    linear_input_size=embedding_size+decoder_hid_dem+(encoder_hid_dem)*1

"""**Creating instances of classes**"""
class Seq2Seq(nn.Module):
    def __init__(self,vocab_size, embedding_size, encoder_hid_dem,decoder_hid_dem,device,encoder_bidirectional,decoder_input_size,linear_input_size,decoder_birectional,lr):
        super().__init__()      
        self.encoder   = EncoderLSTM(vocab_size, embedding_size, encoder_hid_dem,decoder_hid_dem,encoder_bidirectional,device).to(device)              # (58, 300, 150)
        self.attention = Attention(encoder_hid_dem,decoder_hid_dem,encoder_bidirectional)
        self.decoder   = DecoderLSTM(decoder_hid_dem, encoder_hid_dem, vocab_size,embedding_size,self.attention,decoder_input_size,linear_input_size,decoder_birectional,device).to(device)          # (606, 300, 58)
        self.encoder_optimizer = torch.optim.Adam(self.encoder.parameters(), lr)
        self.decoder_optimizer = torch.optim.Adam(self.decoder.parameters(), lr)

    def train(self):
        train_acc, train_loss, val_acc, val_loss = train_iter(self.encoder, self.decoder, word_encode_list, inf_encode_list, feat_encode_list, test_word_encode_list, test_inf_encode_list, test_feat_encode_list, device,self.encoder_optimizer,self.decoder_optimizer,batch_size=BATCH_SIZE, epoch_size=EPOCH_SIZE)
        ploatter(loss=train_loss, acc=train_acc, val_loss=val_loss, val_acc=val_acc)
    def test_model(self,test_input_word, test_feature_words,inflection_encode_list1,device,max_word_length=25):
        batch_size = test_input_word.size()[0]
        initial_word = self.encoder.embedding_layer(torch.tensor(char_to_index['<sos>']).view(1, -1).to(device)).repeat(batch_size, 1, 1)
        encoder_outputs,hidden = self.encoder(test_input_word)
        vali_running_acc = 0.0
        feature = test_feature_words[:, :]
        act = torch.zeros(batch_size,max_word_length).to(device)
        decoder_out = []
    
        for idx in range(max_word_length):
            predicted_output, hidden = self.decoder(feature, hidden,initial_word,encoder_outputs)
            topv, topi = predicted_output.topk(1)
            bs = topi.size()[0]
            temp2 = torch.zeros(0,1,300).to(device)

            for row in range(bs):
              index = topi[row][0].item()
              act[row][idx] = index
              temp = self.encoder.embedding_layer(torch.tensor(index).view(1, -1).to(device))
              temp2 = torch.cat((temp2,temp))

            initial_word = temp2
        
            predicted_label = torch.argmax(predicted_output, dim=1)

            num_correct = (predicted_label == inflection_encode_list1[:, idx]).sum()
            vali_running_acc += num_correct.item()
        
            if topi.item() == char_to_index['<eos>']:
                break
            elif topi.item() != char_to_index['<sos>']:
                decoder_out.append(index_to_char[topi.item()])
        return decoder_out, vali_running_acc / (max_word_length * batch_size)

s2s = Seq2Seq(vocab_size,embedding_size,encoder_hid_dem,decoder_hid_dem,device,encoder_bidirectional,decoder_input_size,linear_input_size,decoder_birectional,learning_rate)

s2s.train()
torch.save(s2s.state_dict(),'saved.pt')
#s2s = torch.load('saved.pt')


"""**Printing Test **"""

test_file = 'hindi-test'

test_words_list, test_inflection_lists, test_feature_list, _, _, _, _, _, _ = file_preprocess(test_file)

words_list1 = boundary_appender(test_words_list)
tempo = test_inflection_lists
inflection_list1 = boundary_appender(tempo)

word_encode_list1 = sentence_encoder(words_list1, char_to_index)
inflection_encode_list1 = sentence_encoder(inflection_list1, char_to_index)

feat_encode_list1  = sentence_pad(sentence_encoder(test_feature_list, feature_to_index), max_feature_length)



final_acc = 0;
count=0;
for index in range(0, len(word_encode_list1)):
    
#     test_word = Variable(torch.tensor(word_encode_list1[index]).view(1,-1)).cuda()
#     test_feat = Variable(torch.FloatTensor(feat_encode_list1[index]).view(1, -1)).cuda()
#     test_label = Variable(torch.FloatTensor(inflection_encode_list1[index]).view(1, -1)).cuda()

    test_word = [word_encode_list1[index]]
    test_feat = [feat_encode_list1[index]]
    test_label = [inflection_encode_list1[index]]
    
    test_word, test_label, max_len = source_taget_equal_length_maker(test_word,test_label)
    test_word = torch.tensor(test_word).to(device)
    test_label = torch.tensor(test_label).to(device)
    test_feat = torch.FloatTensor(test_feat).to(device)

    predic_out,ac = s2s.test_model(test_word, test_feat,test_label,device,max_len)
    final_acc = final_acc+ac
    if ac==1:
      count=count+1;
   
print(final_acc/len(word_encode_list1))
print(count)
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 1/30 Avg_TrainLoss: 1.984958 Avg_TrainAccuracy: 0.494766 Avg_ValLoss: 1.705969 Avg_ValAccuracy: 0.548963
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 2/30 Avg_TrainLoss: 1.546707 Avg_TrainAccuracy: 0.582634 Avg_ValLoss: 1.654981 Avg_ValAccuracy: 0.586296
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 3/30 Avg_TrainLoss: 1.329672 Avg_TrainAccuracy: 0.635711 Avg_ValLoss: 1.549099 Avg_ValAccuracy: 0.604111
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 4/30 Avg_TrainLoss: 1.169449 Avg_TrainAccuracy: 0.674935 Avg_ValLoss: 1.438329 Avg_ValAccuracy: 0.634815
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 5/30 Avg_TrainLoss: 0.925479 Avg_TrainAccuracy: 0.737999 Avg_ValLoss: 1.422891 Avg_ValAccuracy: 0.665222
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 6/30 Avg_TrainLoss: 0.832706 Avg_TrainAccuracy: 0.763794 Avg_ValLoss: 1.260085 Avg_ValAccuracy: 0.686963
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 7/30 Avg_TrainLoss: 0.698386 Avg_TrainAccuracy: 0.798176 Avg_ValLoss: 1.291297 Avg_ValAccuracy: 0.706000
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 8/30 Avg_TrainLoss: 0.636090 Avg_TrainAccuracy: 0.813081 Avg_ValLoss: 1.264793 Avg_ValAccuracy: 0.715074
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 9/30 Avg_TrainLoss: 0.548651 Avg_TrainAccuracy: 0.843400 Avg_ValLoss: 1.192623 Avg_ValAccuracy: 0.730519
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 10/30 Avg_TrainLoss: 0.522295 Avg_TrainAccuracy: 0.853743 Avg_ValLoss: 1.132000 Avg_ValAccuracy: 0.745889
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 11/30 Avg_TrainLoss: 0.470930 Avg_TrainAccuracy: 0.869293 Avg_ValLoss: 1.057934 Avg_ValAccuracy: 0.770926
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 12/30 Avg_TrainLoss: 0.404809 Avg_TrainAccuracy: 0.888793 Avg_ValLoss: 1.069062 Avg_ValAccuracy: 0.770519
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 13/30 Avg_TrainLoss: 0.354081 Avg_TrainAccuracy: 0.901527 Avg_ValLoss: 1.035652 Avg_ValAccuracy: 0.786630
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 14/30 Avg_TrainLoss: 0.368453 Avg_TrainAccuracy: 0.899682 Avg_ValLoss: 1.003302 Avg_ValAccuracy: 0.785815
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 15/30 Avg_TrainLoss: 0.291751 Avg_TrainAccuracy: 0.920794 Avg_ValLoss: 1.069599 Avg_ValAccuracy: 0.784926
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 16/30 Avg_TrainLoss: 0.288191 Avg_TrainAccuracy: 0.921508 Avg_ValLoss: 1.016842 Avg_ValAccuracy: 0.796778
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 17/30 Avg_TrainLoss: 0.252961 Avg_TrainAccuracy: 0.934578 Avg_ValLoss: 1.028059 Avg_ValAccuracy: 0.802889
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 18/30 Avg_TrainLoss: 0.204037 Avg_TrainAccuracy: 0.946567 Avg_ValLoss: 1.069776 Avg_ValAccuracy: 0.806815
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 19/30 Avg_TrainLoss: 0.195839 Avg_TrainAccuracy: 0.947399 Avg_ValLoss: 1.016812 Avg_ValAccuracy: 0.815444
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 20/30 Avg_TrainLoss: 0.202468 Avg_TrainAccuracy: 0.947958 Avg_ValLoss: 1.015960 Avg_ValAccuracy: 0.817815
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 21/30 Avg_TrainLoss: 0.184084 Avg_TrainAccuracy: 0.951637 Avg_ValLoss: 0.988488 Avg_ValAccuracy: 0.818259
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 22/30 Avg_TrainLoss: 0.182589 Avg_TrainAccuracy: 0.953536 Avg_ValLoss: 0.990392 Avg_ValAccuracy: 0.821741
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 23/30 Avg_TrainLoss: 0.156539 Avg_TrainAccuracy: 0.960391 Avg_ValLoss: 1.011131 Avg_ValAccuracy: 0.823481
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 24/30 Avg_TrainLoss: 0.152030 Avg_TrainAccuracy: 0.960833 Avg_ValLoss: 1.068981 Avg_ValAccuracy: 0.816444
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 25/30 Avg_TrainLoss: 0.140827 Avg_TrainAccuracy: 0.964904 Avg_ValLoss: 1.117827 Avg_ValAccuracy: 0.814667
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 26/30 Avg_TrainLoss: 0.131135 Avg_TrainAccuracy: 0.966716 Avg_ValLoss: 1.156405 Avg_ValAccuracy: 0.811741
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 27/30 Avg_TrainLoss: 0.113165 Avg_TrainAccuracy: 0.971330 Avg_ValLoss: 1.088901 Avg_ValAccuracy: 0.821037
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 28/30 Avg_TrainLoss: 0.108315 Avg_TrainAccuracy: 0.973580 Avg_ValLoss: 1.151588 Avg_ValAccuracy: 0.820481
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 29/30 Avg_TrainLoss: 0.123785 Avg_TrainAccuracy: 0.971099 Avg_ValLoss: 1.154199 Avg_ValAccuracy: 0.814593
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 30/30 Avg_TrainLoss: 0.099868 Avg_TrainAccuracy: 0.977354 Avg_ValLoss: 1.115763 Avg_ValAccuracy: 0.823852
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# 0.6555805887569753
# 310
