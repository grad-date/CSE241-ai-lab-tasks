# %%
# -*- coding: utf-8 -*-
"""
**Importing Modules**
"""

import pandas as pd
import matplotlib.pyplot as plt
import random
import torch 
from torch import nn
from torch.autograd import Variable
from torch.nn import functional as F

SEED = 1
random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

file_name = 'hindi-train-medium'
evaluate_file = 'hindi-dev'

"""**Processing Files And Other Useful Function**"""

def file_preprocess(file_name):
    
    # from google.colab import files
    # uploaded = files.upload()
    
    pandas_holder = pd.read_csv(file_name, sep='\t', names=['word', 'inflection', 'feature'])
    
    words_list = [list(word) for word in list(pandas_holder['word'])]
    inflection_list = [list(inflection) for inflection in list(pandas_holder['inflection'])]
    feature_list = [feat.split(';') for feat in list(pandas_holder['feature'])]
    #print(words_list);

    vocab_chars_word = [char for word in words_list for char in word]
    vocab_chars_inflection = [char for word in inflection_list for char in word]
    # print(vocab_chars_word)

    char_vocab = ['<pad>', '<sos>', '<eos>'] + list(set(vocab_chars_word+vocab_chars_inflection))
    feat_vocab = ['<pad>'] + list(set([f for feat in feature_list for f in feat]))

    # print(char_vocab)
    char_to_index = dict(zip(char_vocab, list(range(len(char_vocab)))))
    index_to_char = dict(zip(list(range(len(char_vocab))), char_vocab))
    feature_to_index = dict(zip(feat_vocab, list(range(len(feat_vocab)))))

    # 2 added here b/c sos and eos appended to each word and inflection word
    word_list_length = [len(word)+2 for word in words_list]
    inflection_list_length = [len(word)+2 for word in inflection_list]
    feature_list_length = [len(feat) for feat in feature_list]

    max_word_length = max(word_list_length)
    max_inflection_length = max(inflection_list_length)
    max_feature_length = max(feature_list_length)

    return words_list, inflection_list, feature_list, char_to_index, index_to_char, feature_to_index, max_word_length, max_inflection_length, max_feature_length

def boundary_appender(sentence_list):
    sent_list = []
    for sentence in sentence_list:
        sentence.append('<eos>')
        sentence.insert(0,'<sos>')
        sent_list.append(sentence)
    return sent_list

def sentence_pad(sentence_list, length):
    sent_list = []
    for sentence in sentence_list:
        while len(sentence) != length:
            sentence.append(char_to_index['<pad>'])
        sent_list.append(sentence)
    return sent_list

def word_pad(word, length):
    while len(word) != length:
        word.append(char_to_index['<pad>'])
    return word

def source_taget_equal_length_maker(source, target):
    source_lengths = [len(s) for s in source]
    target_lengths = [len(t) for t in target]
    max_lengths = max(max(source_lengths), max(target_lengths))

    source_sent = sentence_pad(source, max_lengths)
    target_sent = sentence_pad(target, max_lengths)
    return source_sent, target_sent, max_lengths

def sentence_encoder(sentence_list, dictionary):
    sent_list = [[dictionary[word] for word in sentence]for sentence in sentence_list]
    return sent_list

def mini_batch_creator(sentence_list, batch_size):
    final = [sentence_list[i * batch_size:(i + 1) * batch_size] for i in range((len(sentence_list) + batch_size - 1) // batch_size)]
    return final

"""**Encoder Class**"""

class EncoderLSTM(nn.Module):
    def __init__(self,vocab_size,embedding_size, encoder_hid_dem,decoder_hid_dem,bidirectional,device):
        super().__init__()
        # super(EncoderLSTM, self).__init__()
        self.encoder_hid_dem  = encoder_hid_dem
        self.encoder_n_direction=1;
        self.device = device
        self.bias = False
        if(bidirectional==True):
            self.encoder_n_direction=2;

        self.embedding_layer  = nn.Embedding(num_embeddings=vocab_size, embedding_dim=embedding_size, padding_idx=0)
        self.GRU_layer        = nn.GRU(input_size=embedding_size, hidden_size=encoder_hid_dem, batch_first=True, bidirectional=bidirectional)
        self.fc               = nn.Linear(encoder_hid_dem*self.encoder_n_direction,decoder_hid_dem)
        #self.GRU_layer.bias   = torch.nn.Parameter(torch.zeros(encoder_hid_dem))


    def forward(self, input_word):
        # print(input_word.size())
        #[batch_size    src_sent_lent]

        embed_out = self.embedding_layer(input_word)
        #[BATCH_SIZE    src_sent_lent   embedding_dim]
        
        embed_out = F.relu(embed_out)
        embed_out = F.dropout(embed_out, p=0.5)

        self.batch = embed_out.size()[0]

        # hidden = self.init_hidden()
        GRU_out,hidden = self.GRU_layer(embed_out)

        
        # print(GRU_out.size())
        # print(hidd.size())

        #[BATCH_SIZE    sec_sent_len    n_direction*hid_dem]
        #[n_layer*n_direction   batch_size    hid_dem]

        #where the first hid_dim elements in the third axis are the hidden states from the top layer forward RNN, and the last hid_dim elements are hidden states from the top layer backward RNN

        #hidden is stacked [forward_1, backward_1, forward_2, backward_2, ...]
        #hidden [-2, :, : ] is the last of the forwards RNN 
        #hidden [-1, :, : ] is the last of the backwards RNN

        GRU_out = F.relu(GRU_out)
        hidden = torch.tanh(self.fc(torch.cat((hidden[-2,:,:],hidden[-1,:,:]),dim=1)))
        
        # print(GRU_out.size())
        # print(hidden.size())

        #outputs = [batch_size    src sent len, encoder_hid_dim * n_direction]
        #hidden = [batch size, dec hid dim]
        return GRU_out,hidden

    def init_hidden(self):
        return (Variable(torch.eye(1, self.encoder_hid_dem)).unsqueeze(1).repeat(2, self.batch, 1).to(self.device))

"""**Attention Class**"""

class Attention(nn.Module):
    def __init__(self,encoder_hid_dem,decoder_hid_dem,bidirectional):
        super().__init__()
        self.enc_hid_dim = encoder_hid_dem
        self.dec_hid_dim = decoder_hid_dem
        self.encoder_n_direction=1;
        if(bidirectional==True):
            self.encoder_n_direction=2;
        self.attn = nn.Linear((encoder_hid_dem * self.encoder_n_direction) + decoder_hid_dem, decoder_hid_dem)
        self.v = nn.Parameter(torch.rand(decoder_hid_dem))
        
    def forward(self, hidden, encoder_outputs):
        
        #hidden = [batch size, dec hid dim]
        #encoder_outputs = [batch_size    ,src sent len, enc hid dim * encoder_n_direction]
        
        batch_size = encoder_outputs.shape[0]
        src_len    = encoder_outputs.shape[1]
        
        hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)
        
        #hidden          = [batch size, src sent len, dec hid dim]
        #encoder_outputs = [batch size, src sent len, enc hid dim * encoder_n_direction]
        
        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim=2))) 
        #energy = [batch size, src sent len, dec hid dim]
        
        energy = energy.permute(0, 2, 1)
        #energy = [batch size, dec hid dim, src sent len]
        
        #v = [dec hid dim]
        v = self.v.repeat(batch_size, 1).unsqueeze(1)
        #v = [batch size, 1, dec hid dim]
                
        attention = torch.bmm(v, energy).squeeze(1)
        #attention= [batch size, src len]
        
        return F.softmax(attention, dim=1)

"""**Decoder Class**"""

class DecoderLSTM(nn.Module):
    def __init__(self, decoder_hid_dem, encoder_hid_dem, vocab_size,embedding_dim,attention,decoder_input_size,linear_input_size,bidirectional,device):
        super().__init__()      
        self.encoder_hid_dem=encoder_hid_dem
        self.decoder_hid_dem=decoder_hid_dem
        self.attention=attention
        self.device = device

        self.decoder_n_direction=1;
        if(bidirectional==True):
            self.decoder_n_direction=2;
        self.GRU_layer_out = nn.GRU(decoder_input_size,decoder_hid_dem)
        self.out_layer = nn.Linear(in_features=linear_input_size, out_features=vocab_size)
        #self.GRU_layer_out.bias = torch.nn.Parameter(torch.zeros(decoder_input_size))

    def forward(self, feature, hidden,actual_word,encoder_outputs):

        feature = feature.unsqueeze(1)
        # print('decoder')
        # print(feature.size())
        #[batch_size    src_sent_lent=1   feat_size=6]
       
        # print(hidden.size())
        # [batch_size     dec_hid_dim]


        # print(actual_word.size())
        # [batch_size    src_sent_lent=1   embedding_dim]

        # print(encoder_outputs.size())
        # outputs = [batch_size    src sent len, encoder_hid_dim * encoder_n_directional]


        a = self.attention(hidden,encoder_outputs)
        #  print(a.size())
        # [batch_size    src_sent_len]

        a = a.unsqueeze(1)
        #a = [batch size, 1, src len] 

        weighted = torch.bmm(a,encoder_outputs)
        # print(weighted.size())
        # weighted = [batch size, 1, enc_hid_dim * encoder_n_direction]
        # if len(actual_word.size()) != 0:
        input_char = torch.cat((actual_word,feature,weighted),2) 
        # else:
        #     input_char = torch.cat((feature,weighted),2)

        input_char=input_char.permute(1,0,2)
        #  print(input_char.size())
        # [1    BATCH_SIZE      decoder_input_size]

        hidden = hidden.unsqueeze(0)
        # print(hidden.size())
        #[1 batch_size decoder_hid_dem]
       
        output, hidden = self.GRU_layer_out(input_char, hidden)

        # print(output.size())
        # [sent_len=1   batch_size  decoder_n_direction*decoder_hid_dem]
        # print(hidden.size())
        # [n_layer*n_direction    BATCH_SIZE      hid_dem]



        output = F.leaky_relu(output)
        output = F.dropout(output, p=0.5)

        output = torch.cat((output.squeeze(0),weighted.squeeze(1),actual_word.squeeze(1)),dim=1)
        pre_out = self.out_layer(output)
        predicted_output = F.log_softmax(pre_out, dim=1)

        # print(predicted_output.size())
        # [ batch_size vacab_size ]
        return predicted_output, hidden.squeeze(0)  

    def init_hidden(self, batch):
        return (Variable(torch.eye(1, self.decoder_hid_dem)).unsqueeze(1).repeat(1, batch, 1).to(self.device),Variable(torch.eye(1, self.decoder_hid_dem)).unsqueeze(1).repeat(1, batch, 1).to(self.device))

"""**Ploatter Class**"""

def ploatter(loss, acc, val_loss, val_acc):
    fig = plt.figure()

    # x axis values
    x = list(range(1,len(loss)+1))
    fig1=plt.figure(figsize=(18, 12), dpi= 80, facecolor='w', edgecolor='k')
    fig1=plt.subplot(1,2,1)

    lines_1 = plt.plot(x, loss, x, val_loss)
    l1, l2 = lines_1
    plt.setp(lines_1, linestyle='--')
    plt.setp(l1, linewidth=2, color='b', label='Train Loss')
    plt.setp(l2, linewidth=2, color='g', label='Validation Loss')

    plt.legend(loc='upper right')
    fig1.set_title('Loss/Epoch')
    fig1.set_xlabel('Epoch')
    fig1.set_ylabel('loss')

    fig2=plt.subplot(1, 2, 2)

    lines_2 = plt.plot(x, acc, x, val_acc)
    l1, l2 = lines_2
    plt.setp(lines_2, linestyle='--')
    plt.setp(l1, linewidth=2, color='b', label='Train Accuracy')
    plt.setp(l2, linewidth=2, color='g', label='Validation Accuracy')

    plt.legend(loc='upper right')
    fig2.set_title('Accuracy/Epoch')
    fig2.set_xlabel('Epoch')
    fig2.set_ylabel('Accuracy')
    
    
    fig.savefig(file_name+'.png')
    plt.show()

"""**Training Model Class**"""

def train_model(encoder, decoder, encoder_optimizer, decoder_optimizer, criteria, train_input_word, train_output_word, train_feature_words, max_word_length,device):


    # print(train_input_word.size())
    # print(train_feature_words.size())

    batch_size = train_input_word.size()[0]

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    actual_word = encoder.embedding_layer(torch.tensor(char_to_index['<sos>']).view(1, -1).to(device)).repeat(batch_size, 1, 1)
    # print(encoder.embedding_layer(torch.tensor(char_to_index['<sos>']).to(device)).size())
    
    encoder_outputs,hidden = encoder(train_input_word)

    feature = train_feature_words[:, :]
    
    char_loss   = 0.0
    running_acc = 0.0

    for idx in range(max_word_length):

        predicted_output, hidden = decoder(feature, hidden,actual_word,encoder_outputs)

        topv, topi = predicted_output.topk(1)
        bs = topi.size()[0]
        temp2 = torch.zeros(0,1,300).to(device)

        for row in range(bs):
            index = topi[row][0].item()
            temp = encoder.embedding_layer(torch.tensor(index).view(1, -1).to(device))
            temp2 = torch.cat((temp2,temp))

        teacher_force = random.random() < .5
        
        if teacher_force == 1:
            actual_word = encoder.embedding_layer(train_output_word[:,idx]).unsqueeze(1)
        else:
            actual_word = temp2
        
        # print(temp2.size())
        # initial_word = encoder.embedding_layer(torch.tensor(char_to_index[index_to_char[topi.item()]]).view(1, -1).cuda())



        predicted_label = torch.argmax(predicted_output, dim=1)
        num_correct = (predicted_label == train_output_word[:, idx]).sum()
        
        running_acc += num_correct.item()
        char_loss += criteria(predicted_output, train_output_word[:, idx])

    char_loss.backward()
    
    encoder_optimizer.step()
    decoder_optimizer.step()

    return char_loss.item()/max_word_length, running_acc/(max_word_length*batch_size)

"""**Validation Class**"""

def validate_model(encoder, decoder, criteria, valid_input_word, valid_output_word, valid_feature_words, max_word_length,device):
    batch_size = valid_input_word.size()[0]

    initial_word = encoder.embedding_layer(torch.tensor(char_to_index['<sos>']).view(1, -1).to(device)).repeat(batch_size, 1, 1)

    encoder_outputs,hidden = encoder(valid_input_word)
    decoder_output = []

    vali_char_loss = 0.0
    vali_running_acc = 0.0
  
    feature = valid_feature_words[:, :]
    act = torch.zeros(batch_size,max_word_length).to(device)
  
    for idx in range(max_word_length):

        predicted_output, hidden = decoder(feature, hidden,initial_word,encoder_outputs)
        # initial_word = encoder.embedding_layer(valid_output_word[:,idx]).unsqueeze(1)               
        # topv, topi = predicted_output.data.topk(batch_size)
        # initial_word = encoder.embedding_layer(torch.tensor(char_to_index[index_to_char[topi.item()]]).view(1, -1).to(device)).repeat(batch_size, 1, 1)

        
        topv, topi = predicted_output.topk(1)
        bs = topi.size()[0]
        temp2 = torch.zeros(0,1,300).to(device)

        decoder_output.append(topi)

        for row in range(bs):
            index = topi[row][0].item()
            act[row][idx] = index
            temp = encoder.embedding_layer(torch.tensor(index).view(1, -1).to(device))
            temp2 = torch.cat((temp2,temp))

        initial_word = temp2

        predicted_label = torch.argmax(predicted_output, dim=1)

        num_correct = (predicted_label == valid_output_word[:, idx]).sum()
        vali_running_acc += num_correct.item()
        vali_char_loss += criteria(predicted_output, valid_output_word[:, idx])
    
    # for i in range(batch_size):
    #   for j in range(max_word_length):
    #     print(index_to_char[int(act[i][j].item())],end="")
    #   print('')
    

        
    return vali_char_loss.item() / max_word_length, vali_running_acc / (max_word_length * batch_size)

"""**Actual Training function**"""

def train_iter(encoder, decoder, input_word, output_word, feat_encode_list, valid_word, valid_label, valid_feat,device,encoder_optimizer,decoder_optimizer, batch_size, epoch_size):
    criteria = nn.NLLLoss()

    input_word_minibatches  = mini_batch_creator(input_word, batch_size=batch_size)
    output_word_minibatches = mini_batch_creator(output_word, batch_size=batch_size)
    feature_minibatches     = mini_batch_creator(feat_encode_list, batch_size=batch_size)

    # valid_word_minibatches  = mini_batch_creator(valid_word,batch_size=10)
    # valid_label_minibatches = mini_batch_creator(valid_label,batch_size=10)
    # valid_feat_minibatches  = mini_batch_creator(valid_feat,batch_size=10)

    return_batch_loss, return_batch_acc = [], []
    val_return_batch_loss, val_return_batch_acc = [], []

    valid_word, valid_label, max_length_1 = source_taget_equal_length_maker(valid_word, valid_label)
    valid_word = torch.tensor(valid_word).to(device)
    valid_label = torch.tensor(valid_label).to(device)
    valid_feat = torch.FloatTensor(valid_feat).to(device)

    for epoch in range(epoch_size):

        batch_loss, batch_acc = [], []
        val_batch_loss, val_batch_acc = [], []

        for batch_idx, _ in enumerate(input_word_minibatches):
            train_word = input_word_minibatches[batch_idx]
            train_label = output_word_minibatches[batch_idx]
            train_feat = feature_minibatches[batch_idx]

            train_word, train_label, max_length = source_taget_equal_length_maker(train_word, train_label)

            train_word = torch.tensor(train_word).to(device)
            train_label = torch.tensor(train_label).to(device)
            train_feat = torch.FloatTensor(train_feat).to(device)

            loss, accuracy = train_model(encoder, decoder, encoder_optimizer, decoder_optimizer, criteria, train_word, train_label, train_feat, max_length,device)

            batch_loss.append(loss)
            batch_acc.append(accuracy)


            # print("Epoch: %d/%d" %(epoch+1, epoch_size),
            #       "Batch: %d/%d" %(batch_idx+1, len(input_word_minibatches)),
            #       "TrainLoss: %3f" %(loss),
            #       "TrainAccuracy: %3f" %(accuracy),
            #       "Avg_TrainLoss: %3f" % (sum(batch_loss)/len(batch_loss)),
            #       "Avg_TrainAccuracy: %3f" %(sum(batch_acc)/len(batch_acc)),)

        return_batch_loss.append(sum(batch_loss)/len(batch_loss))
        return_batch_acc.append(sum(batch_acc)/len(batch_acc))



        # for batch_idx,_ in enumerate(valid_word_minibatches):
        #     valid_word=valid_word_minibatches[batch_idx]
        #     valid_label=valid_label_minibatches[batch_idx] 
        #     valid_feat=valid_feat_minibatches[batch_idx]

        #     valid_word,valid_label,max_length2 = source_taget_equal_length_maker(valid_word,valid_label)

        #     valid_word=torch.tensor(valid_word).to(device)
        #     valid_label=torch.tensor(valid_label).to(device)
        #     valid_feat=torch.FloatTensor(valid_feat).to(device)

        val_loss, val_accuracy = validate_model(encoder, decoder, criteria, valid_word, valid_label, valid_feat, max_length_1,device)
        # val_loss, val_accuracy = validate_model(encoder, decoder, None, valid_word, valid_label, valid_feat, max_length_1,device)
        val_batch_loss.append(val_loss)
        val_batch_acc.append(val_accuracy)
       
      
      
        print('>>>>' * 30)
        print("Epoch: %d/%d" % (epoch + 1, epoch_size),
              "Avg_TrainLoss: %3f" % (sum(batch_loss) / len(batch_loss)),
              "Avg_TrainAccuracy: %3f" % (sum(batch_acc) / len(batch_acc)),
              "Avg_ValLoss: %3f" % (sum(val_batch_loss) / len(val_batch_loss)),
              "Avg_ValAccuracy: %3f" % (sum(val_batch_acc) / len(val_batch_acc)),)
        print('<<<<' * 30)

        val_return_batch_acc.append(sum(val_batch_acc)/len(val_batch_acc))
        val_return_batch_loss.append(sum(val_batch_loss)/len(val_batch_loss))

    return return_batch_acc, return_batch_loss, val_return_batch_acc, val_return_batch_loss

"""**Actual Code Starts**"""
  






words_list, inflection_list, feature_list, char_to_index, index_to_char, feature_to_index, max_word_length, max_inflection_length, max_feature_length = file_preprocess(file_name)

words_list      = boundary_appender(words_list)
inflection_list = boundary_appender(inflection_list)

word_encode_list  = sentence_encoder(words_list, char_to_index)
inf_encode_list   = sentence_encoder(inflection_list, char_to_index)
feat_encode_list  = sentence_pad(sentence_encoder(feature_list, feature_to_index), max_feature_length)


test_words_list, test_inflection_list, test_feature_list, _, _, _, _, _, _ = file_preprocess(evaluate_file)
t_word_list       = boundary_appender(test_words_list)
t_inflection_list = boundary_appender(test_inflection_list)

test_word_encode_list = sentence_encoder(t_word_list, char_to_index)
test_inf_encode_list  = sentence_encoder(t_inflection_list, char_to_index)
test_feat_encode_list = sentence_pad(sentence_encoder(test_feature_list, feature_to_index), max_feature_length)


"""**Hyperparameters**"""
embedding_size   = 300
encoder_hid_dem  = 300
decoder_hid_dem  = 3*encoder_hid_dem
vocab_size       = len(char_to_index.keys())
dropout          = .75
BATCH_SIZE       = 10         
EPOCH_SIZE       = 30
learning_rate    = 0.00069
encoder_bidirectional =True
decoder_birectional   =True
teacher_forcing_ratio = .5


if(encoder_bidirectional):
    decoder_input_size  =len(feat_encode_list[0]) + embedding_size+(encoder_hid_dem)*2
    linear_input_size=embedding_size+decoder_hid_dem+(encoder_hid_dem)*2
else:
    decoder_input_size  =len(feat_encode_list[0]) + embedding_size+(encoder_hid_dem)*1
    linear_input_size=embedding_size+decoder_hid_dem+(encoder_hid_dem)*1

"""**Creating instances of classes**"""
class Seq2Seq:
    def __init__(self,vocab_size, embedding_size, encoder_hid_dem,decoder_hid_dem,device,encoder_bidirectional,decoder_input_size,linear_input_size,decoder_birectional,lr):
        self.encoder   = EncoderLSTM(vocab_size, embedding_size, encoder_hid_dem,decoder_hid_dem,encoder_bidirectional,device).to(device)              # (58, 300, 150)
        self.attention = Attention(encoder_hid_dem,decoder_hid_dem,encoder_bidirectional)
        self.decoder   = DecoderLSTM(decoder_hid_dem, encoder_hid_dem, vocab_size,embedding_size,self.attention,decoder_input_size,linear_input_size,decoder_birectional,device).to(device)          # (606, 300, 58)
        self.encoder_optimizer = torch.optim.Adam(self.encoder.parameters(), lr)
        self.decoder_optimizer = torch.optim.Adam(self.decoder.parameters(), lr)

    def train(self):
        train_acc, train_loss, val_acc, val_loss = train_iter(self.encoder, self.decoder, word_encode_list, inf_encode_list, feat_encode_list, test_word_encode_list, test_inf_encode_list, test_feat_encode_list, device,self.encoder_optimizer,self.decoder_optimizer,batch_size=BATCH_SIZE, epoch_size=EPOCH_SIZE)
        ploatter(loss=train_loss, acc=train_acc, val_loss=val_loss, val_acc=val_acc)
    def test_model(self,test_input_word, test_feature_words,inflection_encode_list1,device,max_word_length=25):
        batch_size = test_input_word.size()[0]
        initial_word = self.encoder.embedding_layer(torch.tensor(char_to_index['<sos>']).view(1, -1).to(device)).repeat(batch_size, 1, 1)
        encoder_outputs,hidden = self.encoder(test_input_word)
        vali_running_acc = 0.0
        feature = test_feature_words[:, :]
        act = torch.zeros(batch_size,max_word_length).to(device)
        decoder_out = []
    
        for idx in range(max_word_length):
            predicted_output, hidden = self.decoder(feature, hidden,initial_word,encoder_outputs)
            topv, topi = predicted_output.topk(1)
            bs = topi.size()[0]
            temp2 = torch.zeros(0,1,300).to(device)

            for row in range(bs):
              index = topi[row][0].item()
              act[row][idx] = index
              temp = self.encoder.embedding_layer(torch.tensor(index).view(1, -1).to(device))
              temp2 = torch.cat((temp2,temp))

            initial_word = temp2
        
            predicted_label = torch.argmax(predicted_output, dim=1)

            num_correct = (predicted_label == inflection_encode_list1[:, idx]).sum()
            vali_running_acc += num_correct.item()
        
            if topi.item() == char_to_index['<eos>']:
                break
            elif topi.item() != char_to_index['<sos>']:
                decoder_out.append(index_to_char[topi.item()])
        return decoder_out, vali_running_acc / (max_word_length * batch_size)

s2s = Seq2Seq(vocab_size,embedding_size,encoder_hid_dem,decoder_hid_dem,device,encoder_bidirectional,decoder_input_size,linear_input_size,decoder_birectional,learning_rate)

s2s.train()
torch.save(s2s,'saved.pt')
s2s = torch.load('saved.pt')


"""**Printing Test **"""

test_file = 'hindi-test'

test_words_list, test_inflection_lists, test_feature_list, _, _, _, _, _, _ = file_preprocess(test_file)

words_list1 = boundary_appender(test_words_list)
tempo = test_inflection_lists
inflection_list1 = boundary_appender(tempo)

word_encode_list1 = sentence_encoder(words_list1, char_to_index)
inflection_encode_list1 = sentence_encoder(inflection_list1, char_to_index)

feat_encode_list1  = sentence_pad(sentence_encoder(test_feature_list, feature_to_index), max_feature_length)



final_acc = 0;
count=0;
for index in range(0, len(word_encode_list1)):
    
#     test_word = Variable(torch.tensor(word_encode_list1[index]).view(1,-1)).cuda()
#     test_feat = Variable(torch.FloatTensor(feat_encode_list1[index]).view(1, -1)).cuda()
#     test_label = Variable(torch.FloatTensor(inflection_encode_list1[index]).view(1, -1)).cuda()

    test_word = [word_encode_list1[index]]
    test_feat = [feat_encode_list1[index]]
    test_label = [inflection_encode_list1[index]]
    
    test_word, test_label, max_len = source_taget_equal_length_maker(test_word,test_label)
    test_word = torch.tensor(test_word).to(device)
    test_label = torch.tensor(test_label).to(device)
    test_feat = torch.FloatTensor(test_feat).to(device)

    predic_out,ac = s2s.test_model(test_word, test_feat,test_label,device,max_len)
    final_acc = final_acc+ac
    if ac==1:
      count=count+1;
    print(index+1)
    print('Actual    :\t',"".join(test_inflection_lists[index][1:-1]))
    print('Prediction:\t',"".join(predic_out))
    print(ac)
    print('')

print(final_acc/len(word_encode_list1))
print(count)
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 1/30 Avg_TrainLoss: 1.941498 Avg_TrainAccuracy: 0.504685 Avg_ValLoss: 1.778803 Avg_ValAccuracy: 0.567556
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 2/30 Avg_TrainLoss: 1.480608 Avg_TrainAccuracy: 0.600788 Avg_ValLoss: 1.609046 Avg_ValAccuracy: 0.606000
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 3/30 Avg_TrainLoss: 1.326567 Avg_TrainAccuracy: 0.645591 Avg_ValLoss: 1.554627 Avg_ValAccuracy: 0.623741
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 4/30 Avg_TrainLoss: 1.170201 Avg_TrainAccuracy: 0.678072 Avg_ValLoss: 1.506644 Avg_ValAccuracy: 0.647407
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 5/30 Avg_TrainLoss: 0.938871 Avg_TrainAccuracy: 0.737517 Avg_ValLoss: 1.345053 Avg_ValAccuracy: 0.681000
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 6/30 Avg_TrainLoss: 0.856747 Avg_TrainAccuracy: 0.761977 Avg_ValLoss: 1.245929 Avg_ValAccuracy: 0.704556
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 7/30 Avg_TrainLoss: 0.743048 Avg_TrainAccuracy: 0.788327 Avg_ValLoss: 1.218720 Avg_ValAccuracy: 0.728333
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 8/30 Avg_TrainLoss: 0.655666 Avg_TrainAccuracy: 0.812467 Avg_ValLoss: 1.124778 Avg_ValAccuracy: 0.740444
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 9/30 Avg_TrainLoss: 0.569394 Avg_TrainAccuracy: 0.838339 Avg_ValLoss: 1.132377 Avg_ValAccuracy: 0.754444
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 10/30 Avg_TrainLoss: 0.528498 Avg_TrainAccuracy: 0.853093 Avg_ValLoss: 1.009096 Avg_ValAccuracy: 0.775296
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 11/30 Avg_TrainLoss: 0.478736 Avg_TrainAccuracy: 0.865966 Avg_ValLoss: 0.994760 Avg_ValAccuracy: 0.790148
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 12/30 Avg_TrainLoss: 0.417756 Avg_TrainAccuracy: 0.883344 Avg_ValLoss: 0.885739 Avg_ValAccuracy: 0.803630
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 13/30 Avg_TrainLoss: 0.388044 Avg_TrainAccuracy: 0.888072 Avg_ValLoss: 0.932287 Avg_ValAccuracy: 0.806704
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 14/30 Avg_TrainLoss: 0.384077 Avg_TrainAccuracy: 0.891961 Avg_ValLoss: 0.884210 Avg_ValAccuracy: 0.811148
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 15/30 Avg_TrainLoss: 0.312962 Avg_TrainAccuracy: 0.911751 Avg_ValLoss: 0.915405 Avg_ValAccuracy: 0.816407
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 16/30 Avg_TrainLoss: 0.294863 Avg_TrainAccuracy: 0.919555 Avg_ValLoss: 1.012984 Avg_ValAccuracy: 0.809815
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 17/30 Avg_TrainLoss: 0.287456 Avg_TrainAccuracy: 0.921839 Avg_ValLoss: 0.958322 Avg_ValAccuracy: 0.807778
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 18/30 Avg_TrainLoss: 0.251964 Avg_TrainAccuracy: 0.929088 Avg_ValLoss: 0.964619 Avg_ValAccuracy: 0.818333
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 19/30 Avg_TrainLoss: 0.237748 Avg_TrainAccuracy: 0.934257 Avg_ValLoss: 0.946117 Avg_ValAccuracy: 0.817037
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 20/30 Avg_TrainLoss: 0.251027 Avg_TrainAccuracy: 0.931961 Avg_ValLoss: 0.859846 Avg_ValAccuracy: 0.824296
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 21/30 Avg_TrainLoss: 0.214902 Avg_TrainAccuracy: 0.942544 Avg_ValLoss: 0.917185 Avg_ValAccuracy: 0.824926
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 22/30 Avg_TrainLoss: 0.201555 Avg_TrainAccuracy: 0.947022 Avg_ValLoss: 0.936826 Avg_ValAccuracy: 0.828704
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 23/30 Avg_TrainLoss: 0.177512 Avg_TrainAccuracy: 0.952671 Avg_ValLoss: 0.915987 Avg_ValAccuracy: 0.835000
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 24/30 Avg_TrainLoss: 0.160645 Avg_TrainAccuracy: 0.955746 Avg_ValLoss: 1.025295 Avg_ValAccuracy: 0.823296
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 25/30 Avg_TrainLoss: 0.176238 Avg_TrainAccuracy: 0.954602 Avg_ValLoss: 0.974342 Avg_ValAccuracy: 0.823481
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 26/30 Avg_TrainLoss: 0.180482 Avg_TrainAccuracy: 0.950915 Avg_ValLoss: 1.020906 Avg_ValAccuracy: 0.822593
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 27/30 Avg_TrainLoss: 0.142285 Avg_TrainAccuracy: 0.962837 Avg_ValLoss: 0.981140 Avg_ValAccuracy: 0.836037
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 28/30 Avg_TrainLoss: 0.153271 Avg_TrainAccuracy: 0.959972 Avg_ValLoss: 0.918328 Avg_ValAccuracy: 0.838444
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 29/30 Avg_TrainLoss: 0.148646 Avg_TrainAccuracy: 0.963032 Avg_ValLoss: 0.916678 Avg_ValAccuracy: 0.834667
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 30/30 Avg_TrainLoss: 0.135029 Avg_TrainAccuracy: 0.965805 Avg_ValLoss: 0.906626 Avg_ValAccuracy: 0.845778
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Streaming output truncated to the last 5000 lines.
# Prediction:	 पा रहा है
# 0.8181818181818182
#
# 2
# Actual    :	 झांकिए
# Prediction:
# 0.125
#
# 3
# Actual    :	 चुराते होंगे
# Prediction:	 चुनाता था
# 0.42857142857142855
#
# 4
# Actual    :	 लड़ी होती
# Prediction:	 लड़ी होती
# 1.0
#
# 5
# Actual    :	 पिघल रही होगी
# Prediction:	 पिघल रही होगी
# 1.0
#
# 6
# Actual    :	 चढ़ती हैं
# Prediction:	 चोती हैं
# 0.18181818181818182
#
# 7
# Actual    :	 आरम्भ कर रही हैं
# Prediction:	 आर्भ कर रही है
# 0.16666666666666666
#
# 8
# Actual    :	 बन रही होती
# Prediction:	 बन रही हो
# 0.7692307692307693
#
# 9
# Actual    :	 भेजती होती
# Prediction:	 भुमती होती
# 0.8333333333333334
#
# 10
# Actual    :	 जगी हो
# Prediction:	 जगी हो
# 1.0
#
# 11
# Actual    :	 सहमा होगा
# Prediction:	 सहमा होगा
# 1.0
#
# 12
# Actual    :	 उड़ाई होती
# Prediction:	 उड़ाई हो
# 0.75
#
# 13
# Actual    :	 संभोग कर रही है
# Prediction:	 संभोग कर रही है
# 1.0
#
# 14
# Actual    :	 ये फँसें
# Prediction:	 यह फँसेगी
# 0.7
#
# 15
# Actual    :	 चबा रही होती
# Prediction:	 चबा रही होती
# 1.0
#
# 16
# Actual    :	 माफ़ करता था
# Prediction:	 माफ़ करते थे
# 0.8571428571428571
#
# 17
# Actual    :	 ठीक होई हूँ
# Prediction:	 ठीक हो होऊंग
# 0.5384615384615384
#
# 18
# Actual    :	 पिघले होते
# Prediction:	 पिघले हो
# 0.75
#
# 19
# Actual    :	 हम सड़ें
# Prediction:	 सड़ी थीं
# 0.3
#
# 20
# Actual    :	 तू अध्ययन करेगी
# Prediction:	 अप्ययन करयी थी
# 0.058823529411764705
#
# 21
# Actual    :	 स्वप्न देखते
# Prediction:	 व
# 0.07142857142857142
#
# 22
# Actual    :	 तुम बनोगे
# Prediction:	 बनी है
# 0.18181818181818182
#
# 23
# Actual    :	 ये खोलें
# Prediction:	 खोली थीं
# 0.3
#
# 24
# Actual    :	 उड़ा रही हों
# Prediction:	 उड़ा रही होती
# 0.8571428571428571
#
# 25
# Actual    :	 प्रयत्न करती होती
# Prediction:	 प्रयत्न करती होती
# 1.0
#
# 26
# Actual    :	 बेच रही होंगी
# Prediction:	 बेच रही होंगी
# 1.0
#
# 27
# Actual    :	 झूम रही हैं
# Prediction:	 झूम रही है
# 0.8461538461538461
#
# 28
# Actual    :	 तू छिपाएगी
# Prediction:	 छिपापी थी
# 0.08333333333333333
#
# 29
# Actual    :	 हम टेंटुआ दबाएं
# Prediction:	 मुटुआ दें दें
# 0.17647058823529413
#
# 30
# Actual    :	 बचता होता
# Prediction:	 बचते हो
# 0.6363636363636364
#
# 31
# Actual    :	 बेच रही होगी
# Prediction:	 बेची होगी
# 0.35714285714285715
#
# 32
# Actual    :	 बनती हूँगी
# Prediction:	 बनती होंगी
# 0.8333333333333334
#
# 33
# Actual    :	 नहा रहा होगा
# Prediction:	 नहा रहा होगा
# 1.0
#
# 34
# Actual    :	 छुट रही होती
# Prediction:	 छुन रही होती
# 0.9285714285714286
#
# 35
# Actual    :	 मस्ती करते होते
# Prediction:	 मस्त करते हो
# 0.29411764705882354
#
# 36
# Actual    :	 प्रवेश किया होगा
# Prediction:	 प्रवेश करता होगा
# 0.8888888888888888
#
# 37
# Actual    :	 यह स्वप्न देखेगी
# Prediction:	 स्वप्न प्न देखी थ
# 0.1111111111111111
#
# 38
# Actual    :	 छींक रही हैं
# Prediction:	 छींक रही हैं
# 1.0
#
# 39
# Actual    :	 ना करती हों
# Prediction:	 ना करती हो
# 0.8461538461538461
#
# 40
# Actual    :	 यह अपना पालक पनीर देखे
# Prediction:	 अपना पालक पनीर पनीर पनी
# 0.08333333333333333
#
# 41
# Actual    :	 तुम जपोगे
# Prediction:	 जपी है
# 0.18181818181818182
#
# 42
# Actual    :	 हगे थे
# Prediction:	 गारे थे
# 0.125
#
# 43
# Actual    :	 बनाए थे
# Prediction:	 बना  था
# 0.7777777777777778
#
# 44
# Actual    :	 बोल रहे हैं
# Prediction:	 बोल रहा है
# 0.7692307692307693
#
# 45
# Actual    :	 ये बेचेंगे
# Prediction:	 बेची हैं
# 0.25
#
# 46
# Actual    :	 बैठता होगा
# Prediction:	 बैठता होगा
# 1.0
#
# 47
# Actual    :	 छीलता हो
# Prediction:	 छीलता है
# 0.9
#
# 48
# Actual    :	 सेक्स किया होता
# Prediction:	 तू सेक्क रहा हूँ
# 0.058823529411764705
#
# 49
# Actual    :	 बोलती हों
# Prediction:	 बोली हों
# 0.36363636363636365
#
# 50
# Actual    :	 मतलब होई हों
# Prediction:	 मतलब होत होती
# 0.7857142857142857
#
# 51
# Actual    :	 उलटी कर रही होती
# Prediction:	 उलटी कर रही होत
# 0.8888888888888888
#
# 52
# Actual    :	 ऐश किया होता
# Prediction:	 ऐश किये हो
# 0.7142857142857143
#
# 53
# Actual    :	 सहमा रही हैं
# Prediction:	 सहमा रही हूँ
# 0.8571428571428571
#
# 54
# Actual    :	 खोला हो
# Prediction:	 खोला हो
# 1.0
#
# 55
# Actual    :	 उतरने
# Prediction:
# 0.14285714285714285
#
# 56
# Actual    :	 कुरेदने
# Prediction:	 कंगिश र
# 0.1111111111111111
#
# 57
# Actual    :	 घुसा हूँ
# Prediction:	 सुसा होता
# 0.6
#
# 58
# Actual    :	 झाड़ते हों
# Prediction:	 झाड़ते हो
# 0.8333333333333334
#
# 59
# Actual    :	 लिखते होगे
# Prediction:	 लिखाएा था
# 0.3333333333333333
#
# 60
# Actual    :	 कूटे हो
# Prediction:	 कूटा हो
# 0.8888888888888888
#
# 61
# Actual    :	 मोड़ रहे हो
# Prediction:	 मोड़ रहे हो
# 1.0
#
# 62
# Actual    :	 अंछर मारई होती
# Prediction:	 अंछर मारई हो
# 0.8125
#
# 63
# Actual    :	 पहन रही हों
# Prediction:	 पहन रही हो
# 0.8461538461538461
#
# 64
# Actual    :	 रची होती
# Prediction:	 रची हो
# 0.7
#
# 65
# Actual    :	 झाड़ी हूँगी
# Prediction:	 झां झाड़ूँगी
# 0.23076923076923078
#
# 66
# Actual    :	 छुट रही हों
# Prediction:	 छुन रही होती
# 0.7692307692307693
#
# 67
# Actual    :	 चुसी होती
# Prediction:	 चुसी होती
# 1.0
#
# 68
# Actual    :	 ठगी होती
# Prediction:	 गाँी होती
# 0.1
#
# 69
# Actual    :	 मनाती थीं
# Prediction:	 मनाती थीं
# 1.0
#
# 70
# Actual    :	 यह भेजे
# Prediction:	 तुम पनके
# 0.1111111111111111
#
# 71
# Actual    :	 नहाते हो
# Prediction:	 नाँकाा है
# 0.2
#
# 72
# Actual    :	 अंछर मारए होंगे
# Prediction:	 अंछर बराए होगा
# 0.5882352941176471
#
# 73
# Actual    :	 त्यागा होता
# Prediction:	 त्यागा होता
# 1.0
#
# 74
# Actual    :	 गुणा करता हूँगा
# Prediction:	 गुणा करता हूँगा
# 1.0
#
# 75
# Actual    :	 मैं साफ़ करूंगी
# Prediction:	 साफ कियी थीं
# 0.17647058823529413
#
# 76
# Actual    :	 उड़ता होता
# Prediction:	 उड़ते हो
# 0.6666666666666666
#
# 77
# Actual    :	 गुणा कर रही थीं
# Prediction:	 गुणा कर रही थीं
# 1.0
#
# 78
# Actual    :	 बर्दाश्त किया था
# Prediction:	 बर्दाश्त किया था
# 1.0
#
# 79
# Actual    :	 ये पहनें
# Prediction:	 पहनी थी
# 0.1
#
# 80
# Actual    :	 पड़ी हूँ
# Prediction:	 पड़ी है
# 0.7
#
# 81
# Actual    :	 इलाज कर रहा था
# Prediction:	 इला कर रहे थे
# 0.25
#
# 82
# Actual    :	 मिला रहे थे
# Prediction:	 मिला रहा था
# 0.8461538461538461
#
# 83
# Actual    :	 समझ रहा था
# Prediction:	 समझ रहे थे
# 0.8333333333333334
#
# 84
# Actual    :	 बर्दाश्त कियी थी
# Prediction:	 बर्दाश्त कियी थी
# 1.0
#
# 85
# Actual    :	 चाट रहा होता
# Prediction:	 चाट रहे हो
# 0.7142857142857143
#
# 86
# Actual    :	 दोहरा रही होगी
# Prediction:	 दोहोर रही होगगी
# 0.75
#
# 87
# Actual    :	 स्वप्न देख रहे होंगे
# Prediction:	 स्वप्न देख रहा हूँगा
# 0.8181818181818182
#
# 88
# Actual    :	 सुधार रही होगी
# Prediction:	 सुधा रही होगी
# 0.3125
#
# 89
# Actual    :	 लौटी होगी
# Prediction:	 लौटी थी
# 0.5454545454545454
#
# 90
# Actual    :	 ये पूजा करेंगी
# Prediction:	 पूजा कियी थी
# 0.0625
#
# 91
# Actual    :	 चुक रहा होता
# Prediction:	 चुक रहे होते
# 0.8571428571428571
#
# 92
# Actual    :	 सूंघती हों
# Prediction:	 सूंघती हों
# 1.0
#
# 93
# Actual    :	 नहाती थी
# Prediction:	 नहानी थीं
# 0.8
#
# 94
# Actual    :	 सोचती हैं
# Prediction:	 सोची है
# 0.36363636363636365
#
# 95
# Actual    :	 पिट रहे थे
# Prediction:	 पिट रहा था
# 0.8333333333333334
#
# 96
# Actual    :	 पीया हूँ
# Prediction:	 पी  हूँ
# 0.3
#
# 97
# Actual    :	 हस्तमैथुन किया होगा
# Prediction:	 हस्तमम्न किये होगे
# 0.2857142857142857
#
# 98
# Actual    :	 गिरफ़्तार करता होगा
# Prediction:	 गिरफ़्तारते होगे
# 0.47619047619047616
#
# 99
# Actual    :	 बन रही हों
# Prediction:	 बन रही हूँ
# 0.8333333333333334
#
# 100
# Actual    :	 झूमते हों
# Prediction:	 झूमा हो
# 0.36363636363636365
#
# 101
# Actual    :	 झगड़े थे
# Prediction:	 झगड़े थे
# 1.0
#
# 102
# Actual    :	 भूले हैं
# Prediction:	 भूला हूँ
# 0.7
#
# 103
# Actual    :	 सुना रहे होंगे
# Prediction:	 सुना रहा होगा
# 0.6875
#
# 104
# Actual    :	 प्रेम करते होंगे
# Prediction:	 प्रेम करते होगे
# 0.7777777777777778
#
# 105
# Actual    :	 जोड़ए होगे
# Prediction:	 जोड़ा होगा
# 0.8333333333333334
#
# 106
# Actual    :	 तुम नहाओ
# Prediction:	 नह नाई थी
# 0.1
#
# 107
# Actual    :	 तुम छोड़ो
# Prediction:	 छोड़ी थीं
# 0.18181818181818182
#
# 108
# Actual    :	 साफ़ किया है
# Prediction:	 साफ़ किया हो
# 0.9285714285714286
#
# 109
# Actual    :	 उबल रही होती
# Prediction:	 उबल रही होती
# 1.0
#
# 110
# Actual    :	 याद कर रहा होता
# Prediction:	 याद कर रहे हो
# 0.7647058823529411
#
# 111
# Actual    :	 बात कर रहा हूँ
# Prediction:	 बात कर रहा होता
# 0.8125
#
# 112
# Actual    :	 चढ़ा रहे थे
# Prediction:	 चढ़ा रहे थे
# 1.0
#
# 113
# Actual    :	 बैठा हूँ
# Prediction:	 बैठा हूँ
# 1.0
#
# 114
# Actual    :	 जगा था
# Prediction:	 जगा था
# 1.0
#
# 115
# Actual    :	 बजाई हो
# Prediction:	 बजायी है
# 0.4444444444444444
#
# 116
# Actual    :	 मतलब होती हूँ
# Prediction:	 मतलब होती हो
# 0.8
#
# 117
# Actual    :	 लटकती थी
# Prediction:	 लटकी थीं
# 0.5
#
# 118
# Actual    :	 यह हटेगा
# Prediction:	 हटी है
# 0.1
#
# 119
# Actual    :	 नफ़रत कर रही हैं
# Prediction:	 नफ़रत कर रही है
# 0.8888888888888888
#
# 120
# Actual    :	 निकलते हो
# Prediction:	 निकलाता हो
# 0.45454545454545453
#
# 121
# Actual    :	 रखती
# Prediction:	 निख
# 0.16666666666666666
#
# 122
# Actual    :	 सेक्स कर रही होंगी
# Prediction:	 सू सेक्र रही होगी
# 0.5
#
# 123
# Actual    :	 सहमते हों
# Prediction:	 सहमा होता
# 0.45454545454545453
#
# 124
# Actual    :	 कुरेद रही थी
# Prediction:	 कुरून रही थी
# 0.8571428571428571
#
# 125
# Actual    :	 बर्दाश्त कर रही होगी
# Prediction:	 बर्दाश्क कर रही होगी
# 0.9545454545454546
#
# 126
# Actual    :	 बोलती होती
# Prediction:	 बोलती हो
# 0.75
#
# 127
# Actual    :	 तू जागेगी
# Prediction:	 तुम बागा
# 0.18181818181818182
#
# 128
# Actual    :	 छेड़ रहे हो
# Prediction:	 छेड़ रहा हो
# 0.9230769230769231
#
# 129
# Actual    :	 छाप रही होंगी
# Prediction:	 छाप रही हूँगी
# 0.8666666666666667
#
# 130
# Actual    :	 अंगारे बरस रही हूँ
# Prediction:	 अंगारे बरसई हो
# 0.6
#
# 131
# Actual    :	 आदर करता हूँगा
# Prediction:	 आदर करता होगा
# 0.6875
#
# 132
# Actual    :	 भागए थे
# Prediction:	 भाग थे
# 0.4444444444444444
#
# 133
# Actual    :	 सहमाता
# Prediction:	 हसह
# 0.125
#
# 134
# Actual    :	 बाटए हों
# Prediction:	 बाटा हूँ
# 0.7
#
# 135
# Actual    :	 चोद रहा था
# Prediction:	 चोद रहा था
# 1.0
#
# 136
# Actual    :	 सोची होंगी
# Prediction:	 सोची होंगी
# 1.0
#
# 137
# Actual    :	 दोहराइये
# Prediction:	 दोहरा करए
# 0.6
#
# 138
# Actual    :	 बिखर रही होगी
# Prediction:	 बिखर रही होगी
# 1.0
#
# 139
# Actual    :	 भुना होता
# Prediction:	 भुने हों
# 0.6363636363636364
#
# 140
# Actual    :	 डर रहे थे
# Prediction:	 डर रहा था
# 0.8181818181818182
#
# 141
# Actual    :	 आग्रह करती है
# Prediction:	 आग्रह करती है
# 1.0
#
# 142
# Actual    :	 हिली थी
# Prediction:	 हिल लाए
# 0.5555555555555556
#
# 143
# Actual    :	 हल चलाता
# Prediction:	 हलो ला
# 0.1
#
# 144
# Actual    :	 कुरेदा हूँगा
# Prediction:	 कुरेदा हूँगा
# 1.0
#
# 145
# Actual    :	 डलवाती होती
# Prediction:	 डलवाती हो
# 0.7692307692307693
#
# 146
# Actual    :	 नशा कियी हो
# Prediction:	 नाश कियी है
# 0.7692307692307693
#
# 147
# Actual    :	 बटोरती होती
# Prediction:	 बटोरती होती
# 1.0
#
# 148
# Actual    :	 चोट किये होंगे
# Prediction:	 चोट किया हूँगा
# 0.75
#
# 149
# Actual    :	 छींकती हो
# Prediction:	 छींकती हो
# 1.0
#
# 150
# Actual    :	 अंगारा होती होगी
# Prediction:	 अंगारा होत होगी
# 0.6111111111111112
#
# 151
# Actual    :	 पहुँची हो
# Prediction:	 पहुँची हो
# 1.0
#
# 152
# Actual    :	 यह सड़े
# Prediction:	 सड़ी थीं
# 0.1111111111111111
#
# 153
# Actual    :	 अंगारे बरसई होती
# Prediction:	 अंगारे बरसई हो
# 0.8333333333333334
#
# 154
# Actual    :	 सहमाए होंगे
# Prediction:	 सहमाए हूँगा
# 0.7692307692307693
#
# 155
# Actual    :	 लौटती थीं
# Prediction:	 ये लौटेंगी
# 0.09090909090909091
#
# 156
# Actual    :	 झगड़ते थे
# Prediction:	 झगड़ते थे
# 1.0
#
# 157
# Actual    :	 ठगती हैं
# Prediction:	 गगी
# 0.2
#
# 158
# Actual    :	 शुक्रिया करती थी
# Prediction:	 शुक्रिया करती थी
# 1.0
#
# 159
# Actual    :	 तैराता होता
# Prediction:	 तरााता होता
# 0.8461538461538461
#
# 160
# Actual    :	 ठग रही होती
# Prediction:	 गी रही होत
# 0.6923076923076923
#
# 161
# Actual    :	 टपकिए
# Prediction:	 टो कि
# 0.14285714285714285
#
# 162
# Actual    :	 ग़लत कर रहा था
# Prediction:	 ग़लत कर रहे थे
# 0.875
#
# 163
# Actual    :	 गिरफ़्तार करती थीं
# Prediction:	 गिरफ़्तार करेगी
# 0.65
#
# 164
# Actual    :	 भौंह चढ़ाई होगी
# Prediction:	 भौंह चढ़ा करएगगी
# 0.6470588235294118
#
# 165
# Actual    :	 निर्माण किये हों
# Prediction:	 निर्माण किया हो
# 0.8333333333333334
#
# 166
# Actual    :	 जला रही हैं
# Prediction:	 जाल रही हैं
# 0.8461538461538461
#
# 167
# Actual    :	 यह तौबा करेगी
# Prediction:	 तौबा करती थी
# 0.06666666666666667
#
# 168
# Actual    :	 चूमी थी
# Prediction:	 चूम चो
# 0.4444444444444444
#
# 169
# Actual    :	 कुरेदे हो
# Prediction:	 कुरे  हो
# 0.45454545454545453
#
# 170
# Actual    :	 पीए थे
# Prediction:	 पीने थे
# 0.375
#
# 171
# Actual    :	 घृणा कियी होती
# Prediction:	 घृणा कियी होत
# 0.875
#
# 172
# Actual    :	 हम पसीजेंगी
# Prediction:	 पसीजी थी
# 0.07692307692307693
#
# 173
# Actual    :	 चलती है
# Prediction:	 चलती है
# 1.0
#
# 174
# Actual    :	 थाम रहा हो
# Prediction:	 थाम रहे हो
# 0.9166666666666666
#
# 175
# Actual    :	 झूठ बोल रहे होंगे
# Prediction:	 झूम ब कर रहा हूँगा
# 0.2631578947368421
#
# 176
# Actual    :	 पा रही होती
# Prediction:	 पा रही होती
# 1.0
#
# 177
# Actual    :	 तू दबाएगा
# Prediction:	 दबा
# 0.09090909090909091
#
# 178
# Actual    :	 सहमा रहे हों
# Prediction:	 सहमा रहे हों
# 1.0
#
# 179
# Actual    :	 सहायता किया
# Prediction:	 हह
# 0.23076923076923078
#
# 180
# Actual    :	 हम टपकेंगी
# Prediction:	 टपकी थी
# 0.08333333333333333
#
# 181
# Actual    :	 अंगारे बरसती हैं
# Prediction:	 अंगारे बरसती हैं
# 1.0
#
# 182
# Actual    :	 सूखी होंगी
# Prediction:	 सूखी होंगी
# 1.0
#
# 183
# Actual    :	 नहा रही हूँ
# Prediction:	 नह नारही हैं
# 0.23076923076923078
#
# 184
# Actual    :	 पाई हूँगी
# Prediction:	 पाई होंगी
# 0.8181818181818182
#
# 185
# Actual    :	 ग़लत कर रही हूँ
# Prediction:	 ग़लत कर रही होती
# 0.8235294117647058
#
# 186
# Actual    :	 बनाया हूँगा
# Prediction:	 बनाए होंगे
# 0.3076923076923077
#
# 187
# Actual    :	 इस्तेमाल किये होगे
# Prediction:	 इस्तेमाल किये होगे
# 1.0
#
# 188
# Actual    :	 हम चोट करें
# Prediction:	 चोट कियी थी
# 0.15384615384615385
#
# 189
# Actual    :	 लौटती थी
# Prediction:	 मैलटती थी
# 0.1
#
# 190
# Actual    :	 मना रही हों
# Prediction:	 मना रही होती
# 0.8461538461538461
#
# 191
# Actual    :	 झूमी हों
# Prediction:	 झूमी हो
# 0.8
#
# 192
# Actual    :	 माफ़ कियी होती
# Prediction:	 माफ़ कियी हो
# 0.8125
#
# 193
# Actual    :	 रौशन करते हो
# Prediction:	 रौशन करते हो
# 1.0
#
# 194
# Actual    :	 मिला रही हूँ
# Prediction:	 मिला रही हो
# 0.7857142857142857
#
# 195
# Actual    :	 खेला था
# Prediction:	 खिखला था
# 0.2222222222222222
#
# 196
# Actual    :	 दोहराते हैं
# Prediction:	 दोहराते है
# 0.8461538461538461
#
# 197
# Actual    :	 लू कर रहा होता
# Prediction:	 लूट कर रहे होत
# 0.25
#
# 198
# Actual    :	 सहमाने
# Prediction:	 सहनां
# 0.5
#
# 199
# Actual    :	 बर्दाश्त कियी थी
# Prediction:	 बर्दाश्त कियी थी
# 1.0
#
# 200
# Actual    :	 पड़ रही हों
# Prediction:	 पड़ रही होती
# 0.8461538461538461
#
# 201
# Actual    :	 जमा कियी होंगी
# Prediction:	 जमा कियी होंगी
# 1.0
#
# 202
# Actual    :	 ये डलवाएंगी
# Prediction:	 डला जलाए
# 0.23076923076923078
#
# 203
# Actual    :	 भौंह चढ़ाई थी
# Prediction:	 भौंह चढ़ा करएं
# 0.6666666666666666
#
# 204
# Actual    :	 कस रहे होते
# Prediction:	 कस रहा हूँ
# 0.6153846153846154
#
# 205
# Actual    :	 ये बिकेंगी
# Prediction:	 बिक्ब थी
# 0.08333333333333333
#
# 206
# Actual    :	 दौड़ रहे होते
# Prediction:	 दौड़ रहे होते
# 1.0
#
# 207
# Actual    :	 झाँकती हूँगी
# Prediction:	 झाँकती होंगी
# 0.8571428571428571
#
# 208
# Actual    :	 मैं निखारूँगा
# Prediction:	 निखारी हैं
# 0.06666666666666667
#
# 209
# Actual    :	 भेज रहा हो
# Prediction:	 भून रहे हो
# 0.75
#
# 210
# Actual    :	 बिलबिलाना
# Prediction:	 बििलिलि
# 0.45454545454545453
#
# 211
# Actual    :	 यह कोशिश करेगी
# Prediction:	 कोशिश करती थी
# 0.0625
#
# 212
# Actual    :	 बिलबिलाए होगे
# Prediction:	 बिलबिलाया होगा
# 0.5333333333333333
#
# 213
# Actual    :	 पिट रहा हूँ
# Prediction:	 पिट रहा होता
# 0.7692307692307693
#
# 214
# Actual    :	 कोशिश करो
# Prediction:	 कोिशि
# 0.08333333333333333
#
# 215
# Actual    :	 सामने आता हो
# Prediction:	 सामन करते हो
# 0.7142857142857143
#
# 216
# Actual    :	 रोकते हैं
# Prediction:	 रोकता है
# 0.7272727272727273
#
# 217
# Actual    :	 आरम्भ कर रहा होगा
# Prediction:	 आरम्भ कर रहे होगा
# 0.9473684210526315
#
# 218
# Actual    :	 कोशिश कर रही हैं
# Prediction:	 कोशिश कर रही हैं
# 1.0
#
# 219
# Actual    :	 बाँध
# Prediction:	 बाँध दि
# 0.625
#
# 220
# Actual    :	 टेंटुआ दबाई होती
# Prediction:	 टेंटुआ दबाई हो
# 0.8333333333333334
#
# 221
# Actual    :	 स्थापित करती होती
# Prediction:	 स्थाप्त करती हो
# 0.7894736842105263
#
# 222
# Actual    :	 स्थापित करता था
# Prediction:	 स्थापित किया था
# 0.8823529411764706
#
# 223
# Actual    :	 तू बांधएगी
# Prediction:	 बां बनाती थ
# 0.08333333333333333
#
# 224
# Actual    :	 तुम खड़ा करो
# Prediction:	 खड़ा कियी थी
# 0.14285714285714285
#
# 225
# Actual    :	 नापए हो
# Prediction:	 नापन  है
# 0.5555555555555556
#
# 226
# Actual    :	 अंछर मार रहे थे
# Prediction:	 अंछर जा रहे थे
# 0.4117647058823529
#
# 227
# Actual    :	 कसती हूँ
# Prediction:	 कसती हूँ
# 1.0
#
# 228
# Actual    :	 यह डाउनलोड करे
# Prediction:	 डाउनलोड करनी थी
# 0.0625
#
# 229
# Actual    :	 चूसती होगी
# Prediction:	 चूसती होगी
# 1.0
#
# 230
# Actual    :	 फूँका है
# Prediction:	 फूँके हो
# 0.8
#
# 231
# Actual    :	 चमकी होती
# Prediction:	 चमक  हो
# 0.6363636363636364
#
# 232
# Actual    :	 चोरी करती हैं
# Prediction:	 चोरी करती है
# 0.8666666666666667
#
# 233
# Actual    :	 पका रही हूँ
# Prediction:	 पका रही है
# 0.7692307692307693
#
# 234
# Actual    :	 दोहरा रही होंगी
# Prediction:	 दोह दर रही होंगी
# 0.23529411764705882
#
# 235
# Actual    :	 तैरी होती
# Prediction:	 तैरी है
# 0.6363636363636364
#
# 236
# Actual    :	 उठाी थीं
# Prediction:	 उठाा थी
# 0.7
#
# 237
# Actual    :	 सहमाती होगी
# Prediction:	 सहाती होगी
# 0.23076923076923078
#
# 238
# Actual    :	 सुधार किया हो
# Prediction:	 सुधार किया हो
# 1.0
#
# 239
# Actual    :	 निभाई होती
# Prediction:	 निभानी हो
# 0.4166666666666667
#
# 240
# Actual    :	 उबलती होंगी
# Prediction:	 उबलती होंगी
# 1.0
#
# 241
# Actual    :	 ये बनेंगी
# Prediction:	 बनाई थीं
# 0.09090909090909091
#
# 242
# Actual    :	 चुसे होते
# Prediction:	 चुसे हों
# 0.7272727272727273
#
# 243
# Actual    :	 हटती होंगी
# Prediction:	 हमीटेंगी
# 0.16666666666666666
#
# 244
# Actual    :	 डलवाए हो
# Prediction:	 ले जाए हो
# 0.1
#
# 245
# Actual    :	 हग रही हूँ
# Prediction:	 हग रही है
# 0.75
#
# 246
# Actual    :	 मरोड़ रही हैं
# Prediction:	 मरोड़ रही हूँ
# 0.8666666666666667
#
# 247
# Actual    :	 अंगारा बन रही हो
# Prediction:	 अंगारा बन रही होत
# 0.9444444444444444
#
# 248
# Actual    :	 भुन रहे हैं
# Prediction:	 भुन रहा हूँ
# 0.7692307692307693
#
# 249
# Actual    :	 बैठता हूँ
# Prediction:	 बैठता है
# 0.7272727272727273
#
# 250
# Actual    :	 भुने होते
# Prediction:	 भुने हो
# 0.7272727272727273
#
# 251
# Actual    :	 मरती हों
# Prediction:	 रुनी हूँ
# 0.5
#
# 252
# Actual    :	 घृणा कर रहे थे
# Prediction:	 घृणा कर रहे थे
# 1.0
#
# 253
# Actual    :	 चलाई हों
# Prediction:	 चलाई हो
# 0.8
#
# 254
# Actual    :	 सुनाओ
# Prediction:	 सुना कर
# 0.625
#
# 255
# Actual    :	 आराम करती होती
# Prediction:	 आराम कियी हो
# 0.6875
#
# 256
# Actual    :	 झाँका था
# Prediction:	 झामक किया
# 0.4
#
# 257
# Actual    :	 चुराे
# Prediction:	 चुुना र
# 0.375
#
# 258
# Actual    :	 उलटी किया हो
# Prediction:	 उलटी किया हो
# 1.0
#
# 259
# Actual    :	 घूमती हूँ
# Prediction:	 घूमो
# 0.36363636363636365
#
# 260
# Actual    :	 विश्लेषण कियी होगी
# Prediction:	 हम विल्लेषण करेंगे
# 0.15
#
# 261
# Actual    :	 याद करते होते
# Prediction:	 याद करते हों
# 0.8
#
# 262
# Actual    :	 सहमा रही होती
# Prediction:	 सहमा रही होती
# 1.0
#
# 263
# Actual    :	 साफ़ किये हों
# Prediction:	 साफ़ किया हो
# 0.8
#
# 264
# Actual    :	 रोई हो
# Prediction:	 रो  रही
# 0.5
#
# 265
# Actual    :	 लाती होगी
# Prediction:	 लाती होगी
# 1.0
#
# 266
# Actual    :	 अपलोड कर रही होगी
# Prediction:	 अपलोड कर रही होगी
# 1.0
#
# 267
# Actual    :	 तौबा करती होती
# Prediction:	 तबा करती होत
# 0.125
#
# 268
# Actual    :	 दोहराई होती
# Prediction:	 दोहराई होती
# 1.0
#
# 269
# Actual    :	 पहन रही हूँगी
# Prediction:	 पहन रही हूँगी
# 1.0
#
# 270
# Actual    :	 घुस रही होगी
# Prediction:	 घुस रही होगी
# 1.0
#
# 271
# Actual    :	 आराम कियी हूँ
# Prediction:	 आराम कियी हो
# 0.8
#
# 272
# Actual    :	 फिसलते होंगे
# Prediction:	 फिसलते होगा
# 0.7142857142857143
#
# 273
# Actual    :	 लौटी थी
# Prediction:	 लौटी थी
# 1.0
#
# 274
# Actual    :	 गान की
# Prediction:	 गान किय<pad>
# 0.2
#
# 275
# Actual    :	 खाँसती होगी
# Prediction:	 खाँसती होगी
# 1.0
#
# 276
# Actual    :	 मर रहे हैं
# Prediction:	 रम रहा हूँ
# 0.5833333333333334
#
# 277
# Actual    :	 पूछना
# Prediction:	 पूछी
# 0.14285714285714285
#
# 278
# Actual    :	 नशा कर रहा होगा
# Prediction:	 नशा कर रहे होगे
# 0.8823529411764706
#
# 279
# Actual    :	 सामने आ रही होगी
# Prediction:	 सामने आ रही होंगी
# 0.8333333333333334
#
# 280
# Actual    :	 झूठ बोली होती
# Prediction:	 झूठी कियी होती
# 0.26666666666666666
#
# 281
# Actual    :	 सहमा रही थी
# Prediction:	 सहमा रही थीं
# 0.9230769230769231
#
# 282
# Actual    :	 फूटे हैं
# Prediction:	 फूटा है
# 0.7
#
# 283
# Actual    :	 खो रही होगी
# Prediction:	 खो रही होगी
# 1.0
#
# 284
# Actual    :	 ये ना करेंगी
# Prediction:	 ना कियी थी
# 0.14285714285714285
#
# 285
# Actual    :	 पा रहा होगा
# Prediction:	 पा रहा होगा
# 1.0
#
# 286
# Actual    :	 डूबते होते
# Prediction:	 डूबता होता
# 0.8333333333333334
#
# 287
# Actual    :	 टेंटुआ दबा रही होती
# Prediction:	 टेंटुआ दबा रही होती
# 1.0
#
# 288
# Actual    :	 उलटी कर रहे थे
# Prediction:	 उलटी कर रहे थे
# 1.0
#
# 289
# Actual    :	 फूटा हूँ
# Prediction:	 फूटा हूँ
# 1.0
#
# 290
# Actual    :	 झाँकी होती
# Prediction:	 झाँकी होती
# 1.0
#
# 291
# Actual    :	 मैं उछलूँगा
# Prediction:	 उछली हैं
# 0.07692307692307693
#
# 292
# Actual    :	 अंछर मार रही हों
# Prediction:	 अंछराम र रही होती
# 0.7777777777777778
#
# 293
# Actual    :	 सुधार रहा था
# Prediction:	 सुधार रहा था
# 1.0
#
# 294
# Actual    :	 जाना है
# Prediction:	 जाा  हो
# 0.6666666666666666
#
# 295
# Actual    :	 ख़रीद रही थीं
# Prediction:	 ख़रीद रही थी
# 0.8666666666666667
#
# 296
# Actual    :	 मरोड़ता हूँ
# Prediction:	 मरोड़ता हूँ
# 1.0
#
# 297
# Actual    :	 उठ रहा हूँ
# Prediction:	 उठ रहा होता
# 0.75
#
# 298
# Actual    :	 बचा रहे होते
# Prediction:	 चबा रहा होता
# 0.7142857142857143
#
# 299
# Actual    :	 फैल रहे होगे
# Prediction:	 फैल रहा होगा
# 0.8571428571428571
#
# 300
# Actual    :	 खड़ा करते हो
# Prediction:	 खड़ा करते हो
# 1.0
#
# 301
# Actual    :	 डाउनलोड करते हों
# Prediction:	 डाउनलोड करते हैं
# 0.9444444444444444
#
# 302
# Actual    :	 चूसा
# Prediction:	 चू
# 0.42857142857142855
#
# 303
# Actual    :	 कह रही हूँ
# Prediction:	 कह रही हैं
# 0.8333333333333334
#
# 304
# Actual    :	 सिखाई होगी
# Prediction:	 सिखायी होगी
# 0.4166666666666667
#
# 305
# Actual    :	 आग्रह करने
# Prediction:	 आगग्र
# 0.08333333333333333
#
# 306
# Actual    :	 डाउनलोड कर रहा हूँ
# Prediction:	 डाउनलोड कर रहा हूँ
# 1.0
#
# 307
# Actual    :	 सुधार कर रहा हो
# Prediction:	 सुधार कर रहे हो
# 0.9411764705882353
#
# 308
# Actual    :	 चलाती है
# Prediction:	 चलाती है
# 1.0
#
# 309
# Actual    :	 ये छोड़ें
# Prediction:	 छोड़ी थीं
# 0.2727272727272727
#
# 310
# Actual    :	 बना रही होती
# Prediction:	 बना रही हो
# 0.7857142857142857
#
# 311
# Actual    :	 तू पिटेगी
# Prediction:	 पिटपनी थी
# 0.36363636363636365
#
# 312
# Actual    :	 बर्दाश्त कर
# Prediction:	 बिरित्द किय
# 0.13333333333333333
#
# 313
# Actual    :	 तुम भौंको
# Prediction:	 भौंभ को
# 0.09090909090909091
#
# 314
# Actual    :	 अपना पालक पनीर देख रही होंगी
# Prediction:	 अपना पा पन पन रही ही होगी
# 0.26666666666666666
#
# 315
# Actual    :	 घुस करती हो
# Prediction:	 घुस करती हो
# 1.0
#
# 316
# Actual    :	 ख़तना करती थीं
# Prediction:	 ख़तनत करती थी
# 0.8125
#
# 317
# Actual    :	 इलाज कर रही होगी
# Prediction:	 इला कर रही होंगी
# 0.3888888888888889
#
# 318
# Actual    :	 डाउनलोड कियी थीं
# Prediction:	 डाउनलोड कियी थीं
# 1.0
#
# 319
# Actual    :	 गान कियी होती
# Prediction:	 गान कियी हूँ
# 0.7333333333333333
#
# 320
# Actual    :	 रही होती
# Prediction:	 रही हो
# 0.7
#
# 321
# Actual    :	 सुना रहे हो
# Prediction:	 सुना रहा हो
# 0.9230769230769231
#
# 322
# Actual    :	 छुड़ा रही थीं
# Prediction:	 छुड़ा रही थीं
# 1.0
#
# 323
# Actual    :	 अपलोड करती थी
# Prediction:	 अपलोड करती थी
# 1.0
#
# 324
# Actual    :	 यह चूमे
# Prediction:	 चूमी थीं
# 0.1111111111111111
#
# 325
# Actual    :	 छोड़ते होंगे
# Prediction:	 छोड़ता हूँगा
# 0.7142857142857143
#
# 326
# Actual    :	 उड़ने
# Prediction:
# 0.14285714285714285
#
# 327
# Actual    :	 उड़ती हो
# Prediction:	 उड़ती हो
# 1.0
#
# 328
# Actual    :	 थाम रही हो
# Prediction:	 थाम रही होत
# 0.9166666666666666
#
# 329
# Actual    :	 बीती हो
# Prediction:	 बीत करती
# 0.4444444444444444
#
# 330
# Actual    :	 बिखरता हूँ
# Prediction:	 बिखरा हूँ
# 0.4166666666666667
#
# 331
# Actual    :	 कसा हूँगा
# Prediction:	 कसके होंगे
# 0.2727272727272727
#
# 332
# Actual    :	 तरसती हों
# Prediction:	 तरसती हो
# 0.8181818181818182
#
# 333
# Actual    :	 छोड़ रहे होते
# Prediction:	 छोड़ रहे हों
# 0.8
#
# 334
# Actual    :	 कह रहे हो
# Prediction:	 कह रहा है
# 0.8181818181818182
#
# 335
# Actual    :	 सूखो
# Prediction:	 सूखत र
# 0.5714285714285714
#
# 336
# Actual    :	 चोट करता हूँ
# Prediction:	 चोट करते हो
# 0.7142857142857143
#
# 337
# Actual    :	 पढ़ाते हैं
# Prediction:	 पढ़ाता है
# 0.75
#
# 338
# Actual    :	 आश्चर्य किये हो
# Prediction:	 आश्चर्य किये है
# 0.9411764705882353
#
# 339
# Actual    :	 छोड़ रही थी
# Prediction:	 छोड़ रही थीं
# 0.9230769230769231
#
# 340
# Actual    :	 खाँसता होगा
# Prediction:	 खाँसे होगे
# 0.38461538461538464
#
# 341
# Actual    :	 हम छापएंगी
# Prediction:	 छापी थी
# 0.08333333333333333
#
# 342
# Actual    :	 उछलते होंगे
# Prediction:	 उछलाए होंगे
# 0.8461538461538461
#
# 343
# Actual    :	 फूँक रहा हो
# Prediction:	 फूँक रहे हो
# 0.9230769230769231
#
# 344
# Actual    :	 अंछर मारई थीं
# Prediction:	 छरम पमर पहो
# 0.13333333333333333
#
# 345
# Actual    :	 मरोड़ा हूँगा
# Prediction:	 मरोड़  हूँगा
# 0.9285714285714286
#
# 346
# Actual    :	 इलाज किये हो
# Prediction:	 इलाज किया हो
# 0.9285714285714286
#
# 347
# Actual    :	 कूटे होते
# Prediction:	 कूटा हो
# 0.6363636363636364
#
# 348
# Actual    :	 बची हूँ
# Prediction:	 बची हूँ
# 1.0
#
# 349
# Actual    :	 आग्रह कर रही है
# Prediction:	 आग्रह कर रही है
# 1.0
#
# 350
# Actual    :	 प्रेम करते थे
# Prediction:	 प्रेम करता था
# 0.8666666666666667
#
# 351
# Actual    :	 उड़ा रहा था
# Prediction:	 उड़ा रहा था
# 1.0
#
# 352
# Actual    :	 पकया होगा
# Prediction:	 पकया होगा
# 1.0
#
# 353
# Actual    :	 नहाई होती
# Prediction:	 नहान होती
# 0.9090909090909091
#
# 354
# Actual    :	 उड़ रहा होता
# Prediction:	 उड़ रहा होता
# 1.0
#
# 355
# Actual    :	 पिट रहा था
# Prediction:	 पिट रहा था
# 1.0
#
# 356
# Actual    :	 रो रहे हो
# Prediction:	 रो रहा हो
# 0.9090909090909091
#
# 357
# Actual    :	 पकई होगी
# Prediction:	 पक पनीरहो
# 0.3
#
# 358
# Actual    :	 मैं छीनूँ
# Prediction:	 छीनी थी
# 0.09090909090909091
#
# 359
# Actual    :	 उतारे हो
# Prediction:	 उतारा होत
# 0.8
#
# 360
# Actual    :	 चुम्बन किये थे
# Prediction:	 चुम्बन किये थे
# 1.0
#
# 361
# Actual    :	 तुम लू करोगी
# Prediction:	 लू कियी थी
# 0.07142857142857142
#
# 362
# Actual    :	 पलट रही हूँ
# Prediction:	 पलट रही होती
# 0.7692307692307693
#
# 363
# Actual    :	 घुस करती होंगी
# Prediction:	 घुस करती होंगी
# 1.0
#
# 364
# Actual    :	 भौंह चढ़ाए होते
# Prediction:	 भौंह चढ़ाए होते
# 1.0
#
# 365
# Actual    :	 ये बांधएं
# Prediction:	 बां बनाएगी
# 0.18181818181818182
#
# 366
# Actual    :	 पड़े हों
# Prediction:	 पड़ा होता
# 0.7
#
# 367
# Actual    :	 नफ़रत कर रहे थे
# Prediction:	 नफ़रत कर रहे थे
# 1.0
#
# 368
# Actual    :	 ये मिटेंगी
# Prediction:	 ये मिटेंगी
# 1.0
#
# 369
# Actual    :	 गिरफ़्तार कर रहा होता
# Prediction:	 गिरफ़्ता कर रहा होता
# 0.391304347826087
#
# 370
# Actual    :	 ख़रीदी थी
# Prediction:	 ख़रीद करें
# 0.5454545454545454
#
# 371
# Actual    :	 बिलबिलाई हूँ
# Prediction:	 बिलबलाई हों
# 0.35714285714285715
#
# 372
# Actual    :	 अंगारे उगलए हैं
# Prediction:	 अंगारा हो रहे है
# 0.4117647058823529
#
# 373
# Actual    :	 सुस्ताता होगा
# Prediction:	 सुस्ताते होगा
# 0.9333333333333333
#
# 374
# Actual    :	 अंगारा होई हों
# Prediction:	 अंगारा होयी होत
# 0.625
#
# 375
# Actual    :	 छोड़ रहे होगे
# Prediction:	 छोड़ रहा होगा
# 0.8666666666666667
#
# 376
# Actual    :	 कह रहा होता
# Prediction:	 कह रहे हों
# 0.6923076923076923
#
# 377
# Actual    :	 पक रही है
# Prediction:	 पक रही है
# 1.0
#
# 378
# Actual    :	 ये सहमाएं
# Prediction:	 सहमाई थी
# 0.09090909090909091
#
# 379
# Actual    :	 बिक रही हों
# Prediction:	 बिक रही हो
# 0.8461538461538461
#
# 380
# Actual    :	 झूमी थीं
# Prediction:	 झूमी थी
# 0.8
#
# 381
# Actual    :	 बिखरती होगी
# Prediction:	 बिखरती होगी
# 1.0
#
# 382
# Actual    :	 जाई होती
# Prediction:	 जाती हो
# 0.3
#
# 383
# Actual    :	 तरस रही थी
# Prediction:	 तरसी थी
# 0.4166666666666667
#
# 384
# Actual    :	 पढ़ाता
# Prediction:	 प
# 0.125
#
# 385
# Actual    :	 तैरते होंगे
# Prediction:	 तैरता हूँगा
# 0.6923076923076923
#
# 386
# Actual    :	 आरम्भ किया है
# Prediction:	 आर्भ किया है
# 0.2
#
# 387
# Actual    :	 हिलती होंगी
# Prediction:	 हिलती होगी
# 0.6923076923076923
#
# 388
# Actual    :	 इनकार करते होते
# Prediction:	 इनकार किया हूँ
# 0.5882352941176471
#
# 389
# Actual    :	 चाटती होती
# Prediction:	 चाटती हो
# 0.75
#
# 390
# Actual    :	 पिट रही हो
# Prediction:	 पिट रही हो
# 1.0
#
# 391
# Actual    :	 अंगारा बनने
# Prediction:	 गांगार न
# 0.15384615384615385
#
# 392
# Actual    :	 हिलते होंगे
# Prediction:	 हिलाते होंगे
# 0.3076923076923077
#
# 393
# Actual    :	 झाँकते हो
# Prediction:	 झाँकता होत
# 0.8181818181818182
#
# 394
# Actual    :	 चूसता होता
# Prediction:	 चूसता होता
# 1.0
#
# 395
# Actual    :	 झांकती
# Prediction:
# 0.125
#
# 396
# Actual    :	 रह रहा है
# Prediction:	 रहा रहा है
# 0.2727272727272727
#
# 397
# Actual    :	 इंतज़ार कियी हैं
# Prediction:	 इंतज़ार कियी है
# 0.8888888888888888
#
# 398
# Actual    :	 इंतज़ार करता है
# Prediction:	 इंतज़ार करते है
# 0.9411764705882353
#
# 399
# Actual    :	 ठीक कर रही होंगी
# Prediction:	 ठीक कर रही होंगी
# 1.0
#
# 400
# Actual    :	 हस्तमैथुन कियी होगी
# Prediction:	 हस्तमैथुन कियी होगी
# 1.0
#
# 401
# Actual    :	 हम चुसें
# Prediction:	 चुम चुसें
# 0.1
#
# 402
# Actual    :	 फैल रहे हो
# Prediction:	 फैल रहा हैं
# 0.75
#
# 403
# Actual    :	 टपक रहे थे
# Prediction:	 टपक रहे थे
# 1.0
#
# 404
# Actual    :	 पढ़ा था
# Prediction:	 प्री था
# 0.6666666666666666
#
# 405
# Actual    :	 बर्दाश्त कर रही होगी
# Prediction:	 बर्दाश्त कर रही होगी
# 1.0
#
# 406
# Actual    :	 तू चुनेगी
# Prediction:	 चुनी थी
# 0.09090909090909091
#
# 407
# Actual    :	 ऐश कियी होती
# Prediction:	 ऐश कियी होती
# 1.0
#
# 408
# Actual    :	 लौटता हूँगा
# Prediction:	 लौटता हूँगा
# 1.0
#
# 409
# Actual    :	 बिकता होता
# Prediction:	 बिकते हो
# 0.6666666666666666
#
# 410
# Actual    :	 काटती हूँगी
# Prediction:	 काटती हूँगी
# 1.0
#
# 411
# Actual    :	 उठा रहे थे
# Prediction:	 उठा रहे थे
# 1.0
#
# 412
# Actual    :	 त्याग रहे होंगे
# Prediction:	 त्या रहा होगा
# 0.29411764705882354
#
# 413
# Actual    :	 बाँधती थी
# Prediction:	 बाँधती थी
# 1.0
#
# 414
# Actual    :	 हम अपलोड करेंगे
# Prediction:	 अपलोड कियी हैं
# 0.058823529411764705
#
# 415
# Actual    :	 मैं खोलूँगी
# Prediction:	 खोली थी
# 0.07692307692307693
#
# 416
# Actual    :	 यह तरसे
# Prediction:	 तैरी थी
# 0.2222222222222222
#
# 417
# Actual    :	 प्राप्त कियी होती
# Prediction:	 प्राप्त कर रही होत
# 0.5263157894736842
#
# 418
# Actual    :	 छीपता हूँ
# Prediction:	 छीपता हूँ
# 1.0
#
# 419
# Actual    :	 अंगारा हो जाता है
# Prediction:	 अंगारा हो जाएगा
# 0.6842105263157895
#
# 420
# Actual    :	 पूछ रहा हूँ
# Prediction:	 पूछ रहे हों
# 0.7692307692307693
#
# 421
# Actual    :	 छिपा रही है
# Prediction:	 पिपा रही है
# 0.9230769230769231
#
# 422
# Actual    :	 पी रही हूँ
# Prediction:	 पी रही होती
# 0.75
#
# 423
# Actual    :	 रुकया था
# Prediction:	 रुकी था
# 0.4
#
# 424
# Actual    :	 सड़ती होंगी
# Prediction:	 सड़ती होंगी
# 1.0
#
# 425
# Actual    :	 सहमा रही होती
# Prediction:	 सहमा रही होती
# 1.0
#
# 426
# Actual    :	 जमी होती
# Prediction:	 जमती होती
# 0.7
#
# 427
# Actual    :	 इलाज करता है
# Prediction:	 इलाज करते है
# 0.9285714285714286
#
# 428
# Actual    :	 छील रही हो
# Prediction:	 छील रही होत
# 0.9166666666666666
#
# 429
# Actual    :	 रौशन कर रही हो
# Prediction:	 रौशन कर रही हो
# 1.0
#
# 430
# Actual    :	 चलता होगा
# Prediction:	 चलते होगा
# 0.9090909090909091
#
# 431
# Actual    :	 पहुँच
# Prediction:	 पहुँची ह
# 0.6666666666666666
#
# 432
# Actual    :	 डूबता होगा
# Prediction:	 डूबते होगा
# 0.9166666666666666
#
# 433
# Actual    :	 छींकते थे
# Prediction:	 छींकता था
# 0.8181818181818182
#
# 434
# Actual    :	 जोड़ई होती
# Prediction:	 जोड़ी हो
# 0.6666666666666666
#
# 435
# Actual    :	 दिलाई होती
# Prediction:	 दिलाई हो
# 0.75
#
# 436
# Actual    :	 खोलती थीं
# Prediction:	 खोलीखतूँगी
# 0.36363636363636365
#
# 437
# Actual    :	 छीपी थीं
# Prediction:	 पीपनी थी
# 0.4
#
# 438
# Actual    :	 चोरी किया हूँ
# Prediction:	 चोरी किये हैं
# 0.8
#
# 439
# Actual    :	 बन्द कर रही हूँगी
# Prediction:	 बन्द कर रही हूँगी
# 1.0
#
# 440
# Actual    :	 खोजते
# Prediction:	 ोलो क
# 0.2857142857142857
#
# 441
# Actual    :	 उड़ती हो
# Prediction:	 उड़ती हो
# 1.0
#
# 442
# Actual    :	 रोकता था
# Prediction:	 रोका था
# 0.4
#
# 443
# Actual    :	 ये सेक्स करेंगे
# Prediction:	 तू सेक्स करेगा
# 0.6470588235294118
#
# 444
# Actual    :	 हंस रहे होंगे
# Prediction:	 हंस रहे होगा
# 0.7333333333333333
#
# 445
# Actual    :	 पहुँच रहे हैं
# Prediction:	 पहुँच रहा हूँ
# 0.8
#
# 446
# Actual    :	 भेज रहा होगा
# Prediction:	 भुन रहा होगा
# 0.8571428571428571
#
# 447
# Actual    :	 चुने हैं
# Prediction:	 चुना हूँ
# 0.7
#
# 448
# Actual    :	 पलटती होती
# Prediction:	 पलटती हो
# 0.75
#
# 449
# Actual    :	 नशा करता था
# Prediction:	 नशा करते थे
# 0.8461538461538461
#
# 450
# Actual    :	 पिघला हो
# Prediction:	 पिपली हो
# 0.8
#
# 451
# Actual    :	 भूलता हो
# Prediction:	 भूलता हो
# 1.0
#
# 452
# Actual    :	 अंगारा हो रहा होता
# Prediction:	 अंगारा हो रहा होता
# 1.0
#
# 453
# Actual    :	 जलाती होंगी
# Prediction:	 जलाती होगी
# 0.6923076923076923
#
# 454
# Actual    :	 लड़ती होती
# Prediction:	 लड़ती होती
# 1.0
#
# 455
# Actual    :	 याद कर रहे हैं
# Prediction:	 याद कर रहे हो
# 0.8125
#
# 456
# Actual    :	 कमाती हूँ
# Prediction:	 कमाती होती
# 0.7272727272727273
#
# 457
# Actual    :	 साफ़ किये थे
# Prediction:	 साफ़ किया था
# 0.8571428571428571
#
# 458
# Actual    :	 मिला रहा था
# Prediction:	 मिला रहा था
# 1.0
#
# 459
# Actual    :	 पढ़ती हो
# Prediction:	 पूनती हो
# 0.8
#
# 460
# Actual    :	 प्रारम्भ करती होती
# Prediction:	 प्रारम्भ करती हो
# 0.85
#
# 461
# Actual    :	 बटोरी है
# Prediction:	 बटोर रहो
# 0.7
#
# 462
# Actual    :	 भागई थीं
# Prediction:	 भाग थी
# 0.4
#
# 463
# Actual    :	 अंगारा हो रही होगी
# Prediction:	 अंगारा हो रही होगी
# 1.0
#
# 464
# Actual    :	 तू झांकेगी
# Prediction:	 झांकी थी
# 0.08333333333333333
#
# 465
# Actual    :	 दिलाता हूँ
# Prediction:	 दिलाएा है
# 0.6666666666666666
#
# 466
# Actual    :	 सड़ता होगा
# Prediction:	 सड़ते होगे
# 0.8333333333333334
#
# 467
# Actual    :	 नफ़रत करती थी
# Prediction:	 नफ़रत करती थी
# 1.0
#
# 468
# Actual    :	 रोने
# Prediction:	 रो
# 0.16666666666666666
#
# 469
# Actual    :	 जमा करती होगी
# Prediction:	 जमा कियी होगी
# 0.8666666666666667
#
# 470
# Actual    :	 बकई होंगी
# Prediction:	 बनक करेंग
# 0.36363636363636365
#
# 471
# Actual    :	 चूसते होते
# Prediction:	 चूसता होता
# 0.8333333333333334
#
# 472
# Actual    :	 अपना पालक पनीर देखती हो
# Prediction:	 अपना पालक पनीर देखी हो
# 0.76
#
# 473
# Actual    :	 सूज रहे होगे
# Prediction:	 सूज रहा होगा
# 0.8571428571428571
#
# 474
# Actual    :	 हटी होंगी
# Prediction:	 हम रही हूँ
# 0.2727272727272727
#
# 475
# Actual    :	 शुक्रिया कर रहा हूँ
# Prediction:	 शुक्िशा कर रहे हो
# 0.23809523809523808
#
# 476
# Actual    :	 चमकता हो
# Prediction:	 चमके होते
# 0.4
#
# 477
# Actual    :	 चोद रही हो
# Prediction:	 चोद रही है
# 0.9166666666666666
#
# 478
# Actual    :	 निखारता था
# Prediction:	 निखारा था
# 0.5
#
# 479
# Actual    :	 हग रहे थे
# Prediction:	 हग रहे थे
# 1.0
#
# 480
# Actual    :	 भौंकती हो
# Prediction:	 भौंकती होत
# 0.9090909090909091
#
# 481
# Actual    :	 तुम छींकओगी
# Prediction:	 छींकी थी
# 0.07692307692307693
#
# 482
# Actual    :	 संभोग कियी थी
# Prediction:	 संभोग करी थी
# 0.5333333333333333
#
# 483
# Actual    :	 इस्तेमाल कर रहा है
# Prediction:	 इस्तेमाल कर रहे हो
# 0.9
#
# 484
# Actual    :	 लटक रही है
# Prediction:	 लटक रही है
# 1.0
#
# 485
# Actual    :	 भौंह चढ़ाती हो
# Prediction:	 भौंह चढ़ाई हो
# 0.625
#
# 486
# Actual    :	 गुणा कियी होगी
# Prediction:	 गुणा कियी होगी
# 1.0
#
# 487
# Actual    :	 ख़रीदते हैं
# Prediction:	 ख़रीदता हूँ
# 0.7692307692307693
#
# 488
# Actual    :	 उबल रहा हूँगा
# Prediction:	 उबल रहे होंगे
# 0.7333333333333333
#
# 489
# Actual    :	 उलटी किया हूँ
# Prediction:	 उलटी किया हूँ
# 1.0
#
# 490
# Actual    :	 आराम करता होगा
# Prediction:	 आराम करता होगा
# 1.0
#
# 491
# Actual    :	 पिघला था
# Prediction:	 पिपलकिया
# 0.5
#
# 492
# Actual    :	 पीट रही है
# Prediction:	 पीट रही है
# 1.0
#
# 493
# Actual    :	 लूटता था
# Prediction:	 लूटता था
# 1.0
#
# 494
# Actual    :	 तू प्यार करेगी
# Prediction:	 प्यार कियी थी
# 0.0625
#
# 495
# Actual    :	 बजाते होंगे
# Prediction:	 बजाता हूँगा
# 0.6923076923076923
#
# 496
# Actual    :	 प्रारम्भ करती होती
# Prediction:	 प्रारम्भ करती हो
# 0.85
#
# 497
# Actual    :	 बांध रही हो
# Prediction:	 बांध रही होत
# 0.9230769230769231
#
# 498
# Actual    :	 हंसी होती
# Prediction:	 हंसी होती
# 1.0
#
# 499
# Actual    :	 तौबा किया है
# Prediction:	 तौबा किया है
# 1.0
#
# 500
# Actual    :	 बोलता है
# Prediction:	 बोलाता है
# 0.4
#
# 501
# Actual    :	 उबलता है
# Prediction:	 उबलता है
# 1.0
#
# 502
# Actual    :	 पिघल रहा था
# Prediction:	 पिपल रहा था
# 0.9230769230769231
#
# 503
# Actual    :	 छापया था
# Prediction:	 छापना था
# 0.9
#
# 504
# Actual    :	 हल चला रही होंगी
# Prediction:	 हल चला रही होंगी
# 1.0
#
# 505
# Actual    :	 बनाया होता
# Prediction:	 बनाया हो
# 0.75
#
# 506
# Actual    :	 भौंह चढ़ाई हैं
# Prediction:	 भौंह चढ़ार हैं
# 0.9375
#
# 507
# Actual    :	 छीप रहे थे
# Prediction:	 छीप रहा था
# 0.8333333333333334
#
# 508
# Actual    :	 लूटी थीं
# Prediction:	 लूटी थीं
# 1.0
#
# 509
# Actual    :	 तरसता
# Prediction:
# 0.14285714285714285
#
# 510
# Actual    :	 ये टूटें
# Prediction:	 टूटी थी
# 0.1
#
# 511
# Actual    :	 डलवा रहे थे
# Prediction:	 डलवा रहा था
# 0.8461538461538461
#
# 512
# Actual    :	 प्यार कर रहा था
# Prediction:	 प्यार कर रहा था
# 1.0
#
# 513
# Actual    :	 यह छीले
# Prediction:	 छीली थी
# 0.2222222222222222
#
# 514
# Actual    :	 हम रुकएं
# Prediction:	 रुक रूँ
# 0.1
#
# 515
# Actual    :	 ये डाउनलोड करें
# Prediction:	 डाउनलोड करए
# 0.058823529411764705
#
# 516
# Actual    :	 खड़ा करते हैं
# Prediction:	 खड़ा करते हों
# 0.9333333333333333
#
# 517
# Actual    :	 पक रहा हूँ
# Prediction:	 पक रहा हूँ
# 1.0
#
# 518
# Actual    :	 ये छुड़ाएंगी
# Prediction:	 छुड़ाएी थीं
# 0.07142857142857142
#
# 519
# Actual    :	 पिघली थी
# Prediction:	 पिप्ला पक
# 0.3
#
# 520
# Actual    :	 सुनाई हैं
# Prediction:	 सुनाई हैं
# 1.0
#
# 521
# Actual    :	 बाटया हो
# Prediction:	 बाटा हो
# 0.4
#
# 522
# Actual    :	 सूंघती थी
# Prediction:	 सूंसी थीं
# 0.45454545454545453
#
# 523
# Actual    :	 पकाता हो
# Prediction:	 पकाता हो
# 1.0
#
# 524
# Actual    :	 लगती थीं
# Prediction:	 गलगी
# 0.2
#
# 525
# Actual    :	 जमा हूँगा
# Prediction:	 जमा हूँगा
# 1.0
#
# 526
# Actual    :	 बक रही होती
# Prediction:	 बक रही होती
# 1.0
#
# 527
# Actual    :	 खोजती हैं
# Prediction:	 खोलती हैं
# 0.9090909090909091
#
# 528
# Actual    :	 शिकार कियी होगी
# Prediction:	 शिकार कियी होगी
# 1.0
#
# 529
# Actual    :	 चुसते होते
# Prediction:	 चुसता होता
# 0.8333333333333334
#
# 530
# Actual    :	 आदर किया हो
# Prediction:	 आदर किया हो
# 1.0
#
# 531
# Actual    :	 रखना
# Prediction:
# 0.16666666666666666
#
# 532
# Actual    :	 प्रारम्भ करो
# Prediction:	 प्रिया पियी ह
# 0.26666666666666666
#
# 533
# Actual    :	 हगते हैं
# Prediction:	 हगे हो
# 0.3
#
# 534
# Actual    :	 बेच रहे हों
# Prediction:	 बेच रहे हों
# 1.0
#
# 535
# Actual    :	 जाती थी
# Prediction:	 ता जानो
# 0.3333333333333333
#
# 536
# Actual    :	 ख़रीद रहा हूँगा
# Prediction:	 ख़रीद रहा हूँगा
# 1.0
#
# 537
# Actual    :	 घुमाती हूँ
# Prediction:	 घुमाती है
# 0.75
#
# 538
# Actual    :	 पढ़ाई होंगी
# Prediction:	 पढ़ाई होगी
# 0.6923076923076923
#
# 539
# Actual    :	 घुस कियी थीं
# Prediction:	 घुस कियी थी
# 0.8571428571428571
#
# 540
# Actual    :	 छेड़ रहे होगे
# Prediction:	 छेड़ रहा होगा
# 0.8666666666666667
#
# 541
# Actual    :	 झगड़ रही हो
# Prediction:	 झगड़ रही है
# 0.9230769230769231
#
# 542
# Actual    :	 ठगा होगा
# Prediction:	 ठी हा था
# 0.4
#
# 543
# Actual    :	 बाट रहे होते
# Prediction:	 बाट रहा होता
# 0.8571428571428571
#
# 544
# Actual    :	 अंगारा हो जाता
# Prediction:
# 0.0625
#
# 545
# Actual    :	 विश्लेषण कियी होगी
# Prediction:	 विश्लेषण कियी होगी
# 1.0
#
# 546
# Actual    :	 खोती होती
# Prediction:	 खोसती हो
# 0.2727272727272727
#
# 547
# Actual    :	 बनती हूँ
# Prediction:	 बनती हैं
# 0.8
#
# 548
# Actual    :	 चमकती हूँगी
# Prediction:	 चमकी हूँगी
# 0.3076923076923077
#
# 549
# Actual    :	 बचाते थे
# Prediction:	 बचाता था
# 0.8
#
# 550
# Actual    :	 कुरेदते होगे
# Prediction:	 कुरेदे होगा
# 0.42857142857142855
#
# 551
# Actual    :	 झूठ बोलती थीं
# Prediction:	 झूठ बोली थी
# 0.5333333333333333
#
# 552
# Actual    :	 नागरिक बनाई होती
# Prediction:	 नागरिक बनई हो
# 0.5555555555555556
#
# 553
# Actual    :	 मुड़ी होंगी
# Prediction:	 मुड़ी होगी
# 0.6923076923076923
#
# 554
# Actual    :	 पसीजते होगे
# Prediction:	 पसीजता होगा
# 0.8461538461538461
#
# 555
# Actual    :	 मक्खन लगाती होती
# Prediction:	 मक्न लाए हों
# 0.2222222222222222
#
# 556
# Actual    :	 प्यार करते हो
# Prediction:	 प्यार करते हो
# 1.0
#
# 557
# Actual    :	 बाट रही थी
# Prediction:	 बाट रही थीं
# 0.9166666666666666
#
# 558
# Actual    :	 जान रही थी
# Prediction:	 जान रही थी
# 1.0
#
# 559
# Actual    :	 अंगारा होए होते
# ...
# 1.0
#
# 766
# Actual    :	 यह दबाएगा
# Prediction:	 दबाई हो
# 0.09090909090909091
#
# 767
# Actual    :	 निभा रही होती
# Prediction:	 निभा रही हूँ
# 0.7333333333333333
#
# 768
# Actual    :	 छीपी हों
# Prediction:	 छीपी होती
# 0.8
#
# 769
# Actual    :	 उलटी कर रहे होंगे
# Prediction:	 उलटी कर रहा हूँगा
# 0.7894736842105263
#
# 770
# Actual    :	 हम तौबा करेंगे
# Prediction:	 बौशा कियी हैं
# 0.0625
#
# 771
# Actual    :	 शुक्रिया किया होता
# Prediction:	 शुक्रिया किये होते
# 0.9
#
# 772
# Actual    :	 जगी होती
# Prediction:	 जगत हो
# 0.6
#
# 773
# Actual    :	 खोल रही होगी
# Prediction:	 खोल रही होगी
# 1.0
#
# 774
# Actual    :	 अपलोड करती थीं
# Prediction:	 अपलोड करती थी
# 0.875
#
# 775
# Actual    :	 लगते हैं
# Prediction:	 लाता है
# 0.6
#
# 776
# Actual    :	 मुड़ी है
# Prediction:	 मुड़ी हो
# 0.9
#
# 777
# Actual    :	 बन्द कियी हो
# Prediction:	 बन्द कियी है
# 0.9285714285714286
#
# 778
# Actual    :	 नापती होती
# Prediction:	 नापनी हो
# 0.6666666666666666
#
# 779
# Actual    :	 पढ़ाते हों
# Prediction:	 पहापता होता
# 0.5
#
# 780
# Actual    :	 ये दबाएं
# Prediction:	 दबाई थी
# 0.1
#
# 781
# Actual    :	 रख रहा हूँ
# Prediction:	 रख रहा हूँ
# 1.0
#
# 782
# Actual    :	 निर्माण कर रही होती
# Prediction:	 निर्म्न कर रही हो
# 0.7619047619047619
#
# 783
# Actual    :	 भुने थे
# Prediction:	 भुने थे
# 1.0
#
# 784
# Actual    :	 डाउनलोड कीजिए
# Prediction:	 डाउनलोड कियी ह
# 0.6666666666666666
#
# 785
# Actual    :	 त्याग रहा हो
# Prediction:	 त्या रहा हो
# 0.35714285714285715
#
# 786
# Actual    :	 जग रहे हैं
# Prediction:	 जग रहा हूँ
# 0.75
#
# 787
# Actual    :	 कह रही होंगी
# Prediction:	 कह रही होगी
# 0.7142857142857143
#
# 788
# Actual    :	 इनकार कियी हूँगी
# Prediction:	 इनकार कियी हूँगी
# 1.0
#
# 789
# Actual    :	 स्वप्न देखती थीं
# Prediction:	 वप्वप्न देखती थी
# 0.1111111111111111
#
# 790
# Actual    :	 छीपती हो
# Prediction:	 छीपती हो
# 1.0
#
# 791
# Actual    :	 ले जाए थे
# Prediction:	 ले जाया था
# 0.5454545454545454
#
# 792
# Actual    :	 रखी होती
# Prediction:	 तू रही हो
# 0.2
#
# 793
# Actual    :	 हस्तमैथुन कियी होती
# Prediction:	 सहस्तेम कियी हो
# 0.047619047619047616
#
# 794
# Actual    :	 ख़तना कियी थी
# Prediction:	 ख़तन कियी थी
# 0.3333333333333333
#
# 795
# Actual    :	 ख़ून कियी है
# Prediction:	 ख़ून कियी है
# 1.0
#
# 796
# Actual    :	 हस्तमैथुन करती होती
# Prediction:	 हस्तमैस्त करती होती
# 0.8571428571428571
#
# 797
# Actual    :	 भागए होते
# Prediction:	 भागा होता
# 0.8181818181818182
#
# 798
# Actual    :	 बिकी थी
# Prediction:	 बिकली थी
# 0.4444444444444444
#
# 799
# Actual    :	 शुरू कर रहा होगा
# Prediction:	 शूरू कर रहे होगे
# 0.8333333333333334
#
# 800
# Actual    :	 मिटी होती
# Prediction:	 मिटी हो
# 0.7272727272727273
#
# 801
# Actual    :	 पड़ते हो
# Prediction:	 पपकते है
# 0.7
#
# 802
# Actual    :	 मस्ती कर रही हैं
# Prediction:	 मस्ती कर रही है
# 0.8888888888888888
#
# 803
# Actual    :	 स्वप्न देखे होते
# Prediction:	 स्वप्न देखे हो
# 0.8333333333333334
#
# 804
# Actual    :	 यह सूखेगी
# Prediction:	 सूखी थी
# 0.09090909090909091
#
# 805
# Actual    :	 शिकार किये होंगे
# Prediction:	 शिकार किया हूँगा
# 0.7777777777777778
#
# 806
# Actual    :	 स्वप्न देखो
# Prediction:	 स्वे पन द
# 0.07142857142857142
#
# 807
# Actual    :	 रचती थी
# Prediction:	 चरती थी
# 0.7777777777777778
#
# 808
# Actual    :	 सकता हो
# Prediction:	 सकता है
# 0.8888888888888888
#
# 809
# Actual    :	 सुस्ताया हूँगा
# Prediction:	 सुस्ता होंगा
# 0.4375
#
# 810
# Actual    :	 बरसते थे
# Prediction:	 बरसत था
# 0.5
#
# 811
# Actual    :	 तैरते थे
# Prediction:	 तैरता था
# 0.8
#
# 812
# Actual    :	 घुस कर रही थीं
# Prediction:	 घुस कर रही थीं
# 1.0
#
# 813
# Actual    :	 उतरे हो
# Prediction:	 उतरे हो
# 1.0
#
# 814
# Actual    :	 बचाती होगी
# Prediction:	 बचाती होगी
# 1.0
#
# 815
# Actual    :	 यह इस्तेमाल करेगी
# Prediction:	 हस्तेमाल करे
# 0.05263157894736842
#
# 816
# Actual    :	 आश्चर्य कर रही थीं
# Prediction:	 आश्चर्य कर रही थीं
# 1.0
#
# 817
# Actual    :	 कोशिश करते होते
# Prediction:	 कोशिश करते हो
# 0.8235294117647058
#
# 818
# Actual    :	 रोकती हो
# Prediction:	 रोरती हो
# 0.9
#
# 819
# Actual    :	 डलवाई होगी
# Prediction:	 डलवा  होंगी
# 0.6666666666666666
#
# 820
# Actual    :	 खाँसा हूँगा
# Prediction:	 खाँसा हूँगा
# 1.0
#
# 821
# Actual    :	 बिखरता होगा
# Prediction:	 बिखता होगा
# 0.3076923076923077
#
# 822
# Actual    :	 समझाते होते
# Prediction:	 समझाते हो
# 0.7692307692307693
#
# 823
# Actual    :	 पका रहा है
# Prediction:	 पका रहा हो
# 0.9166666666666666
#
# 824
# Actual    :	 हिला है
# Prediction:	 हिलाए है
# 0.5555555555555556
#
# 825
# Actual    :	 ठीक होती हूँगी
# Prediction:	 ठीक होती होंगी
# 0.875
#
# 826
# Actual    :	 अंगारा बनया होता
# Prediction:	 अंगारा हो होते
# 0.4444444444444444
#
# 827
# Actual    :	 चला रही होगी
# Prediction:	 चला रही होगी
# 1.0
#
# 828
# Actual    :	 पिट रही हों
# Prediction:	 पिट रही हो
# 0.8461538461538461
#
# 829
# Actual    :	 तैराते होगे
# Prediction:	 तैराता होगा
# 0.8461538461538461
#
# 830
# Actual    :	 छेड़ा है
# Prediction:	 छेड़े हैं
# 0.8
#
# 831
# Actual    :	 चढ़ते हो
# Prediction:	 चढ़ता है
# 0.8
#
# 832
# Actual    :	 ख़ून कर रहे थे
# Prediction:	 ख़ून कर रहे थे
# 1.0
#
# 833
# Actual    :	 बिलबिला रहा होता
# Prediction:	 बिलबिला रहा होता
# 1.0
#
# 834
# Actual    :	 यह लूटेगी
# Prediction:	 लूटी थी
# 0.09090909090909091
#
# 835
# Actual    :	 रहती हैं
# Prediction:	 रही हूँ
# 0.3
#
# 836
# Actual    :	 मोड़ी होती
# Prediction:	 मोड़ी होत
# 0.8333333333333334
#
# 837
# Actual    :	 चुनता होता
# Prediction:	 चुनते होते
# 0.8333333333333334
#
# 838
# Actual    :	 ये जागें
# Prediction:	 ये जागें
# 1.0
#
# 839
# Actual    :	 छीपा हो
# Prediction:	 छीपना हो
# 0.4444444444444444
#
# 840
# Actual    :	 प्रवेश कियी हो
# Prediction:	 प्रवेश कर
# 0.5625
#
# 841
# Actual    :	 ऐसी तैसी कर रही हों
# Prediction:	 ऐसी तैसी कर रही हो
# 0.9047619047619048
#
# 842
# Actual    :	 गिरफ़्तार करता हूँगा
# Prediction:	 गिरफ़्तार करते होंगे
# 0.8181818181818182
#
# 843
# Actual    :	 छिपाओ
# Prediction:	 छिपि ि
# 0.125
#
# 844
# Actual    :	 उठा रही है
# Prediction:	 उठा रही है
# 1.0
#
# 845
# Actual    :	 डर रही होगी
# Prediction:	 डरी रही होगी
# 0.23076923076923078
#
# 846
# Actual    :	 सूजे हों
# Prediction:	 सूखा हो
# 0.6
#
# 847
# Actual    :	 छीन रही हों
# Prediction:	 छीन रही हो
# 0.8461538461538461
#
# 848
# Actual    :	 भूले थे
# Prediction:	 भूला था
# 0.7777777777777778
#
# 849
# Actual    :	 निकलते होते
# Prediction:	 निकलता हूँ
# 0.6153846153846154
#
# 850
# Actual    :	 कमाते होंगे
# Prediction:	 कमाता हूँगा
# 0.6923076923076923
#
# 851
# Actual    :	 सामने आते
# Prediction:	 से
# 0.09090909090909091
#
# 852
# Actual    :	 चाह रहा हो
# Prediction:	 चाह रहे हो
# 0.9166666666666666
#
# 853
# Actual    :	 रोक रही हैं
# Prediction:	 रोक रही हो
# 0.7692307692307693
#
# 854
# Actual    :	 त्यागा होगा
# Prediction:	 त्याग ा होगा
# 0.46153846153846156
#
# 855
# Actual    :	 भेज रही होती
# Prediction:	 भूट रही हूँ
# 0.5714285714285714
#
# 856
# Actual    :	 चूमा होता
# Prediction:	 चूमा होता
# 1.0
#
# 857
# Actual    :	 बैठ रहा है
# Prediction:	 बैठ रहा है
# 1.0
#
# 858
# Actual    :	 तौबा कर रही हूँगी
# Prediction:	 तौबा कर रही होंगी
# 0.8947368421052632
#
# 859
# Actual    :	 छींक रहा हूँ
# Prediction:	 छींक रहा होता
# 0.7857142857142857
#
# 860
# Actual    :	 अपलोड कियी है
# Prediction:	 अपलोड कियी है
# 1.0
#
# 861
# Actual    :	 तुम तैराओगी
# Prediction:	 तैराई थी
# 0.15384615384615385
#
# 862
# Actual    :	 अपलोड करती होती
# Prediction:	 अपलोड करती होती
# 1.0
#
# 863
# Actual    :	 मरोड़ रहा है
# Prediction:	 मरोड़ रहा हूँ
# 0.8571428571428571
#
# 864
# Actual    :	 चूमी होती
# Prediction:	 चूमी हो
# 0.7272727272727273
#
# 865
# Actual    :	 हम बिलबिलाएंगे
# Prediction:	 बिलबिलाती है
# 0.25
#
# 866
# Actual    :	 घूमी थीं
# Prediction:	 घूम
# 0.4
#
# 867
# Actual    :	 ये तैराएं
# Prediction:	 तैयतारस
# 0.2727272727272727
#
# 868
# Actual    :	 आराम करती थीं
# Prediction:	 यह आराम करे
# 0.06666666666666667
#
# 869
# Actual    :	 आश्चर्य कियी थीं
# Prediction:	 आश्चर्य कियी थी
# 0.8888888888888888
#
# 870
# Actual    :	 उबलने
# Prediction:
# 0.14285714285714285
#
# 871
# Actual    :	 आरम्भ किये हो
# Prediction:	 आरम्भ किया हो
# 0.9333333333333333
#
# 872
# Actual    :	 गुणा कियी थी
# Prediction:	 गुना कियी थी
# 0.9285714285714286
#
# 873
# Actual    :	 हार रही थी
# Prediction:	 हार रही थी
# 1.0
#
# 874
# Actual    :	 कहे हैं
# Prediction:	 कहे हो
# 0.6666666666666666
#
# 875
# Actual    :	 माफ़ करती हो
# Prediction:	 माफ़ करती हो
# 1.0
#
# 876
# Actual    :	 घुमाई होती
# Prediction:	 घुमाई होती
# 1.0
#
# 877
# Actual    :	 मैं माफ़ करूंगा
# Prediction:	 माफ़ कियी हूँ
# 0.17647058823529413
#
# 878
# Actual    :	 भूल रही थी
# Prediction:	 भू  रही थी
# 0.9166666666666666
#
# 879
# Actual    :	 ये बचेंगी
# Prediction:	 बची होगी
# 0.09090909090909091
#
# 880
# Actual    :	 तैयार कर रहा हो
# Prediction:	 याफ़ कर रहा होता
# 0.058823529411764705
#
# 881
# Actual    :	 अपलोड की
# Prediction:	 अलोड  कियी
# 0.4166666666666667
#
# 882
# Actual    :	 स्थापित कियी है
# Prediction:	 स्थापित कियी है
# 1.0
#
# 883
# Actual    :	 अंगारे बरसया हूँ
# Prediction:	 अंगारे बरसे हों
# 0.6111111111111112
#
# 884
# Actual    :	 अंगारों पर पैर रखया होता
# Prediction:	 अंगारा हो करया होत
# 0.2692307692307692
#
# 885
# Actual    :	 मक्खन लगा रहे हो
# Prediction:	 मक्ल न रहा हैं
# 0.2777777777777778
#
# 886
# Actual    :	 जप रहे हैं
# Prediction:	 जप रहा हूँ
# 0.75
#
# 887
# Actual    :	 चाट रही हों
# Prediction:	 चाट रही होती
# 0.8461538461538461
#
# 888
# Actual    :	 चूमी हो
# Prediction:	 चूमी हो
# 1.0
#
# 889
# Actual    :	 पा रहा है
# Prediction:	 पा रहा है
# 1.0
#
# 890
# Actual    :	 जागी होती
# Prediction:	 जागा होती
# 0.9090909090909091
#
# 891
# Actual    :	 हम रचेंगी
# Prediction:	 रची थी
# 0.09090909090909091
#
# 892
# Actual    :	 तैयार कियी होती
# Prediction:	 तैयार कियी होती
# 1.0
#
# 893
# Actual    :	 झांक रहा था
# Prediction:	 झांक रहा था
# 1.0
#
# 894
# Actual    :	 शुक्रिया कर रही हो
# Prediction:	 शुक्रिया कर रही है
# 0.95
#
# 895
# Actual    :	 फँस रहा होता
# Prediction:	 फँस रहे हों
# 0.7142857142857143
#
# 896
# Actual    :	 झुकी हों
# Prediction:	 झुकी होती
# 0.8
#
# 897
# Actual    :	 ला रही हूँगी
# Prediction:	 ला रही हूँगी
# 1.0
#
# 898
# Actual    :	 पूजा करती हो
# Prediction:	 पूजा करती है
# 0.9285714285714286
#
# 899
# Actual    :	 बन्द कर रहा हूँगा
# Prediction:	 बन्द कर रहे हूँगा
# 0.9473684210526315
#
# 900
# Actual    :	 झाड़ती हूँगी
# Prediction:	 झाँची होगी
# 0.21428571428571427
#
# 901
# Actual    :	 बिकी हैं
# Prediction:	 बिकल करूं
# 0.5
#
# 902
# Actual    :	 चमक रहे थे
# Prediction:	 चमक रहे थे
# 1.0
#
# 903
# Actual    :	 बैठ रहा है
# Prediction:	 बैठ रहा है
# 1.0
#
# 904
# Actual    :	 खड़ा कियी हों
# Prediction:	 खड़ा कियी हों
# 1.0
#
# 905
# Actual    :	 रहती हों
# Prediction:	 रही हूँ
# 0.3
#
# 906
# Actual    :	 सूज रही हो
# Prediction:	 सूज रही हो
# 1.0
#
# 907
# Actual    :	 हट रहे होंगे
# Prediction:	 हट रहा होगा
# 0.6428571428571429
#
# 908
# Actual    :	 भौंका हो
# Prediction:	 भौंक किये
# 0.5
#
# 909
# Actual    :	 त्यागा होता
# Prediction:	 त्यागा होत
# 0.8461538461538461
#
# 910
# Actual    :	 डाउनलोड कर रहे हैं
# Prediction:	 डाउनलोड कर रहा हूँ
# 0.85
#
# 911
# Actual    :	 प्रेम किया होता
# Prediction:	 प्रेम किये होते
# 0.8823529411764706
#
# 912
# Actual    :	 घूमता हूँ
# Prediction:	 घूमा हूँ
# 0.36363636363636365
#
# 913
# Actual    :	 मिटा हो
# Prediction:	 मिटा हो
# 1.0
#
# 914
# Actual    :	 नाप रही होगी
# Prediction:	 नाप रही होगी
# 1.0
#
# 915
# Actual    :	 खोजी होती
# Prediction:	 खोोी हो
# 0.6363636363636364
#
# 916
# Actual    :	 भेजी होती
# Prediction:	 भुनी होती
# 0.8181818181818182
#
# 917
# Actual    :	 चोरी करता था
# Prediction:	 चोरी करते थे
# 0.8571428571428571
#
# 918
# Actual    :	 पिघली हैं
# Prediction:	 पिपली हैं
# 0.9090909090909091
#
# 919
# Actual    :	 बैठता
# Prediction:	 बैं
# 0.42857142857142855
#
# 920
# Actual    :	 चुस रही होती
# Prediction:	 चुस रही होती
# 1.0
#
# 921
# Actual    :	 अंगारा बनते हों
# Prediction:	 अंगारा बनते हो
# 0.8823529411764706
#
# 922
# Actual    :	 बाँधा होगा
# Prediction:	 बाँधया होगा
# 0.4166666666666667
#
# 923
# Actual    :	 बिखरती हो
# Prediction:	 बिखरी हो
# 0.45454545454545453
#
# 924
# Actual    :	 बोली थी
# Prediction:	 बोली थी
# 1.0
#
# 925
# Actual    :	 तौबा करती थी
# Prediction:	 तैठ बरत करती
# 0.21428571428571427
#
# 926
# Actual    :	 पलट रहा हूँ
# Prediction:	 पलट रहा हों
# 0.8461538461538461
#
# 927
# Actual    :	 सूख रहे होंगे
# Prediction:	 सूख रहा होगा
# 0.6666666666666666
#
# 928
# Actual    :	 जुड़ रहा हो
# Prediction:	 जुड़ रहा होत
# 0.9230769230769231
#
# 929
# Actual    :	 लू करती हों
# Prediction:	 लू करती होती
# 0.8461538461538461
#
# 930
# Actual    :	 इनकार कियी है
# Prediction:	 हमना कियी है
# 0.13333333333333333
#
# 931
# Actual    :	 बीत रहे होते
# Prediction:	 बीत रहा होता
# 0.8571428571428571
#
# 932
# Actual    :	 पसीजी होती
# Prediction:	 पसीजी हो
# 0.75
#
# 933
# Actual    :	 बकता होगा
# Prediction:	 बनकता होगा
# 0.18181818181818182
#
# 934
# Actual    :	 ख़ून करता हूँ
# Prediction:	 ख़ून करता हूँ
# 1.0
#
# 935
# Actual    :	 ग़लत कियी थीं
# Prediction:	 तल गित करो
# 0.06666666666666667
#
# 936
# Actual    :	 झूठ बोल रहा हूँ
# Prediction:	 झूठ बो रहा होता
# 0.47058823529411764
#
# 937
# Actual    :	 यह पिटेगा
# Prediction:	 पिटपी है
# 0.18181818181818182
#
# 938
# Actual    :	 सोच रहा हूँ
# Prediction:	 सोच रहे हों
# 0.7692307692307693
#
# 939
# Actual    :	 बोल रहे होते
# Prediction:	 बोल रहे हो
# 0.7857142857142857
#
# 940
# Actual    :	 बेचते होगे
# Prediction:	 बेचाा हूँगा
# 0.5
#
# 941
# Actual    :	 उठ रही हो
# Prediction:	 उठ रही हो
# 1.0
#
# 942
# Actual    :	 घुस कर रहे होते
# Prediction:	 घुस कर रहे हो
# 0.8235294117647058
#
# 943
# Actual    :	 मिट रहा था
# Prediction:	 मिट रहा था
# 1.0
#
# 944
# Actual    :	 हस्तमैथुन करना
# Prediction:	 हम हस हों थ
# 0.1875
#
# 945
# Actual    :	 अपलोड कर रहा है
# Prediction:	 अपलोड कर रहे हो
# 0.8823529411764706
#
# 946
# Actual    :	 छीली होती
# Prediction:	 छीलती होती
# 0.36363636363636365
#
# 947
# Actual    :	 मस्ती किया होगा
# Prediction:	 मस्त किया होगा
# 0.29411764705882354
#
# 948
# Actual    :	 डरता हूँ
# Prediction:	 डरता हूँ
# 1.0
#
# 949
# Actual    :	 पसीजता
# Prediction:	 पीजी हो
# 0.25
#
# 950
# Actual    :	 भौंक रहे हों
# Prediction:	 भौंक रहे होते
# 0.8571428571428571
#
# 951
# Actual    :	 इलाज कर रहे होगे
# Prediction:	 इलाज कर रहा होगा
# 0.8888888888888888
#
# 952
# Actual    :	 चोदी होती
# Prediction:	 चोदी होती
# 1.0
#
# 953
# Actual    :	 चूमता था
# Prediction:	 चूमा था
# 0.4
#
# 954
# Actual    :	 झूम रही हो
# Prediction:	 झूम रही हो
# 1.0
#
# 955
# Actual    :	 तुम इस्तेमाल करोगी
# Prediction:	 इस्तेमाल करें
# 0.05
#
# 956
# Actual    :	 घूम रही है
# Prediction:	 घूम रही है
# 1.0
#
# 957
# Actual    :	 प्यार कर रही होती
# Prediction:	 प्यार कर रही होती
# 1.0
#
# 958
# Actual    :	 प्रवेश कर रहे थे
# Prediction:	 प्रवेश कर रहा था
# 0.8888888888888888
#
# 959
# Actual    :	 पिघल रहे होते
# Prediction:	 पिघल रहे हों
# 0.8
#
# 960
# Actual    :	 पका रही थीं
# Prediction:	 पका रही थी
# 0.8461538461538461
#
# 961
# Actual    :	 पीटी होगी
# Prediction:	 पीटी होंगी
# 0.7272727272727273
#
# 962
# Actual    :	 बचा है
# Prediction:	 बची है
# 0.875
#
# 963
# Actual    :	 ठगा होता
# Prediction:	 गाते हो
# 0.1
#
# 964
# Actual    :	 तुला रहे होते
# Prediction:	 तुला रहा हो
# 0.7333333333333333
#
# 965
# Actual    :	 सीखती हो
# Prediction:	 सीखती हो
# 1.0
#
# 966
# Actual    :	 भेजता था
# Prediction:	 भुनते थे
# 0.6
#
# 967
# Actual    :	 दिला रहा था
# Prediction:	 दिला रहा था
# 1.0
#
# 968
# Actual    :	 मुड़ रहा हो
# Prediction:	 मुड़ रहा होत
# 0.9230769230769231
#
# 969
# Actual    :	 सका होता
# Prediction:	 सक करे
# 0.3
#
# 970
# Actual    :	 नहाई है
# Prediction:	 नहना ही
# 0.5555555555555556
#
# 971
# Actual    :	 खोजती होगी
# Prediction:	 खो ती होगी
# 0.9166666666666666
#
# 972
# Actual    :	 अपलोड किये होते
# Prediction:	 अपलोड किया होता
# 0.8823529411764706
#
# 973
# Actual    :	 रोई हों
# Prediction:	 रो रहो
# 0.5555555555555556
#
# 974
# Actual    :	 संभोग कर रहा होता
# Prediction:	 संभोग कर रहे हो
# 0.7894736842105263
#
# 975
# Actual    :	 सहमती है
# Prediction:	 सहमी है
# 0.4
#
# 976
# Actual    :	 उड़ाता हूँगा
# Prediction:	 उड़ाता होगा
# 0.6428571428571429
#
# 977
# Actual    :	 पूछे होते
# Prediction:	 पूछे हो
# 0.7272727272727273
#
# 978
# Actual    :	 छुड़ाती हूँ
# Prediction:	 छुड़ाती हैं
# 0.8461538461538461
#
# 979
# Actual    :	 डलवाती थी
# Prediction:	 डला लाएंगी
# 0.2727272727272727
#
# 980
# Actual    :	 प्राप्त करो
# Prediction:	 प्रप्रिया
# 0.2857142857142857
#
# 981
# Actual    :	 निर्माण करते थे
# Prediction:	 निरम्न करता था
# 0.23529411764705882
#
# 982
# Actual    :	 डलवाता होता
# Prediction:	 डलाएते हो
# 0.5384615384615384
#
# 983
# Actual    :	 सोच रहे थे
# Prediction:	 सोच रहे थे
# 1.0
#
# 984
# Actual    :	 शुरू किया होगा
# Prediction:	 शुरू किया होगा
# 1.0
#
# 985
# Actual    :	 मैं नशा करूंगा
# Prediction:	 नशा कियी हैं
# 0.1875
#
# 986
# Actual    :	 नशा करते हो
# Prediction:	 नशा करते हो
# 1.0
#
# 987
# Actual    :	 अंगारे बरस रहा है
# Prediction:	 अंगारे बरस रहे हो
# 0.8947368421052632
#
# 988
# Actual    :	 पीई होती
# Prediction:	 पी
# 0.3
#
# 989
# Actual    :	 अध्ययन कर रहे हैं
# Prediction:	 अध्ययन कर रहे हों
# 0.9473684210526315
#
# 990
# Actual    :	 ठीक होई थीं
# Prediction:	 ठीक हो रही थ
# 0.6153846153846154
#
# 991
# Actual    :	 जमे हो
# Prediction:	 जम रहा
# 0.5
#
# 992
# Actual    :	 अपलोड किये हैं
# Prediction:	 अपलोड किया है
# 0.8125
#
# 993
# Actual    :	 मैं भागऊंगा
# Prediction:	 भागी हूँ
# 0.07692307692307693
#
# 994
# Actual    :	 दौड़ता होगा
# Prediction:	 दौड़ता होगा
# 1.0
#
# 995
# Actual    :	 मुड़ रहा होता
# Prediction:	 मुड़ रहे होत
# 0.8
#
# 996
# Actual    :	 तैरे होंगे
# Prediction:	 तैरी होगा
# 0.5833333333333334
#
# 997
# Actual    :	 सेक्स कियी होती
# Prediction:	 सेक्स्कर रहो
# 0.4117647058823529
#
# 998
# Actual    :	 जमा कियी हो
# Prediction:	 जमा कियी हो
# 1.0
#
# 999
# Actual    :	 अंगारे उगलई थी
# Prediction:	 अंगारे बर बरखए
# 0.5625
#
# 1000
# Actual    :	 हटे
# Prediction:	 हट र
# 0.16666666666666666
#
# 0.6751704578647375
# 233
