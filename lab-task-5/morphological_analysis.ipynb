# %% [markdown]
# # Lab Task-5: Isolated Word Morphological Analysis

# %% [markdown]
# ### Cloning the Repo

# %%
# !git clone https://github.com/NLPRL/MTDMA-Morph-Analyzer.git
# Out:
# Cloning into 'MTDMA-Morph-Analyzer'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 516 (delta 42), reused 33 (delta 33), pack-reused 471
# Receiving objects: 100% (516/516), 28.97 MiB | 38.98 MiB/s, done.
# Resolving deltas: 100% (245/245), done.

# %% [markdown]
# ### Installing Compatible Versions

# %%
# !pip install --upgrade scikit-learn==0.20.3
# !pip3 install tensorflow==1.15.0
# !pip install keras==2.1.6
# !pip install tensorflow-gpu==1.15
# Out:
# ...
#      |████████████████████████████████| 5.4MB 17.9MB/s
# ...
# ERROR: umap-learn 0.5.1 has requirement scikit-learn>=0.22, but you'll have scikit-learn 0.20.3 which is incompatible.
# ...
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# ...
#      |████████████████████████████████| 412.3MB 41kB/s
# ...
#      |████████████████████████████████| 3.8MB 48.0MB/s
# ...
#      |████████████████████████████████| 51kB 8.7MB/s
# ...
#      |████████████████████████████████| 512kB 50.6MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp37-none-any.whl size=7540 sha256=d9e2d1f72a36caf2049ecea190d8de86e095e18dbf59310436a8dc37962749b0
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...

# %% [markdown]
# ### Moving the Desired Path

# %%
cd MTDMA-Morph-Analyzer
# Out:
# /content/MTDMA-Morph-Analyzer

# %% [markdown]
# ### Downloading the Dataset

# %%
# !wget http://ltrc.iiit.ac.in/hutb_release/HDTB_pre_release_version-0.05.zip   #hindi
# Out:
# --2021-03-20 11:03:07--  http://ltrc.iiit.ac.in/hutb_release/HDTB_pre_release_version-0.05.zip
# Resolving ltrc.iiit.ac.in (ltrc.iiit.ac.in)... 196.12.53.50
# Connecting to ltrc.iiit.ac.in (ltrc.iiit.ac.in)|196.12.53.50|:80... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: http://cdn.iiit.ac.in/cdn/ltrc.iiit.ac.in/hutb_release/HDTB_pre_release_version-0.05.zip [following]
# --2021-03-20 11:03:08--  http://cdn.iiit.ac.in/cdn/ltrc.iiit.ac.in/hutb_release/HDTB_pre_release_version-0.05.zip
# Resolving cdn.iiit.ac.in (cdn.iiit.ac.in)... 14.139.82.19
# Connecting to cdn.iiit.ac.in (cdn.iiit.ac.in)|14.139.82.19|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 628493531 (599M) [application/zip]
# Saving to: ‘HDTB_pre_release_version-0.05.zip’
#
# HDTB_pre_release_ve 100%[===================>] 599.38M  4.62MB/s    in 2m 35s
#
# 2021-03-20 11:05:44 (3.86 MB/s) - ‘HDTB_pre_release_version-0.05.zip’ saved [628493531/628493531]

# %%
# !wget http://ltrc.iiit.ac.in/hutb_release/UDTB_pre_release_version-0.01.zip    #urdu
# Out:
# --2021-03-20 11:05:44--  http://ltrc.iiit.ac.in/hutb_release/UDTB_pre_release_version-0.01.zip
# Resolving ltrc.iiit.ac.in (ltrc.iiit.ac.in)... 196.12.53.50
# Connecting to ltrc.iiit.ac.in (ltrc.iiit.ac.in)|196.12.53.50|:80... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: http://cdn.iiit.ac.in/cdn/ltrc.iiit.ac.in/hutb_release/UDTB_pre_release_version-0.01.zip [following]
# --2021-03-20 11:05:45--  http://cdn.iiit.ac.in/cdn/ltrc.iiit.ac.in/hutb_release/UDTB_pre_release_version-0.01.zip
# Resolving cdn.iiit.ac.in (cdn.iiit.ac.in)... 14.139.82.19
# Connecting to cdn.iiit.ac.in (cdn.iiit.ac.in)|14.139.82.19|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 226297009 (216M) [application/zip]
# Saving to: ‘UDTB_pre_release_version-0.01.zip’
#
# UDTB_pre_release_ve 100%[===================>] 215.81M  2.05MB/s    in 55s
#
# 2021-03-20 11:06:41 (3.93 MB/s) - ‘UDTB_pre_release_version-0.01.zip’ saved [226297009/226297009]

# %% [markdown]
# ### Extracting the Dataset

# %%
# !unzip HDTB_pre_release_version-0.05.zip    #hindi
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2494108_date_1_6_2004.dat
#   inflating: HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2494312_date_1_6_2004.dat
#   inflating: HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2571134_date_4_7_2004.dat
#   inflating: HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2561717_date_30_6_2004.dat
#   inflating: HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2501730_date_4_6_2004.dat
#   inflating: HDTB_pre_release_version-0.05/IntraChunk/CoNLL/wx/news_articles_and_heritage/Training/fullnews_id_2506457_date_6_6_2004.dat
# ...

# %%
# !unzip UDTB_pre_release_version-0.01.zip    #urdu
# Out:
# Archive:  UDTB_pre_release_version-0.01.zip
#    creating: UDTB_pre_release_version-0.01/
#    creating: UDTB_pre_release_version-0.01/Inter-chunk/
#    creating: UDTB_pre_release_version-0.01/Inter-chunk/CONLL/
#    creating: UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/
#    creating: UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/Testing/
#    creating: UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/Testing/UTB-v1.0-set126/
#   inflating: UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/Testing/UTB-v1.0-set126/fullnews_id_200345_date_07_25_2009.utf8.cml.V.tkn.cml_updated.mo.pos.chnk.prun.posn
#   inflating: UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/Testing/UTB-v1.0-set126/fullnews_id_200351_date_07_25_2009.utf8.cml.V.tkn.cml_updated.mo.pos.chnk.prun.posn
#   inflating: UDTB_pre_release_version-0.01/Inter-chunk/CONLL/utf/Testing/UTB-v1.0-set126/fullnews_id_200346_date_07_25_2009.utf8.cml.V.tkn.cml_updated.mo.pos.chnk.prun.posn
# ...

# %% [markdown]
# ### Urdu

# %%
# !python main.py --lang urdu --mode train --phonetic true --freezing true #train
# Out:
# Using TensorFlow backend.
# tcmalloc: large alloc 2299912192 bytes == 0x55f81207c000 @  0x7fb164872001 0x7fb1622f054f 0x7fb162340b58 0x7fb162344b17 0x7fb1623e3203 0x55f7fc45d050 0x55f7fc45cde0 0x55f7fc4d1244 0x55f7fc45e69a 0x55f7fc4d0e50 0x55f7fc45e69a 0x55f7fc4ccc9e 0x55f7fc4cbe0d 0x55f7fc45e77a 0x55f7fc4cca45 0x55f7fc4cbb0e 0x55f7fc4cb813 0x55f7fc595592 0x55f7fc59590d 0x55f7fc5957b6 0x55f7fc56d103 0x55f7fc56cdac 0x7fb16365abf7 0x55f7fc56cc8a
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
# !python main.py --lang urdu --mode test --phonetic true --freezing true #test
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:125: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:127: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ...

# %%
# !python main.py --lang urdu --mode predict --phonetic true --freezing true #predict
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:125: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:127: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ...

# %% [markdown]
# ### Hindi

# %%
# !python main.py --lang hindi --mode train --phonetic true --freezing true #train
# Out:
# Using TensorFlow backend.
# tcmalloc: large alloc 4456816640 bytes == 0x5654e4824000 @  0x7fa879fe3001 0x7fa877a6154f 0x7fa877ab1b58 0x7fa877ab5b17 0x7fa877b54203 0x5654be668050 0x5654be667de0 0x5654be6dc244 0x5654be66969a 0x5654be6dbe50 0x5654be66969a 0x5654be6d7c9e 0x5654be6d6e0d 0x5654be66977a 0x5654be6d7a45 0x5654be6d6b0e 0x5654be6d6813 0x5654be7a0592 0x5654be7a090d 0x5654be7a07b6 0x5654be778103 0x5654be777dac 0x7fa878dcbbf7 0x5654be777c8a
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
# !python main.py --lang hindi --mode test --phonetic true --freezing true #test
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:125: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:127: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ...

# %%
# !python main.py --lang hindi --mode predict --phonetic true --freezing true #predict
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:125: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:127: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ...
